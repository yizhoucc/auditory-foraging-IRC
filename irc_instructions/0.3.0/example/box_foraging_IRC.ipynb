# %%
import os
import sys
sys.path.append(f'{os.getcwd()}/irc_package')

# %%
from irc.examples import IdenticalBoxesEnv
env = IdenticalBoxesEnv()
observation, info = env.reset(seed=0)

print(f'state_space: {env.state_space}')
env_param = env.get_param()
print(f'environment parameter: {env_param}')
env.set_param(env_param)
state = env.get_state()
print(f'environment state: {state}')
env.set_state(state)
# Out:
# state_space: MultiDiscrete([2 2 3])
# environment parameter: [ 0.2   0.05  0.6   0.1  10.   -1.  ]
# environment state: (0, 0, 2)

# %%
from irc.manager import AgentManager
defaults = {'env._target_': 'irc.examples.IdenticalBoxesEnv'}
manager = AgentManager(defaults=defaults)

# %%
agent = manager.train_agent() # using default environment parameter
# Out:
# Checkpoint (epoch 30) loaded.

# %%
#Alternate
env_param = (0.2, 0.05, 0.8, 0.1, 10., -1.)
agent = manager.train_agent(env_param=env_param, num_epochs=10)
# Out:
# Checkpoint (epoch 10) loaded.

# %%
agent, fig = manager.inspect_agent(env_param)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb Cell 6 in 1
# ----> <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> agent, fig = manager.inspect_agent(env_param)
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/irc/manager.py:291, in AgentManager.inspect_agent(self, env_param, seed, figsize)
#     271 def inspect_agent(self,
#     272     env_param: Sequence[float],
#     273     seed: Optional[int] = None,
#     274     figsize: Optional[tuple[float, float]] = None,
#     275 ) -> tuple[BeliefAgent, Figure]:
#     276     r"""Inspects one agent.
#     277
#     278     This method generates a figure composed of the training progress of the
#    (...)
#     289
#     290     """
# --> 291     agent, _ = self.fetch_agent(env_param, seed)
#     292     fig = plot_agent_checkpoint(self.ckpt, figsize)
#     293     return agent, fig
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/irc/manager.py:246, in AgentManager.fetch_agent(self, env_param, seed)
#     243 if seed is None:
#     244     # if agent seed is not specified, find the most trained one
#     245     max_epoch, best_key = 0, None
# --> 246     for key in self._env_param_keys(env_param):
#     247         epoch = self.stats[key]['epoch']
#     248         if epoch>max_epoch:
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/irc/manager.py:213, in AgentManager._env_param_keys(self, env_param, **kwargs)
#     211 cond = self.get_config({'env_param': env_param})
#     212 cond.pop('seed')
# --> 213 for key in self.completed(cond=cond, **kwargs):
#     214     yield key
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/jarvis/manager.py:501, in Manager.completed(self, min_epoch, cond)
#     497 _stats = self.stats._safe_read(f'{self.stats.store_dir}/{file_name}')
#     498 for key, stat in _stats.items():
#     499     if (
#     500         stat['epoch']>=min_epoch and
# --> 501         self._is_matched(_configs.get(key, {}), cond)
#     502     ):
#     503         yield key
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/jarvis/manager.py:474, in Manager._is_matched(config, cond)
#     471 flat_config, flat_cond = config.flatten(), cond.flatten()
#     472 for key in flat_cond:
#     473     if not (key in flat_config and (
# --> 474         flat_config[key]==flat_cond[key]
#     475         or
#     476         (callable(flat_cond[key]) and flat_cond[key](flat_config[key]))
#     477     )):
#     478         return False
#     479 return True
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
episode = agent.run_one_episode()

# %%
#Alternate
env = IdenticalBoxesEnv()
#episode = agent.run_one_episode(env, num_steps=60) #wrong
episode = agent.run_one_episode(env = env, max_steps=60)

# %%
env_param_grid = [
    [0.1, 0.2, 0.3],    # p_appear
    [],                 # p_vanish
    [0.6, 0.8],         # p_cue
    [],                 # lambda_center
    [10., 5.],          # r_food
    [],                 # r_move
]
seeds = range(2)
manager.train_agents(env_param_grid=env_param_grid, seeds=seeds, num_epochs=10)
# Out:
# 0 works processed.
# All works are processed or being processed.

# %%
report = manager.overview_agents(env_param_grid=env_param_grid, seeds=seeds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb Cell 10 in 1
# ----> <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> report = manager.overview_agents(env_param_grid=env_param_grid, seeds=seeds)
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/irc/manager.py:429, in AgentManager.overview_agents(self, env_param_list, env_param_grid, seeds, **kwargs)
#     425     cond['seed'] = lambda seed: seed in list(seeds)
#     426 configs = (
#     427     self.configs[key] for key in self.completed(cond=cond)
#     428 )
# --> 429 report = self.overview(configs, **kwargs)
#     430 return report
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/jarvis/manager.py:423, in Manager.overview(self, configs, min_epoch, p_keys)
#     420 _previews = {k: v for k, v in self.previews.items()}
#     422 keys = set()
# --> 423 for config in configs:
#     424     _config = self.configs._to_hashable(config)
#     425     if _config in _keys:
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/irc/manager.py:426, in <genexpr>(.0)
#     424 else:
#     425     cond['seed'] = lambda seed: seed in list(seeds)
# --> 426 configs = (
#     427     self.configs[key] for key in self.completed(cond=cond)
#     428 )
#     429 report = self.overview(configs, **kwargs)
#     430 return report
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/jarvis/manager.py:501, in Manager.completed(self, min_epoch, cond)
#     497 _stats = self.stats._safe_read(f'{self.stats.store_dir}/{file_name}')
#     498 for key, stat in _stats.items():
#     499     if (
#     500         stat['epoch']>=min_epoch and
# --> 501         self._is_matched(_configs.get(key, {}), cond)
#     502     ):
#     503         yield key
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/jarvis/manager.py:474, in Manager._is_matched(config, cond)
#     471 flat_config, flat_cond = config.flatten(), cond.flatten()
#     472 for key in flat_cond:
#     473     if not (key in flat_config and (
# --> 474         flat_config[key]==flat_cond[key]
#     475         or
#     476         (callable(flat_cond[key]) and flat_cond[key](flat_config[key]))
#     477     )):
#     478         return False
#     479 return True
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# beliefs, logps = agent.episode_logps(observations, actions)
beliefs, logps = agent.episode_logps(episode['observations'], episode['actions'])

# %%
# counts, logps = manager.compute_logps(
#     observations, actions,
#     env_param_grid=env_param_grid,
# )
counts, logps = manager.compute_logps(
    episode['observations'], episode['actions'],
    env_param_grid=env_param_grid,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb Cell 12 in 5
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> # counts, logps = manager.compute_logps(
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> #     observations, actions,
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> #     env_param_grid=env_param_grid,
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> # )
# ----> <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> counts, logps = manager.compute_logps(
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>     episode['observations'], episode['actions'],
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a>     env_param_grid=env_param_grid,
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/box_foraging_IRC.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> )
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/irc/manager.py:464, in AgentManager.compute_logps(self, observations, actions, env_param_list, env_param_grid, **kwargs)
#     462 cond['env_param'] = lambda env_param: tuple(env_param) in env_param_list
#     463 cond.pop('seed')
# --> 464 keys = list(self.completed(cond=cond, **kwargs))
#     465 if self.verbose:
#     466     print(f"{len(keys)} trained agents found, computing episode likelihood...")
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/jarvis/manager.py:501, in Manager.completed(self, min_epoch, cond)
#     497 _stats = self.stats._safe_read(f'{self.stats.store_dir}/{file_name}')
#     498 for key, stat in _stats.items():
#     499     if (
#     500         stat['epoch']>=min_epoch and
# --> 501         self._is_matched(_configs.get(key, {}), cond)
#     502     ):
#     503         yield key
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/irc_instructions/example/irc_package/jarvis/manager.py:474, in Manager._is_matched(config, cond)
#     471 flat_config, flat_cond = config.flatten(), cond.flatten()
#     472 for key in flat_cond:
#     473     if not (key in flat_config and (
# --> 474         flat_config[key]==flat_cond[key]
#     475         or
#     476         (callable(flat_cond[key]) and flat_cond[key](flat_config[key]))
#     477     )):
#     478         return False
#     479 return True
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 15, 'lines.linewidth': 2,
    'xtick.labelsize': 13, 'ytick.labelsize': 13,
    'axes.spines.top': False, 'axes.spines.right': False,
    'savefig.dpi': 1200,
})

import yaml
import numpy as np

import os
import sys
sys.path.append(f'{os.getcwd()}/irc_gym')

from irc.manager import IRCManager

from auditoryforage.utils import plot_AF_episode

# %%
from auditoryforage.AF_env import AuditoryForaging
env = AuditoryForaging()

# %%
from read_data import DataToEpisode

# %%
filename = f'../data_flies/compiled/compiled.csv'

# end_trial = 50
# data_to_episode = DataToEpisode(filename = filename, env = env, end_trial = end_trial)
data_to_episode = DataToEpisode(filename = filename, env = env)

# %%
data_IRC = data_to_episode.data_for_IRC()
print(data_IRC['low_reward_blocks'].keys())
print(data_IRC['low_reward_blocks']['block_indices'])
# print(data_IRC['low_reward_blocks']['episodes'])
# Out:
# dict_keys(['episodes', 'block_indices'])
# [0, 2, 4, 6]

# %%
data_IRC = data_to_episode.data_for_IRC()

# exp_dict = data_IRC['low_reward_blocks']['episodes'][3][0]
exp_dict = data_IRC['high_reward_blocks']['episodes'][2][0]

episode = {}
episode['states'] = exp_dict['states']
episode['actions'] = exp_dict['actions']
episode['observations'] = exp_dict['observations']
episode['num_steps'] = len(exp_dict['actions'])

# wrong info
episode['rewards'] = exp_dict['received_food'] # does not incorporate other costs
episode['q_probs'] = np.zeros((len(episode['states'])+1,302)) # all set to 0 temporarily

fig = plot_AF_episode(episode = episode, env = env, agent = None)
# Out:
# problem somwhere here
# [[3]
#  [0]
#  [0]
#  ...
#  [0]
#  [0]
#  [2]]
# (array([2204]), array([0]))
# problem somwhere here
# [[3]
#  [1]
#  [0]
#  ...
#  [0]
#  [0]
#  [2]]
# (array([2204]), array([0]))

# %%
data_IRC = data_to_episode.data_for_IRC()

exp_dict = data_IRC['high_reward_blocks']['episodes'][0][7]
episode = {}
episode['states'] = exp_dict['states']
episode['actions'] = exp_dict['actions']
episode['observations'] = exp_dict['observations']
episode['num_steps'] = len(exp_dict['actions'])

# wrong info
episode['rewards'] = exp_dict['received_food'] # does not incorporate other costs
episode['q_probs'] = np.zeros((len(episode['states'])+1,302)) # all set to 0 temporarily

fig = plot_AF_episode(episode = episode, env = env, agent = None)

print(np.where(exp_dict['states'].flatten() == [151]))
print(len(exp_dict['states']))

# %%
data_IRC = data_to_episode.data_for_IRC(is_continuing = True)

exp_dict = data_IRC['high_reward_blocks']['episodes'][0]
episode = {}
episode['states'] = exp_dict['states']
episode['actions'] = exp_dict['actions']
episode['observations'] = exp_dict['observations']
episode['num_steps'] = len(exp_dict['actions'])

# wrong info
episode['rewards'] = exp_dict['received_food'] # does not incorporate other costs
episode['q_probs'] = np.zeros((len(episode['states'])+1,302)) # all set to 0 temporarily

fig = plot_AF_episode(episode = episode, env = env, agent = None)

print(np.where(exp_dict['states'].flatten() == [151]))
print(len(exp_dict['states']))

# %%
data_IRC = data_to_episode.data_for_IRC(is_continuing = True)

exp_dict = data_IRC['low_reward_blocks']['episodes'][0]
episode = {}
episode['states'] = exp_dict['states']
episode['actions'] = exp_dict['actions']
episode['observations'] = exp_dict['observations']
episode['num_steps'] = len(exp_dict['actions'])

# wrong info
episode['rewards'] = exp_dict['received_food'] # does not incorporate other costs
episode['q_probs'] = np.zeros((len(episode['states'])+1,302)) # all set to 0 temporarily

fig = plot_AF_episode(episode = episode, env = env, agent = None)

for ind in np.where(exp_dict['states'].flatten() == [151])[0]:
    print(f'state was {exp_dict["states"][ind-1]} and action was {exp_dict["actions"][ind-1]}')

# %%
data_IRC = data_to_episode.data_for_IRC(is_continuing = True)

exp_dict = data_IRC['low_reward_blocks']['episodes'][1]
episode = {}
episode['states'] = exp_dict['states']
episode['actions'] = exp_dict['actions']
episode['observations'] = exp_dict['observations']
episode['num_steps'] = len(exp_dict['actions'])

# wrong info
episode['rewards'] = exp_dict['received_food'] # does not incorporate other costs
episode['q_probs'] = np.zeros((len(episode['states'])+1,302)) # all set to 0 temporarily

fig = plot_AF_episode(episode = episode, env = env, agent = None)

for ind in np.where(exp_dict['states'].flatten() == [151])[0]:
    print(f'state was {exp_dict["states"][ind-1]} and action was {exp_dict["actions"][ind-1]}')

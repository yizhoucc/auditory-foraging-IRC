# %%
import csv, copy
import numpy as np

# %%
filename = f'../data_files/orig/3_data_behavior.csv'

hit_skip_trials = 15

with open(filename) as csvfile:
    data_list = list(csv.reader(csvfile))
compiled_data = {}
title_list = data_list[0]
subj_ind = title_list.index('subject_id')
outcome_ind = title_list.index('outcome')
block_id_ind = title_list.index('block_id')
catch_ind = title_list.index('catch')
row_ind = 1
while row_ind <= len(data_list):
    
    if data_list[row_ind][subj_ind] not in compiled_data.keys():
        curr_subj_id = data_list[row_ind][subj_ind]
        compiled_data[curr_subj_id] = {}
        
        # skip block 0
        while data_list[row_ind][block_id_ind] == 0:
            row_ind += 1
    
    elif data_list[row_ind][block_id_ind] not in compiled_data[data_list[row_ind][subj_ind]].keys():
        curr_block_id = data_list[row_ind][block_id_ind]
        compiled_data[data_list[row_ind][subj_ind]][curr_block_id] = {}
        
        # skip 14 trials after first hit in new block
        while data_list[row_ind][outcome_ind] != 0:
            row_ind += 1
        row_ind += hit_skip_trials

        while data_list[row_ind][subj_ind] == curr_subj_id and data_list[row_ind][block_id_ind] == curr_block_id:
            if 
            compiled_data[data_list[row_ind][subj_ind]][curr_block_id]
    
    else:
        print("Something wrong")






    row_ind += 1
    







    
    while first_hit_flag == 0:
        if data_list[row_ind][outcome_ind] != 0:
            row_ind += 1
        else:
            row_ind += hit_skip_trials
    else
    

print(subj_ids)
# subj_id_list.append()
# unqiue_subjects = list(set(data_list[:][0]))
# print(unqiue_subjects)
# # print(data_list)
# #     # data_dict = {} 
# #     # self.end_trial = len(data_list)-2 if self.end_trial is None else self.end_trial
# #     # for col_ind in range(len(data_list[0])):
# #     #     data_dict[data_list[0][col_ind]] = [float(data_list[ind][col_ind]) for ind in range(self.start_trial+1,self.end_trial+2) if self.consider_if_true(data_list, ind)]
# #     # return data_dict
# Out:
# ['A1579', 'A1580', 'A1581', 'A1587', 'A1815', 'A1816', 'A1823', 'A1825', 'A1827', 'A1828', 'A1829', 'A1905', 'A1924', 'A2113', 'A2114', 'A2551', 'C1840', 'C1841', 'C1842', 'C1844', 'C1845', 'C1900', 'C1939', 'C1940', 'CA1914', 'CA1915', 'CA1916', 'CA1917', 'CA1918', 'CA1919', 'CA1922', 'CA1923', 'CA2095', 'CA2155', 'CA2158', 'CA2159', 'CA2160', 'TH2364', 'W1621', 'W1624', 'W1699', 'W1700', 'W1707', 'W1710', 'W1713', 'W1716', 'W1744', 'W1746', 'W1748', 'W1750', 'W1751', 'W1752', 'W1753', 'W1754', 'W1756', 'W1760', 'W1762', 'W1781', 'W1783', 'W1787', 'W1789', 'W1793', 'W1799', 'W1800', 'W1801', 'W1804', 'W1806', 'W1809', 'W1811', 'W1812', 'W2116', 'W2117', 'W2118', 'W2120', 'W2122', 'W2200', 'W2202', 'W2203', 'W2204', 'W2205', 'W2206', 'W2209', 'W2365', 'W2368', 'W2369', 'W2370', 'W2401', 'W2791']

# %%
list(set([row[1] for row in data_list][1:]))
# Out:
# ['W1624',
#  'CA1922',
#  'W2368',
#  'W2365',
#  'W2200',
#  'A1924',
#  'W1800',
#  'W1744',
#  'W2117',
#  'C1842',
#  'W1710',
#  'W1621',
#  'CA2159',
#  'CA2095',
#  'CA2158',
#  'W2120',
#  'C1940',
#  'A1827',
#  'A1828',
#  'W1754',
#  'W2203',
#  'A1825',
#  'CA1914',
#  'CA2155',
#  'W1799',
#  'W1809',
#  'C1844',
#  'CA1918',
#  'A2551',
#  'CA2160',
#  'W1752',
#  'W1753',
#  'A2113',
#  'W1713',
#  'W2116',
#  'W2370',
#  'W2209',
#  'A1905',
#  'W1707',
#  'A2114',
#  'W1760',
#  'W2369',
#  'W1748',
#  'W2206',
#  'W2791',
#  'A1815',
#  'W1804',
#  'W2401',
#  'CA1917',
#  'W1750',
#  'W1756',
#  'A1587',
#  'W1812',
#  'A1816',
#  'C1845',
#  'C1900',
#  'TH2364',
#  'A1829',
#  'W1787',
#  'W1762',
#  'W1811',
#  'W1716',
#  'W1781',
#  'W1806',
#  'C1841',
#  'W2122',
#  'W2118',
#  'CA1919',
#  'CA1923',
#  'A1823',
#  'W1746',
#  'C1840',
#  'CA1915',
#  'W2205',
#  'W1793',
#  'C1939',
#  'W2202',
#  'A1581',
#  'A1579',
#  'W1700',
#  'W1789',
#  'CA1916',
#  'W1783',
#  'W1801',
#  'W1751',
#  'W1699',
#  'A1580',
#  'W2204']

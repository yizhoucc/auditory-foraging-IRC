# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 15, 'lines.linewidth': 2,
    'xtick.labelsize': 13, 'ytick.labelsize': 13,
    'axes.spines.top': False, 'axes.spines.right': False,
    'savefig.dpi': 1200,
})

import yaml
import numpy as np

import os
import sys
sys.path.append(f'{os.getcwd()}/irc_gym')

from irc.manager import IRCManager

# %% [markdown]
# # Train one agent for a single environment

# %%
defaults = {
    'agent.env._target_': 'auditoryforage.AF_env.AuditoryForaging',
    'agent.model._target_': 'irc.model.FuncBeliefModel',
}
manager = IRCManager(defaults=defaults)

# %% [markdown]
# ## Train an agent
# We train a rational agent for the assume environment parameter [$lick\_cost, food\_reward, attention\_cost\_coeff, attention\_cost\_temp, penalty\_cost, iti\_cost$].

# %%
env_param = [0, 100.0, .08, .25, 0, 0]

# change back to old no. of epochs
num_epochs = 100

agent = manager.train_agent(env_param, num_epochs=num_epochs)
agent, fig = manager.inspect_agent(env_param, figsize=(5, 2.5))
# Out:
# Checkpoint loaded.
#
# Epoch:   1/100
# Agent trained by 10000 time steps (0m09.41s).
#
# Epoch:   2/100
# Agent trained by 10000 time steps (0m09.25s).
# Agent evaluated for 12 episodes of length 100000. Average return 0.00. ( 0m00.02s)
#
# Epoch:   3/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/AF_IRC.ipynb Cell 5 line 6
#       <a href='vscode-notebook-cell:/Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/AF_IRC.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> # change back to old no. of epochs
#       <a href='vscode-notebook-cell:/Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/AF_IRC.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> num_epochs = 100
# ----> <a href='vscode-notebook-cell:/Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/AF_IRC.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> agent = manager.train_agent(env_param, num_epochs=num_epochs)
#       <a href='vscode-notebook-cell:/Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/AF_IRC.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> agent, fig = manager.inspect_agent(env_param, figsize=(5, 2.5))
#
# File ~/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/irc_gym/irc/manager.py:427, in IRCManager.train_agent(self, env_param, seed, num_epochs, **kwargs)
#     409 r"""Traines one agent.
#     410
#     411 Args
#    (...)
#     423
#     424 """
#     426 config = self.agent_manager.get_config({'env_param': env_param, 'seed': seed})
# --> 427 self.agent_manager.process(config, num_epochs=num_epochs, **kwargs)
#     428 return self.agent_manager.agent
#
# File ~/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/irc_gym/jarvis/manager.py:232, in Manager.process(self, config, num_epochs, resume)
#     229     print(f"\nEpoch: {progress_str(self.epoch+1, num_epochs)}")
#     231 tic = time.time()
# --> 232 self.train()
#     233 toc = time.time()
#     234 if self._t_train is None:
#
# File ~/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/irc_gym/irc/manager.py:169, in AgentManager.train(self)
#     161 r"""Runs RL algorithm for one epoch.
#     162
#     163 This method is only called in agent training mode. Each training epoch
#    (...)
#     166
#     167 """
#     168 tic = time.time()
# --> 169 self.agent.algo.learn(
#     170     **self.config.learn, log_interval=None, reset_num_timesteps=False,
#     171 )
#     172 toc = time.time()
#     173 if self.verbose>0:
#
# File ~/miniconda3/envs/IRC/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~/miniconda3/envs/IRC/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:259, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     256 assert self.env is not None
#     258 while self.num_timesteps < total_timesteps:
# --> 259     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     261     if continue_training is False:
#     262         break
#
# File ~/miniconda3/envs/IRC/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 if isinstance(self.action_space, spaces.Box):
#     176     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 178 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     180 self.num_timesteps += env.num_envs
#     182 # Give access to local variables
#
# File ~/miniconda3/envs/IRC/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:172, in VecEnv.step(self, actions)
#     165 """
#     166 Step the environments with the given action
#     167
#     168 :param actions: the action
#     169 :return: observation, reward, done, information
#     170 """
#     171 self.step_async(actions)
# --> 172 return self.step_wait()
#
# File ~/miniconda3/envs/IRC/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/miniconda3/envs/IRC/lib/python3.11/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/miniconda3/envs/IRC/lib/python3.11/site-packages/shimmy/openai_gym_compatibility.py:255, in GymV21CompatibilityV0.step(self, action)
#     246 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     247     """Steps through the environment.
#     248
#     249     Args:
#    (...)
#     253         (observation, reward, terminated, truncated, info)
#     254     """
# --> 255     obs, reward, done, info = self.gym_env.step(action)
#     257     if self.render_mode is not None:
#     258         self.render()
#
# File ~/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/irc_gym/irc/model.py:200, in BaseBeliefModel.step(self, action, env)
#     198         pass
#     199 # update belief
# --> 200 self.update_belief(action, observation)
#     201 belief = self.get_belief()
#     202 # update internal environment to ensure valid query states
#
# File ~/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/irc_gym/irc/model.py:482, in FuncBeliefModel.update_belief(self, action, observation)
#     481 def update_belief(self, action, observation) -> None:
# --> 482     self.belief = self.env.update_belief(self.belief, action, observation)
#
# File ~/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/auditoryforage/AF_env.py:330, in AuditoryForaging.update_belief(self, previous_belief, action, observation)
#     324 """
#     325 Updating belief, given previous belief, new observation, and past action.
#     326 """
#     328 lick_choice, attention_choice = self.dict_action_possible[int(action)]
# --> 330 transition_matrix = self.find_transition_matrix()
#     331 observation_matrix = self.find_observation_matrix()
#     332 new_belief = np.zeros(self.no_nodes)
#
# File ~/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/template_code/auditoryforage/AF_env.py:384, in AuditoryForaging.find_transition_matrix(self)
#     376 # Lokesh changed this to make ITI 1
#     377 # #for episodic
#     378 # # for i in range(1,self.no_signal_nodes+1):
#    (...)
#     381 #     for j in range(self.no_signal_nodes + self.no_penalty_nodes + 1, self.no_signal_nodes + self.no_penalty_nodes + 1 + int(self.no_ITI_nodes/3)):
#     382 #         transition_matrix[(i, j, 1)] = 1/(self.no_ITI_nodes/3)
#     383 for i in range(1,self.no_signal_nodes+1):
# --> 384     transition_matrix[(i, self.no_signal_nodes + self.no_penalty_nodes + 1, 1)] = 1
#     386 for i in range(self.no_signal_nodes+1,self.no_nodes-1):
#     387     transition_matrix[(i,i+1,1)] = 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Run the agent in an environment
# We create another environment which has the same observation space and action space as the assumed one, albeit with a different set of environment parameters.

# %%
from auditoryforage.AF_env import AuditoryForaging
from auditoryforage.utils import plot_AF_episode

# Change below line if you want to try the trained model on a different set of environemnt.
# env_param = [-3.0, 8.0, 13, 8, -8, -4]

env = AuditoryForaging(spec={'agent':{'lick_cost':env_param[0],'food_reward':env_param[1],'attention_cost_coeff':env_param[2], 'attention_cost_temp': env_param[3], 'penalty_cost': env_param[4], 'iti_cost': env_param[5]}})
episode = agent.run_one_episode(env=env, num_steps=10000, q_states = [[i] for i in range(env.no_nodes)])
fig = plot_AF_episode(episode, env, agent, nodes_from_zero = 40, time_steps_before_lick = 20)

env.spec
# Out:
# problem somwhere here
# [[3]
#  [0]
#  [0]
#  ...
#  [0]
#  [0]
#  [2]]
# (array([3680]), array([0]))
# problem somwhere here
# [[3]
#  [0]
#  [0]
#  ...
#  [1]
#  [0]
#  [2]]
# (array([3680]), array([0]))
# average success streak is 10.705882352941176
# average success rate is 0.0055119696274290655
# average episode time is 2527.1176470588234
# {'agent': {'lick_cost': 0,
#   'food_reward': 50000.0,
#   'attention_cost_coeff': 0.08,
#   'attention_cost_temp': 0.25,
#   'penalty_cost': -5000,
#   'iti_cost': 0,
#   'no_attention_modes': 2},
#  'experiment': {'prob_01': 0.004,
#   'no_signal_nodes': 150,
#   'no_penalty_nodes': 1,
#   'no_ITI_nodes': 1}}

# %%
# from auditoryforage.utils import save_pickle_file
# file_name = './auditoryforage/filters/ref_episode_13_5.pkl'
# save_pickle_file(episode, file_name)

# %% [markdown]
# ### Jump start

# %%
from auditoryforage.utils import open_pickle_file, save_pickle_file
file_name = './auditoryforage/filters/ref_episode_0.08_0.25.pkl'
# save_pickle_file(episode, file_name)
episode = open_pickle_file(file_name)

import os
import sys
sys.path.append(f'{os.getcwd()}/irc_gym')
from irc.manager import IRCManager
defaults = {
    'agent.env._target_': 'auditoryforage.AF_env.AuditoryForaging',
    'agent.model._target_': 'irc.model.FuncBeliefModel',
}
manager = IRCManager(defaults=defaults)
from auditoryforage.AF_env import AuditoryForaging
env_param = [-3.0, 200.0, .08, .25, -5000, 0]
env = AuditoryForaging(spec={'agent':{'lick_cost':env_param[0],'food_reward':env_param[1],'attention_cost_coeff':env_param[2], 'attention_cost_temp': env_param[3], 'penalty_cost': env_param[4], 'iti_cost': env_param[5]}})

# %% [markdown]
# # Load multiple agents

# %%
env_param_list = []
# env_param_list.append([-3.0, 200.0, .08, .25, -5000, 0])
# env_param_list.append([-3.0, 200.0, .08, .25, -5000, 0])

env_param_list.append([-3.0, 200.0, 13, 5, -5000, 0])
env_param_list.append([-3.0, 200.0, .06, .25, -5000, 0])
env_param_list.append([-3.0, 200.0, .08, .25, -5000, 0])

num_epochs = 400
num_epochs_list = [num_epochs] * len(env_param_list)

agent_list = []
for ind in range(len(env_param_list)):
    agent_list.append(manager.train_agent(env_param_list[ind], num_epochs=num_epochs_list[ind]))

# %% [markdown]
# # Particle filter

# %% [markdown]
# ## Running Particle filter

# %% [markdown]
# ### Latent  variable - only attention

# %%
from auditoryforage.filters.PF_attention import ParticleFilter
end_index = 2
no_particles_list = [10000]
sampling_freq_list = [1]
particle_filter = ParticleFilter(agent, env)
particle_filter.multiple_filtering(episode, no_particles_list, sampling_freq_list, end_index, req_output_posterior = True)

# %% [markdown]
# ### Latent  variable - attention, and observation

# %%
from auditoryforage.filters.PF_att_obs import ParticleFilter
end_index = 2
no_particles_list = [10000]
sampling_freq_list = [1]
particle_filter = ParticleFilter(agent, env)
particle_filter.multiple_filtering(episode, no_particles_list, sampling_freq_list, end_index, req_output_posterior = True)

# %% [markdown]
# ### Latent  variable - attention, and agents

# %%
from auditoryforage.filters.PF_att_agent import ParticleFilter
end_index = 2
no_particles_list = [1000]
sampling_freq_list = [1]
true_params_folder_name = ''
particle_filter = ParticleFilter(agent_list, env_param_list, env, true_params_folder_name)
particle_filter.multiple_filtering(episode, no_particles_list, sampling_freq_list, end_index, req_output_posterior = True)

# %% [markdown]
# ### Latent  variable - agents

# %%
from auditoryforage.filters.PF_agent import ParticleFilter
end_index = 2
no_particles_list = [1000]
sampling_freq_list = [1]
true_params_folder_name = ''
particle_filter = ParticleFilter(agent_list, env_param_list, env, true_params_folder_name)
particle_filter.multiple_filtering(episode, no_particles_list, sampling_freq_list, end_index, req_output_posterior = True)

# %% [markdown]
# ## Particle filter generated episode

# %% [markdown]
# ### Latent  variable - only attention

# %%
PF_file = 'PF_np_10000_sf_1_ei_2_rn_35.pkl'

from auditoryforage.filters.PF_attention import ParticleFilter
PF_folder = 'store/filters/PF_attention/'
PF_file_name = PF_folder + PF_file
likelihood_rank = 0
particle_filter = ParticleFilter(agent, env)
particle_filter.plot_generated_episode(file_name = PF_file_name, likelihood_rank = likelihood_rank)

# %% [markdown]
# ## Analyzing particle filter output.

# %% [markdown]
# ### Latent  variable - only attention

# %%
PF_file = 'PF_np_10000_sf_1_ei_2_rn_35.pkl'

from auditoryforage.filters.PF_attention import PF_results_analyzer
PF_folder = 'store/filters/PF_attention/'
PF_file_name = PF_folder + PF_file
likelihood_rank = 0
PF_results_analyzer(PF_file_name, likelihood_rank).analyze_results()

# %% [markdown]
# ### Latent  variable - attention, and observation

# %%
PF_file = 'PF_np_10000_sf_1_ei_2_rn_8.pkl'

from auditoryforage.filters.PF_att_obs import PF_results_analyzer
PF_folder = 'store/filters/PF_att_obs/'
PF_file_name = PF_folder + PF_file
likelihood_rank = 0
PF_results_analyzer(PF_file_name, likelihood_rank).analyze_results()

# %% [markdown]
# ### Latent  variable - attention, and agents

# %%
# PF_file = 'PF_np_30000_sf_1_ei_100_rn_24.pkl'
PF_file = 'PF_np_100_sf_1_ei_1000_rn_63.pkl'
true_params_folder_name = ''

from auditoryforage.filters.PF_att_agent import PF_results_analyzer
PF_folder = 'store/filters/PF_att_agent/' + true_params_folder_name
PF_file_name = PF_folder + PF_file
likelihood_rank = 0
PF_results_analyzer(PF_file_name, likelihood_rank).analyze_results()

# %% [markdown]
# ### Latent  variable - agents

# %%
# env_param_list.append([-3.0, 200.0, 13, 5, -5000, 0])
# env_param_list.append([-3.0, 200.0, .06, .25, -5000, 0])
# env_param_list.append([-3.0, 200.0, .08, .25, -5000, 0])

# true_params_folder_name = '0-13_5/'
# PF_file = 'PF_np_30000_sf_1_ei_3080_rn_97.pkl'

# true_params_folder_name = '1-0.06_0.25/'
# PF_file = 'PF_np_30000_sf_1_ei_846_rn_66.pkl'

true_params_folder_name = '2-0.08_0.25/'
# PF_file = 'PF_np_30000_sf_1_ei_100_rn_24.pkl'
# PF_file = 'PF_np_100_sf_1_ei_1000_rn_63.pkl'
# PF_file = 'PF_np_1000_sf_1_ei_1000_rn_82.pkl'
# PF_file = 'PF_np_10000_sf_1_ei_1000_rn_92.pkl'
PF_file = 'PF_np_30000_sf_1_ei_2000_rn_39.pkl'

from auditoryforage.filters.PF_agent import PF_results_analyzer
PF_folder = 'store/filters/PF_agent/' + true_params_folder_name
PF_file_name = PF_folder + PF_file
likelihood_rank = 0
PF_results_analyzer(PF_file_name, likelihood_rank).analyze_results()
# Out:
# No sampling repetition was needed. Good stuff!

# %% [markdown]
# ## Running HMM.

# %% [markdown]
# ### Latent  variable - only attention

# %%
from auditoryforage.filters.HMM_attention import HMM
end_index = 2
HMM_IO = HMM(agent, env, episode, end_index).compute_posterior_across_attention_series()

# %% [markdown]
# ### Latent  variable - attention, and observation

# %%
from auditoryforage.filters.HMM_att_obs import HMM
end_index = 2
HMM_IO = HMM(agent, env, episode, end_index).compute_posterior_across_attention_obs_series()

# %% [markdown]
# ## Comparing particle filter and HMM outputs.

# %% [markdown]
# ### Latent  variable - only attention

# %%
PF_file = 'PF_np_100000_sf_1_ei_5_rn_66.pkl'
HMM_file = 'HMM_ei_5_rn_44.pkl'

from auditoryforage.filters.HMM_attention import compare_PF_HMM
PF_folder = 'store/filters/PF_attention/'
HMM_folder = 'store/filters/HMM_attention/'
PF_file_name = PF_folder + PF_file
HMM_file_name = HMM_folder + HMM_file
compare_PF_HMM(PF_file_name = PF_file_name, HMM_file_name = HMM_file_name)

# %% [markdown]
# ### Latent  variable - attention, and observation

# %%
PF_file = 'PF_np_10000_sf_1_ei_2_rn_8.pkl'
HMM_file = 'HMM_ei_2_rn_98.pkl'

from auditoryforage.filters.HMM_att_obs import compare_PF_HMM
PF_folder = 'store/filters/PF_att_obs/'
HMM_folder = 'store/filters/HMM_att_obs/'
PF_file_name = PF_folder + PF_file
HMM_file_name = HMM_folder + HMM_file
compare_PF_HMM(PF_file_name = PF_file_name, HMM_file_name = HMM_file_name)

# %% [markdown]
# ## Verifying if saved files makes sense

# %%
from auditoryforage.utils import open_pickle_file, save_pickle_file

# %% [markdown]
# ### Latent  variable - only attention

# %% [markdown]
# #### PF

# %%
PF_file = 'PF_np_100000_sf_1_ei_5_rn_66.pkl'
PF_folder = 'store/filters/PF_attention/'
PF_file_name = PF_folder + PF_file
PF_IO = open_pickle_file(PF_file_name)

# %% [markdown]
# #### HMM

# %%
HMM_file = 'HMM_ei_5_rn_44.pkl'
HMM_folder = 'store/filters/HMM_attention/'
HMM_file_name = HMM_folder + HMM_file
HMM_IO = open_pickle_file(PF_file_name)

# %% [markdown]
# ### Latent  variable - attention, and observation

# %% [markdown]
# #### PF

# %%
PF_file = 'PF_np_10000_sf_1_ei_2_rn_8.pkl'
PF_folder = 'store/filters/PF_att_obs/'
PF_file_name = PF_folder + PF_file
PF_IO = open_pickle_file(PF_file_name)

# %% [markdown]
# #### HMM

# %%
HMM_file = 'HMM_ei_2_rn_98.pkl'
HMM_folder = 'store/filters/HMM_att_obs/'
HMM_file_name = HMM_folder + HMM_file
HMM_IO = open_pickle_file(PF_file_name)

# %% [markdown]
# ### Latent  variable - attention, and agents

# %% [markdown]
# #### PF

# %%
PF_file = 'PF_np_30000_sf_1_ei_100_rn_24.pkl'
PF_folder = 'store/filters/PF_att_agent/'
PF_file_name = PF_folder + PF_file
PF_IO = open_pickle_file(PF_file_name)

# %%
PF_IO['output']['sorted_results']['agent']['agent_ranked']

# %% [markdown]
# ### Latent  variable - agents

# %%
# PF_file = 'PF_np_30000_sf_1_ei_2205_rn_36.pkl'
# true_params_folder_name = '/high_en_2_tn_0_fr_350_ac_0.08_0.25/'

# PF_file = 'PF_np_30000_sf_1_ei_5315_rn_97.pkl'
# true_params_folder_name = '/low_en_2_tn_2_fr_50_ac_0.08_0.25/'

# PF_file = 'PF_np_30000_sf_1_ei_2205_rn_36.pkl'
# true_params_folder_name = '/high_en_2_tn_0_fr_100_ac_0.08_0.25/'

PF_folder = 'store/filters/PF_agent/' + true_params_folder_name
PF_file_name = PF_folder + PF_file
PF_IO = open_pickle_file(PF_file_name)
print(PF_IO['output']['sorted_results']['agent'])

# %% [markdown]
# ## Summary results for a mice

# %%
import os
results = []
main_dir = './store/filters/PF_agent/high_fr_350.0_ac_0.08_0.25'
for folder_name in os.listdir(main_dir):
    for file_name in os.listdir(main_dir + '/' + folder_name):
        results.append(open_pickle_file(main_dir + '/' + folder_name + '/' + file_name)['output']['sorted_results']['agent'])

# %% [markdown]
# ## Deciding good att cost temp

# %%
y = x1 * (np.exp(a/x2) - 1)
x2 = 1
x1 = y/(np.exp(a) - 1)

# %%
import numpy as np
.08 * (np.exp(.9/.25) - 1)
# Out:
# 2.847858755494239

# %%
(np.exp(.9) - 1)
# Out:
# 1.4596031111569499

# %%
0.6851177504050078 * (np.exp(.9) - 1)
# Out:
# 1.0

# %%
0.3425588752025039 * (np.exp(.9) - 1)
# Out:
# 0.5

# %%
0.06851177504050078 * (np.exp(.9) - 1)
# Out:
# 0.1

# %%
0.006851177504050078 * (np.exp(.9) - 1)
# Out:
# 0.01

# %%
y = x1 * (np.exp(a/x2) - 1)
x2 = 1
x1 = y/(np.exp(a) - 1)

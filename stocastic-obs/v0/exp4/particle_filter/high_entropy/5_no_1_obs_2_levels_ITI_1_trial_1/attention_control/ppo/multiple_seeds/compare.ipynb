# %%
import matplotlib.pyplot as plt

low_food_reward_list = [0, 5.0, 10.0, 15.0, 20.0, 25.0, 50.0, 75.0, 100.0]
low_max_hit_count_list = [0.0, 0.447, 0.632, 0.603, 0.776, 0.812, 0.801, 0.794, 0.778]
low_max_miss_count_list = [0.007, 0.007, 0.036, 0.042, 0.071, 0.06, 0.088, 0.054, 0.092]
low_max_false_alarm_list = [0.993, 0.546, 0.332, 0.355, 0.153, 0.128, 0.111, 0.152, 0.13]

med_food_reward_list = [0, 5.0, 10.0, 15.0, 20.0, 25.0, 50.0, 75.0, 100.0]
med_max_hit_count_list = [0.0, 0.418, 0.443, 0.511, 0.484, 0.483, 0.781, 0.801, 0.795]
med_max_miss_count_list = [0.001, 0.001, 0.012, 0.198, 0.016, 0.011, 0.059, 0.037, 0.08]
med_max_false_alarm_list = [0.999, 0.581, 0.545, 0.291, 0.5, 0.506, 0.16, 0.162, 0.125]

high_food_reward_list = [0, 5.0, 10.0, 15.0, 20.0, 25.0, 50.0, 75.0, 100.0]
high_max_hit_count_list = [0.0, 0.403, 0.435, 0.797, 0.424, 0.442, 0.489, 0.77, 0.758]
high_max_miss_count_list = [0.061, 0.135, 0.0, 0.041, 0.026, 0.003, 0.003, 0.044, 0.087]
high_max_false_alarm_list = [0.939, 0.462, 0.565, 0.162, 0.55, 0.555, 0.508, 0.186, 0.155]


plt.plot(low_food_reward_list, low_max_hit_count_list, 'bo-')
plt.plot(med_food_reward_list, med_max_hit_count_list, 'bo--')
plt.plot(high_food_reward_list, high_max_hit_count_list, 'b*-.')
plt.plot(low_food_reward_list, low_max_miss_count_list, 'go-')
plt.plot(med_food_reward_list, med_max_miss_count_list, 'go--')
plt.plot(high_food_reward_list, high_max_miss_count_list, 'g*-.')
plt.plot(low_food_reward_list, low_max_false_alarm_list, 'ro-')
plt.plot(med_food_reward_list, med_max_false_alarm_list, 'ro--')
plt.plot(high_food_reward_list, high_max_false_alarm_list, 'r*-.')
plt.xlabel('food_reward_list')
plt.legend(['low hit', 'medium hit', 'high hit', 'low miss', 'medium miss', 'high miss', 'low false alarm', 'medium false alarm', 'high false alarm'])
plt.title('low att cost Vs high att cost')
plt.show()

# %%
plt.plot(low_food_reward_list, low_max_hit_count_list, 'bo-')
plt.plot(med_food_reward_list, med_max_hit_count_list, 'bo--')
plt.plot(low_food_reward_list, low_max_miss_count_list, 'go-')
plt.plot(med_food_reward_list, med_max_miss_count_list, 'go--')
plt.plot(low_food_reward_list, low_max_false_alarm_list, 'ro-')
plt.plot(med_food_reward_list, med_max_false_alarm_list, 'ro--')
plt.xlabel('food_reward_list')
plt.legend(['low hit', 'med hit', 'med miss', 'high miss', 'low false alarm', 'med false alarm'])
plt.title('low att cost Vs high att cost')
plt.show()

# %%
plt.plot(med_food_reward_list, med_max_hit_count_list, 'bo-')
plt.plot(high_food_reward_list, high_max_hit_count_list, 'b*-.')

plt.plot(med_food_reward_list, med_max_miss_count_list, 'go-')
plt.plot(high_food_reward_list, high_max_miss_count_list, 'g*-.')

plt.plot(med_food_reward_list, med_max_false_alarm_list, 'ro-')
plt.plot(high_food_reward_list, high_max_false_alarm_list, 'r*-.')
plt.xlabel('food_reward_list')
plt.legend([ 'medium hit', 'high hit',  'medium miss', 'high miss',  'medium false alarm', 'high false alarm'])
plt.title('low att cost Vs high att cost')
plt.show()

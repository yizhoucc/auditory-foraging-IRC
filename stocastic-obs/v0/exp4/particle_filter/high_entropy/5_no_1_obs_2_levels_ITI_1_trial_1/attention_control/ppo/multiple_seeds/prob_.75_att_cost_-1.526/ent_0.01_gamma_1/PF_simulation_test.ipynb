# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import numpy as np
from auditoryforage.utils import save_pickle_file, open_pickle_file

folder_name = './store/filters/'
file_name = folder_name + 'PF_likelihood_repo.pkl'

if os.path.exists(file_name):
    PF_likelihood_repo = open_pickle_file(file_name)
else:
    print('Have not run previous cell yet.')

total_posterior = [0] * len(PF_likelihood_repo.keys())
for key in PF_likelihood_repo:
    _, correct_env_index = key
    PF_posterior_full_array = np.array(PF_likelihood_repo[key])
    plt.figure()
    plt.errorbar(np.arange(len(PF_likelihood_repo.keys())), np.mean(PF_posterior_full_array, axis=0), yerr=np.std(PF_posterior_full_array, axis=0), fmt='o', markersize=6, capsize=4)
    plt.xlabel('environment index')
    plt.ylabel('normalized count')
    plt.title(f'Correct index is {correct_env_index}')
    plt.xticks(np.arange(len(PF_likelihood_repo.keys())))  # Set x-axis labels to column indices
    plt.grid()
    plt.show()
# Out:
# Have not run previous cell yet.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/ppo/multiple_seeds/prob_.75_att_cost_-1.526/ent_0.01_gamma_1/PF_simulation_test.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/ppo/multiple_seeds/prob_.75_att_cost_-1.526/ent_0.01_gamma_1/PF_simulation_test.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> else:
#      <a href='vscode-notebook-cell:/Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/ppo/multiple_seeds/prob_.75_att_cost_-1.526/ent_0.01_gamma_1/PF_simulation_test.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a>     print('Have not run previous cell yet.')
# ---> <a href='vscode-notebook-cell:/Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/ppo/multiple_seeds/prob_.75_att_cost_-1.526/ent_0.01_gamma_1/PF_simulation_test.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> total_posterior = [0] * len(PF_likelihood_repo.keys())
#      <a href='vscode-notebook-cell:/Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/ppo/multiple_seeds/prob_.75_att_cost_-1.526/ent_0.01_gamma_1/PF_simulation_test.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> for key in PF_likelihood_repo:
#      <a href='vscode-notebook-cell:/Users/lokeshboominathan/Documents/code/auditory-foraging-IRC/stocastic-obs/v0/exp4/particle_filter/high_entropy/5_no_1_obs_2_levels_ITI_1_trial_1/attention_control/ppo/multiple_seeds/prob_.75_att_cost_-1.526/ent_0.01_gamma_1/PF_simulation_test.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a>     _, correct_env_index = key
#
# NameError: name 'PF_likelihood_repo' is not defined

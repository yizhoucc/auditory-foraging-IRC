# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 15, 'lines.linewidth': 2,
    'xtick.labelsize': 13, 'ytick.labelsize': 13,
    'axes.spines.top': False, 'axes.spines.right': False,
    'savefig.dpi': 1200,
})

import yaml
import numpy as np

import os
import sys
sys.path.append(f'{os.getcwd()}/irc_gym')

from irc.manager import IRCManager

from auditoryforage.utils import plot_AF_episode

# %% [markdown]
# # Train one agent for a single environment

# %%
defaults = {
    'agent.env._target_': 'auditoryforage.AF_env.AuditoryForaging',
    'agent.model._target_': 'irc.model.FuncBeliefModel',
}
manager = IRCManager(defaults=defaults)

# %% [markdown]
# ## Train an agent
# We train a rational agent for the assume environment parameter [$lick\_cost, food\_reward, attention\_cost\_coeff, attention\_cost\_temp, penalty\_cost, iti\_cost$].

# %%
env_param = [-3.0, 10000.0, 25, 10, -10000, 0]
num_epochs = 100

agent = manager.train_agent(env_param, num_epochs=num_epochs)
agent, fig = manager.inspect_agent(env_param, figsize=(5, 2.5))
# Out:
# No checkpoint loaded.
# Initializing an agent with internal environment parameter:
# (-3.0, 10000.0, 25, 10, -10000, 0)
# Agent evaluated for 12 episodes of length 100000. Average return -10162.17. (0m10.27s)
#
# Epoch:   1/100
# Agent trained by 10000 time steps (1m10.42s).
#
# Epoch:   2/100
# Agent trained by 10000 time steps (0m59.74s).
# Agent evaluated for 12 episodes of length 100000. Average return -10159.59. (0m08.19s)
#
# Epoch:   3/100
# Agent trained by 10000 time steps (1m00.21s).
#
# Epoch:   4/100
# Agent trained by 10000 time steps (0m59.59s).
# Agent evaluated for 12 episodes of length 100000. Average return -10161.26. (0m07.98s)
#
# Epoch:   5/100
# Agent trained by 10000 time steps (0m57.91s).
#
# Epoch:   6/100
# Agent trained by 10000 time steps (0m56.77s).
# Agent evaluated for 12 episodes of length 100000. Average return -10150.32. (0m07.34s)
#
# Epoch:   7/100
# Agent trained by 10000 time steps (0m59.73s).
#
# Epoch:   8/100
# Agent trained by 10000 time steps (0m59.97s).
# Agent evaluated for 12 episodes of length 100000. Average return -10154.81. (0m07.20s)
#
# Epoch:   9/100
# Agent trained by 10000 time steps (1m00.22s).
#
# Epoch:  10/100
# Agent trained by 10000 time steps (0m58.21s).
# Agent evaluated for 12 episodes of length 100000. Average return -10157.91. (0m07.55s)
#
# Epoch:  11/100
# Agent trained by 10000 time steps (0m58.57s).
#
# Epoch:  12/100
# Agent trained by 10000 time steps (0m58.88s).
# Agent evaluated for 12 episodes of length 100000. Average return -10157.99. (0m08.27s)
#
# Epoch:  13/100
# Agent trained by 10000 time steps (0m57.55s).
#
# Epoch:  14/100
# Agent trained by 10000 time steps (0m58.14s).
# Agent evaluated for 12 episodes of length 100000. Average return -10152.39. (0m07.46s)
#
# Epoch:  15/100
# Agent trained by 10000 time steps (0m59.85s).
#
# Epoch:  16/100
# Agent trained by 10000 time steps (0m57.61s).
# Agent evaluated for 12 episodes of length 100000. Average return -10164.33. (0m07.57s)
#
# Epoch:  17/100
# Agent trained by 10000 time steps (0m57.08s).
#
# Epoch:  18/100
# Agent trained by 10000 time steps (0m57.43s).
# Agent evaluated for 12 episodes of length 100000. Average return -10158.43. (0m07.22s)
#
# Epoch:  19/100
# Agent trained by 10000 time steps (0m56.81s).
#
# Epoch:  20/100
# Agent trained by 10000 time steps (0m57.09s).
# Agent evaluated for 12 episodes of length 100000. Average return -10150.25. (0m07.64s)
#
# Epoch:  21/100
# Agent trained by 10000 time steps (1m00.28s).
#
# Epoch:  22/100
# Agent trained by 10000 time steps (0m59.09s).
# Agent evaluated for 12 episodes of length 100000. Average return -10159.83. (0m08.00s)
#
# Epoch:  23/100
# Agent trained by 10000 time steps (0m59.99s).
#
# Epoch:  24/100
# Agent trained by 10000 time steps (0m56.59s).
# Agent evaluated for 12 episodes of length 100000. Average return -10153.52. (0m07.54s)
#
# Epoch:  25/100
# Agent trained by 10000 time steps (0m59.49s).
#
# Epoch:  26/100
# Agent trained by 10000 time steps (1m00.27s).
# Agent evaluated for 12 episodes of length 100000. Average return -10155.64. (0m08.04s)
#
# Epoch:  27/100
# Agent trained by 10000 time steps (0m59.35s).
#
# Epoch:  28/100
# Agent trained by 10000 time steps (0m58.16s).
# Agent evaluated for 12 episodes of length 100000. Average return -10147.58. (0m07.71s)
#
# Epoch:  29/100
# Agent trained by 10000 time steps (0m59.50s).
#
# Epoch:  30/100
# Agent trained by 10000 time steps (0m59.22s).
# Agent evaluated for 12 episodes of length 100000. Average return -10146.47. (0m07.47s)
#
# Epoch:  31/100
# Agent trained by 10000 time steps (0m57.95s).
#
# Epoch:  32/100
# Agent trained by 10000 time steps (0m57.71s).
# Agent evaluated for 12 episodes of length 100000. Average return -9899.32. (0m07.91s)
#
# Epoch:  33/100
# Agent trained by 10000 time steps (0m59.43s).
#
# Epoch:  34/100
# Agent trained by 10000 time steps (0m59.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -10162.62. (0m08.15s)
#
# Epoch:  35/100
# Agent trained by 10000 time steps (0m56.92s).
#
# Epoch:  36/100
# Agent trained by 10000 time steps (0m56.79s).
# Agent evaluated for 12 episodes of length 100000. Average return -10156.55. (0m07.90s)
#
# Epoch:  37/100
# Agent trained by 10000 time steps (0m56.96s).
#
# Epoch:  38/100
# Agent trained by 10000 time steps (0m59.45s).
# Agent evaluated for 12 episodes of length 100000. Average return -10153.94. (0m07.87s)
#
# Epoch:  39/100
# Agent trained by 10000 time steps (0m58.46s).
#
# Epoch:  40/100
# Agent trained by 10000 time steps (0m57.49s).
# Agent evaluated for 12 episodes of length 100000. Average return -10153.49. (0m07.35s)
#
# Epoch:  41/100
# Agent trained by 10000 time steps (0m56.24s).
#
# Epoch:  42/100
# Agent trained by 10000 time steps (0m57.65s).
# Agent evaluated for 12 episodes of length 100000. Average return -10154.80. (0m07.92s)
#
# Epoch:  43/100
# Agent trained by 10000 time steps (0m58.10s).
#
# Epoch:  44/100
# Agent trained by 10000 time steps (0m58.83s).
# Agent evaluated for 12 episodes of length 100000. Average return -10161.48. (0m07.69s)
#
# Epoch:  45/100
# Agent trained by 10000 time steps (0m57.88s).
#
# Epoch:  46/100
# Agent trained by 10000 time steps (0m57.28s).
# Agent evaluated for 12 episodes of length 100000. Average return -10154.41. (0m07.67s)
#
# Epoch:  47/100
# Agent trained by 10000 time steps (0m57.02s).
#
# Epoch:  48/100
# Agent trained by 10000 time steps (0m56.75s).
# Agent evaluated for 12 episodes of length 100000. Average return -10150.88. (0m07.20s)
#
# Epoch:  49/100
# Agent trained by 10000 time steps (0m57.98s).
#
# Epoch:  50/100
# Agent trained by 10000 time steps (0m57.26s).
# Agent evaluated for 12 episodes of length 100000. Average return -10157.89. (0m07.47s)
#
# Epoch:  51/100
# Agent trained by 10000 time steps (0m58.93s).
#
# Epoch:  52/100
# Agent trained by 10000 time steps (0m58.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -10154.80. (0m07.80s)
#
# Epoch:  53/100
# Agent trained by 10000 time steps (0m57.45s).
#
# Epoch:  54/100
# Agent trained by 10000 time steps (0m58.58s).
# Agent evaluated for 12 episodes of length 100000. Average return -10142.70. (0m07.30s)
#
# Epoch:  55/100
# Agent trained by 10000 time steps (0m58.81s).
#
# Epoch:  56/100
# Agent trained by 10000 time steps (0m57.85s).
# Agent evaluated for 12 episodes of length 100000. Average return -10149.86. (0m07.82s)
#
# Epoch:  57/100
# Agent trained by 10000 time steps (0m59.11s).
#
# Epoch:  58/100
# Agent trained by 10000 time steps (0m56.66s).
# Agent evaluated for 12 episodes of length 100000. Average return -10150.99. (0m07.63s)
#
# Epoch:  59/100
# Agent trained by 10000 time steps (0m59.33s).
#
# Epoch:  60/100
# Agent trained by 10000 time steps (0m58.11s).
# Agent evaluated for 12 episodes of length 100000. Average return -10155.86. (0m08.01s)
#
# Epoch:  61/100
# Agent trained by 10000 time steps (1m00.87s).
#
# Epoch:  62/100
# Agent trained by 10000 time steps (0m57.75s).
# Agent evaluated for 12 episodes of length 100000. Average return -10153.97. (0m08.15s)
#
# Epoch:  63/100
# Agent trained by 10000 time steps (0m57.69s).
#
# Epoch:  64/100
# Agent trained by 10000 time steps (0m58.35s).
# Agent evaluated for 12 episodes of length 100000. Average return -10153.21. (0m07.46s)
#
# Epoch:  65/100
# Agent trained by 10000 time steps (0m57.22s).
#
# Epoch:  66/100
# Agent trained by 10000 time steps (0m57.67s).
# Agent evaluated for 12 episodes of length 100000. Average return -10157.24. (0m08.34s)
#
# Epoch:  67/100
# Agent trained by 10000 time steps (0m58.62s).
#
# Epoch:  68/100
# Agent trained by 10000 time steps (0m57.48s).
# Agent evaluated for 12 episodes of length 100000. Average return -10147.41. (0m07.25s)
#
# Epoch:  69/100
# Agent trained by 10000 time steps (0m59.08s).
#
# Epoch:  70/100
# Agent trained by 10000 time steps (0m58.05s).
# Agent evaluated for 12 episodes of length 100000. Average return -10152.37. (0m07.41s)
#
# Epoch:  71/100
# Agent trained by 10000 time steps (0m57.41s).
#
# Epoch:  72/100
# Agent trained by 10000 time steps (0m56.92s).
# Agent evaluated for 12 episodes of length 100000. Average return -10150.83. (0m07.53s)
#
# Epoch:  73/100
# Agent trained by 10000 time steps (0m57.95s).
#
# Epoch:  74/100
# Agent trained by 10000 time steps (1m00.79s).
# Agent evaluated for 12 episodes of length 100000. Average return -10145.35. (0m06.82s)
#
# Epoch:  75/100
# Agent trained by 10000 time steps (0m58.86s).
#
# Epoch:  76/100
# Agent trained by 10000 time steps (0m56.79s).
# Agent evaluated for 12 episodes of length 100000. Average return -10148.91. (0m07.39s)
#
# Epoch:  77/100
# Agent trained by 10000 time steps (0m58.77s).
#
# Epoch:  78/100
# Agent trained by 10000 time steps (0m58.07s).
# Agent evaluated for 12 episodes of length 100000. Average return -10148.80. (0m08.06s)
#
# Epoch:  79/100
# Agent trained by 10000 time steps (0m58.47s).
#
# Epoch:  80/100
# Agent trained by 10000 time steps (0m57.89s).
# Agent evaluated for 12 episodes of length 100000. Average return -10146.87. (0m07.45s)
#
# Epoch:  81/100
# Agent trained by 10000 time steps (0m57.88s).
#
# Epoch:  82/100
# Agent trained by 10000 time steps (0m57.98s).
# Agent evaluated for 12 episodes of length 100000. Average return -10150.49. (0m07.71s)
#
# Epoch:  83/100
# Agent trained by 10000 time steps (0m59.68s).
#
# Epoch:  84/100
# Agent trained by 10000 time steps (0m59.24s).
# Agent evaluated for 12 episodes of length 100000. Average return -10148.68. (0m07.23s)
#
# Epoch:  85/100
# Agent trained by 10000 time steps (0m58.11s).
#
# Epoch:  86/100
# Agent trained by 10000 time steps (0m56.43s).
# Agent evaluated for 12 episodes of length 100000. Average return -10140.68. (0m07.58s)
#
# Epoch:  87/100
# Agent trained by 10000 time steps (1m00.71s).
#
# Epoch:  88/100
# Agent trained by 10000 time steps (0m59.15s).
# Agent evaluated for 12 episodes of length 100000. Average return -10153.53. (0m07.18s)
#
# Epoch:  89/100
# Agent trained by 10000 time steps (0m58.30s).
#
# Epoch:  90/100
# Agent trained by 10000 time steps (0m57.84s).
# Agent evaluated for 12 episodes of length 100000. Average return -10152.74. (0m07.96s)
#
# Epoch:  91/100
# Agent trained by 10000 time steps (0m59.98s).
#
# Epoch:  92/100
# Agent trained by 10000 time steps (0m59.36s).
# Agent evaluated for 12 episodes of length 100000. Average return -10148.86. (0m08.19s)
#
# Epoch:  93/100
# Agent trained by 10000 time steps (0m58.12s).
#
# Epoch:  94/100
# Agent trained by 10000 time steps (0m57.69s).
# Agent evaluated for 12 episodes of length 100000. Average return -10146.30. (0m07.72s)
#
# Epoch:  95/100
# Agent trained by 10000 time steps (0m56.94s).
#
# Epoch:  96/100
# Agent trained by 10000 time steps (0m58.26s).
# Agent evaluated for 12 episodes of length 100000. Average return -10144.45. (0m07.48s)
#
# Epoch:  97/100
# Agent trained by 10000 time steps (0m58.46s).
#
# Epoch:  98/100
# Agent trained by 10000 time steps (0m56.15s).
# Agent evaluated for 12 episodes of length 100000. Average return -10151.20. (0m07.66s)
#
# Epoch:  99/100
# Agent trained by 10000 time steps (0m56.79s).
#
# Epoch: 100/100
# Agent trained by 10000 time steps (0m58.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -10142.92. (0m07.50s)
# Fetching the most trained agent so far (epoch 100).
# Agent (seed 0) was trained for 100 epochs.

# %% [markdown]
# ## Run the agent in an environment
# We create another environment which has the same observation space and action space as the assumed one, albeit with a different set of environment parameters.

# %%
from auditoryforage.AF_env import AuditoryForaging

# Change below line if you want to try the trained model on a different set of environemnt.
# env_param = [-3.0, 8.0, 13, 8, -8, -4]

env = AuditoryForaging(spec={'agent':{'lick_cost':env_param[0],'food_reward':env_param[1],'attention_cost_coeff':env_param[2], 'attention_cost_temp': env_param[3], 'penalty_cost': env_param[4], 'iti_cost': env_param[5]}})
episode = agent.run_one_episode(env=env, num_steps=1000, q_states = [[i] for i in range(env.no_nodes)])
fig = plot_AF_episode(episode, env)

env.spec
# Out:
# {'agent': {'lick_cost': -3.0,
#   'food_reward': 10000.0,
#   'attention_cost_coeff': 25,
#   'attention_cost_temp': 10,
#   'penalty_cost': -10000,
#   'iti_cost': 0,
#   'no_attention_modes': 6},
#  'experiment': {'prob_01': 0.004,
#   'no_signal_nodes': 150,
#   'no_penalty_nodes': 1,
#   'no_ITI_nodes': 150}}

# %%
plt.imshow(np.log(episode['q_probs'].T[:100,:]))
plt.colorbar()
plt.show()
# print(episode['rewards'])

plt.imshow(episode['q_probs'].T[152:300,:])
plt.show()
plt.stem(episode['states'])
plt.show()
# Out:
# /tmp/ipykernel_2198827/3647817924.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(episode['q_probs'].T[:100,:]))

# %% [markdown]
# We can save the episode data in an external `pickle` file.

# %%
import os, pickle

episode_path = f'store/episode_{env.get_param()}.pickle'

if os.path.exists(episode_path):
    print(f"File {episode_path} already exists, will not be overwritten.")
else:
    with open(episode_path, 'wb') as f:
        pickle.dump({
            'external_env_param': env.get_param(),
            'internal_env_param': agent.model.env.get_param(),
            **episode,
        }, f)
    print(f"Episode data saved at '{episode_path}'.")

# %% [markdown]
# # Train multiple agents for different environments

# %% [markdown]
# ## Sweep over parameter grid
#
# We define a grid of environment parameters, and train multiple agents for each of the combination using different random seeds.
#
# The following can also be done by running `demo-sweep.py` in command line:
# ```bash
# python demo-sweep.py env_param_grid=param_grids/param_grid_0.yaml num_epochs=20 count=5
# ```

# %%
env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [-50],
    [0]
]

num_epochs = 20 # number of RL epochs

#Lokesh removed the agent_seeds, and count arguments (that can be specified).
manager.train_agents(env_param_grid=env_param_grid, num_epochs=num_epochs)

# %%
report = manager.overview_agents(env_param_grid=env_param_grid)

# %% [markdown]
# # Compute likelihood of an episode

# %% [markdown]
# ## Likelihood of a specific agent
#
# Given a sequence actions and observations, we compute the likelihood of episode data conditioned on a trained agent $p(a_{1:t}, o_{1:t}|\theta_\mathrm{agent})$.

# %%
logp = agent.episode_likelihood(episode['actions'], episode['observations'])
print('log likelihood {:.3f}'.format(logp))

# %% [markdown]
# ## Likelihood of a series of agents
#
# After multiple agents have been trained on a grid of environment parameters, compute the likelihood of episode data conditioned on each agent.

# %%
from irc.utils import logmeanexp

# Uncomment below line, and comment the one after that, if you want to speciy some other episode data
# 'episode_(-3.0, 12.0, 15, 10, -8, -4).pickle'
episode_path = f'episode_{env.get_param()}.pickle'

env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [-50],
    [0]
]

logps = manager.compute_logps(episode_path=episode_path, env_param_grid=env_param_grid, min_epoch=5, min_optimality=.9)

# logps = logmeanexp(logps, axis=(-2, -1))
# print(f"Log likelihood of all environments saved in an array of shape {logps.shape}")

p = np.exp(logmeanexp(logps, axis=(-2, -1)))
p /= np.nansum(p)

print(f"Probabilities of all environments saved in an array of shape {p.shape}")

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# for episode_path in ['episode_00.pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         agent_seeds=agent_seeds, min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))
#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[2], figsize=(8, 2.5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[..., i], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$r_\mathrm{food}$'+'={:g}'.format(env_param_grid[2][i]))
#         ax.set_xticks(range(p.shape[1]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[1]])
#         ax.set_xlabel(r'$p_\mathrm{cue}$')
#         ax.set_yticks(range(p.shape[0]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[0]])
#             ax.set_ylabel(r'$p_\mathrm{appear}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
        
#         # h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         h = ax.imshow(np.log(p[i,...]))
        
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
#     plt.show()

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

episode_path_list = []
episode_path_list.append('episode_(-3.0, 16.0, 30, 14, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 25, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 25, 10, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 10, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 22, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 22, -8, -4).pickle')

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
    plt.show()

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    # h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    h = plt.imshow(np.log(p))
    
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
    plt.show()

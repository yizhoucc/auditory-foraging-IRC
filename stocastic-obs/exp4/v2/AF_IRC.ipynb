# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 15, 'lines.linewidth': 2,
    'xtick.labelsize': 13, 'ytick.labelsize': 13,
    'axes.spines.top': False, 'axes.spines.right': False,
    'savefig.dpi': 1200,
})

import yaml
import numpy as np

import os
import sys
sys.path.append(f'{os.getcwd()}/irc_gym')

from irc.manager import IRCManager

from auditoryforage.utils import plot_AF_episode

# %% [markdown]
# # Train one agent for a single environment

# %%
defaults = {
    'agent.env._target_': 'auditoryforage.AF_env.AuditoryForaging',
    'agent.model._target_': 'irc.model.FuncBeliefModel',
}
manager = IRCManager(defaults=defaults)

# %% [markdown]
# ## Train an agent
# We train a rational agent for the assume environment parameter [$lick\_cost, food\_reward, attention\_cost\_coeff, attention\_cost\_temp, penalty\_cost, iti\_cost$].

# %%
env_param = [-3.0, 200.0, 38, 15, -5000, 0]
num_epochs = 150

agent = manager.train_agent(env_param, num_epochs=num_epochs)
agent, fig = manager.inspect_agent(env_param, figsize=(5, 2.5))
# Out:
# No checkpoint loaded.
# Initializing an agent with internal environment parameter:
# (-3.0, 200.0, 38, 15, -5000, 0)
# Agent evaluated for 12 episodes of length 100000. Average return -5161.71. (0m08.96s)
#
# Epoch:   1/150
# Agent trained by 10000 time steps (1m07.00s).
#
# Epoch:   2/150
# Agent trained by 10000 time steps (1m12.99s).
# Agent evaluated for 12 episodes of length 100000. Average return -5157.08. (0m09.70s)
#
# Epoch:   3/150
# Agent trained by 10000 time steps (1m14.58s).
#
# Epoch:   4/150
# Agent trained by 10000 time steps (1m11.22s).
# Agent evaluated for 12 episodes of length 100000. Average return -5154.99. (0m09.14s)
#
# Epoch:   5/150
# Agent trained by 10000 time steps (1m12.46s).
#
# Epoch:   6/150
# Agent trained by 10000 time steps (1m14.21s).
# Agent evaluated for 12 episodes of length 100000. Average return -5148.46. (0m08.72s)
#
# Epoch:   7/150
# Agent trained by 10000 time steps (1m14.14s).
#
# Epoch:   8/150
# Agent trained by 10000 time steps (1m30.82s).
# Agent evaluated for 12 episodes of length 100000. Average return -5155.53. (0m10.16s)
#
# Epoch:   9/150
# Agent trained by 10000 time steps (1m17.09s).
#
# Epoch:  10/150
# Agent trained by 10000 time steps (1m16.38s).
# Agent evaluated for 12 episodes of length 100000. Average return -5159.87. (0m09.65s)
#
# Epoch:  11/150
# Agent trained by 10000 time steps (1m12.72s).
#
# Epoch:  12/150
# Agent trained by 10000 time steps (1m23.31s).
# Agent evaluated for 12 episodes of length 100000. Average return -5154.40. (0m09.34s)
#
# Epoch:  13/150
# Agent trained by 10000 time steps (1m12.34s).
#
# Epoch:  14/150
# Agent trained by 10000 time steps (1m12.56s).
# Agent evaluated for 12 episodes of length 100000. Average return -5147.96. (0m09.08s)
#
# Epoch:  15/150
# Agent trained by 10000 time steps (1m15.14s).
#
# Epoch:  16/150
# Agent trained by 10000 time steps (1m15.93s).
# Agent evaluated for 12 episodes of length 100000. Average return -5162.24. (0m10.67s)
#
# Epoch:  17/150
# Agent trained by 10000 time steps (1m13.08s).
#
# Epoch:  18/150
# Agent trained by 10000 time steps (1m14.07s).
# Agent evaluated for 12 episodes of length 100000. Average return -5155.25. (0m09.42s)
#
# Epoch:  19/150
# Agent trained by 10000 time steps (1m15.82s).
#
# Epoch:  20/150
# Agent trained by 10000 time steps (1m19.71s).
# Agent evaluated for 12 episodes of length 100000. Average return -5149.17. (0m09.33s)
#
# Epoch:  21/150
# Agent trained by 10000 time steps (1m23.76s).
#
# Epoch:  22/150
# Agent trained by 10000 time steps (1m17.55s).
# Agent evaluated for 12 episodes of length 100000. Average return -5153.35. (0m09.69s)
#
# Epoch:  23/150
# Agent trained by 10000 time steps (1m22.10s).
#
# Epoch:  24/150
# Agent trained by 10000 time steps (1m36.69s).
# Agent evaluated for 12 episodes of length 100000. Average return -5150.69. (0m09.45s)
#
# Epoch:  25/150
# Agent trained by 10000 time steps (1m13.01s).
#
# Epoch:  26/150
# Agent trained by 10000 time steps (1m19.08s).
# Agent evaluated for 12 episodes of length 100000. Average return -5152.04. (0m11.21s)
#
# Epoch:  27/150
# Agent trained by 10000 time steps (1m23.39s).
#
# Epoch:  28/150
# Agent trained by 10000 time steps (1m25.53s).
# Agent evaluated for 12 episodes of length 100000. Average return -5144.45. (0m11.27s)
#
# Epoch:  29/150
# Agent trained by 10000 time steps (1m18.87s).
#
# Epoch:  30/150
# Agent trained by 10000 time steps (1m25.69s).
# Agent evaluated for 12 episodes of length 100000. Average return -5145.03. (0m10.91s)
#
# Epoch:  31/150
# Agent trained by 10000 time steps (1m28.93s).
#
# Epoch:  32/150
# Agent trained by 10000 time steps (1m26.19s).
# Agent evaluated for 12 episodes of length 100000. Average return -5146.94. (0m10.82s)
#
# Epoch:  33/150
# Agent trained by 10000 time steps (1m37.58s).
#
# Epoch:  34/150
# Agent trained by 10000 time steps (1m22.48s).
# Agent evaluated for 12 episodes of length 100000. Average return -5152.36. (0m08.38s)
#
# Epoch:  35/150
# Agent trained by 10000 time steps (1m03.60s).
#
# Epoch:  36/150
# Agent trained by 10000 time steps (1m03.60s).
# Agent evaluated for 12 episodes of length 100000. Average return -5143.66. (0m07.78s)
#
# Epoch:  37/150
# Agent trained by 10000 time steps (1m03.50s).
#
# Epoch:  38/150
# Agent trained by 10000 time steps (1m03.86s).
# Agent evaluated for 12 episodes of length 100000. Average return -5139.80. (0m07.95s)
#
# Epoch:  39/150
# Agent trained by 10000 time steps (1m03.50s).
#
# Epoch:  40/150
# Agent trained by 10000 time steps (1m03.57s).
# Agent evaluated for 12 episodes of length 100000. Average return -5149.65. (0m08.07s)
#
# Epoch:  41/150
# Agent trained by 10000 time steps (1m05.24s).
#
# Epoch:  42/150
# Agent trained by 10000 time steps (1m06.54s).
# Agent evaluated for 12 episodes of length 100000. Average return -5149.03. (0m08.23s)
#
# Epoch:  43/150
# Agent trained by 10000 time steps (1m03.60s).
#
# Epoch:  44/150
# Agent trained by 10000 time steps (1m02.82s).
# Agent evaluated for 12 episodes of length 100000. Average return -5162.23. (0m08.92s)
#
# Epoch:  45/150
# Agent trained by 10000 time steps (1m04.21s).
#
# Epoch:  46/150
# Agent trained by 10000 time steps (1m04.14s).
# Agent evaluated for 12 episodes of length 100000. Average return -5148.13. (0m08.27s)
#
# Epoch:  47/150
# Agent trained by 10000 time steps (1m03.70s).
#
# Epoch:  48/150
# Agent trained by 10000 time steps (1m03.52s).
# Agent evaluated for 12 episodes of length 100000. Average return -5142.94. (0m08.17s)
#
# Epoch:  49/150
# Agent trained by 10000 time steps (1m04.21s).
#
# Epoch:  50/150
# Agent trained by 10000 time steps (1m03.71s).
# Agent evaluated for 12 episodes of length 100000. Average return -5145.10. (0m07.87s)
#
# Epoch:  51/150
# Agent trained by 10000 time steps (1m03.37s).
#
# Epoch:  52/150
# Agent trained by 10000 time steps (1m03.92s).
# Agent evaluated for 12 episodes of length 100000. Average return -5138.37. (0m07.70s)
#
# Epoch:  53/150
# Agent trained by 10000 time steps (1m04.65s).
#
# Epoch:  54/150
# Agent trained by 10000 time steps (1m03.73s).
# Agent evaluated for 12 episodes of length 100000. Average return -5143.42. (0m08.43s)
#
# Epoch:  55/150
# Agent trained by 10000 time steps (1m04.30s).
#
# Epoch:  56/150
# Agent trained by 10000 time steps (1m03.75s).
# Agent evaluated for 12 episodes of length 100000. Average return -5134.61. (0m08.27s)
#
# Epoch:  57/150
# Agent trained by 10000 time steps (1m03.42s).
#
# Epoch:  58/150
# Agent trained by 10000 time steps (1m06.16s).
# Agent evaluated for 12 episodes of length 100000. Average return -5134.05. (0m08.45s)
#
# Epoch:  59/150
# Agent trained by 10000 time steps (1m02.96s).
#
# Epoch:  60/150
# Agent trained by 10000 time steps (1m03.75s).
# Agent evaluated for 12 episodes of length 100000. Average return -5136.82. (0m08.37s)
#
# Epoch:  61/150
# Agent trained by 10000 time steps (1m02.88s).
#
# Epoch:  62/150
# Agent trained by 10000 time steps (1m06.06s).
# Agent evaluated for 12 episodes of length 100000. Average return -5144.16. (0m08.77s)
#
# Epoch:  63/150
# Agent trained by 10000 time steps (1m03.73s).
#
# Epoch:  64/150
# Agent trained by 10000 time steps (1m03.26s).
# Agent evaluated for 12 episodes of length 100000. Average return -5141.50. (0m08.83s)
#
# Epoch:  65/150
# Agent trained by 10000 time steps (1m03.75s).
#
# Epoch:  66/150
# Agent trained by 10000 time steps (1m03.81s).
# Agent evaluated for 12 episodes of length 100000. Average return -5138.61. (0m08.38s)
#
# Epoch:  67/150
# Agent trained by 10000 time steps (1m03.48s).
#
# Epoch:  68/150
# Agent trained by 10000 time steps (1m03.26s).
# Agent evaluated for 12 episodes of length 100000. Average return -5131.52. (0m07.99s)
#
# Epoch:  69/150
# Agent trained by 10000 time steps (1m04.26s).
#
# Epoch:  70/150
# Agent trained by 10000 time steps (1m04.35s).
# Agent evaluated for 12 episodes of length 100000. Average return -5138.86. (0m08.41s)
#
# Epoch:  71/150
# Agent trained by 10000 time steps (1m03.43s).
#
# Epoch:  72/150
# Agent trained by 10000 time steps (1m02.64s).
# Agent evaluated for 12 episodes of length 100000. Average return -5135.60. (0m08.61s)
#
# Epoch:  73/150
# Agent trained by 10000 time steps (1m04.55s).
#
# Epoch:  74/150
# Agent trained by 10000 time steps (1m06.98s).
# Agent evaluated for 12 episodes of length 100000. Average return -5136.30. (0m08.82s)
#
# Epoch:  75/150
# Agent trained by 10000 time steps (1m05.35s).
#
# Epoch:  76/150
# Agent trained by 10000 time steps (1m10.71s).
# Agent evaluated for 12 episodes of length 100000. Average return -5131.26. (0m08.53s)
#
# Epoch:  77/150
# Agent trained by 10000 time steps (1m13.09s).
#
# Epoch:  78/150
# Agent trained by 10000 time steps (1m04.69s).
# Agent evaluated for 12 episodes of length 100000. Average return -5123.15. (0m08.94s)
#
# Epoch:  79/150
# Agent trained by 10000 time steps (1m17.25s).
#
# Epoch:  80/150
# Agent trained by 10000 time steps (1m07.62s).
# Agent evaluated for 12 episodes of length 100000. Average return -5113.21. (0m08.95s)
#
# Epoch:  81/150
# Agent trained by 10000 time steps (1m05.62s).
#
# Epoch:  82/150
# Agent trained by 10000 time steps (1m04.13s).
# Agent evaluated for 12 episodes of length 100000. Average return -5093.13. (0m10.47s)
#
# Epoch:  83/150
# Agent trained by 10000 time steps (1m04.78s).
#
# Epoch:  84/150
# Agent trained by 10000 time steps (1m08.25s).
# Agent evaluated for 12 episodes of length 100000. Average return -5082.95. (0m09.13s)
#
# Epoch:  85/150
# Agent trained by 10000 time steps (1m04.82s).
#
# Epoch:  86/150
# Agent trained by 10000 time steps (1m02.87s).
# Agent evaluated for 12 episodes of length 100000. Average return -5052.35. (0m16.75s)
#
# Epoch:  87/150
# Agent trained by 10000 time steps (1m03.65s).
#
# Epoch:  88/150
# Agent trained by 10000 time steps (1m03.29s).
# Agent evaluated for 12 episodes of length 100000. Average return -5042.68. (0m19.94s)
#
# Epoch:  89/150
# Agent trained by 10000 time steps (1m08.16s).
#
# Epoch:  90/150
# Agent trained by 10000 time steps (1m03.87s).
# Agent evaluated for 12 episodes of length 100000. Average return -5038.44. (0m26.31s)
#
# Epoch:  91/150
# Agent trained by 10000 time steps (1m03.63s).
#
# Epoch:  92/150
# Agent trained by 10000 time steps (1m05.87s).
# Agent evaluated for 12 episodes of length 100000. Average return -5036.06. (0m24.00s)
#
# Epoch:  93/150
# Agent trained by 10000 time steps (1m02.95s).
#
# Epoch:  94/150
# Agent trained by 10000 time steps (1m03.77s).
# Agent evaluated for 12 episodes of length 100000. Average return -5019.32. (0m34.02s)
#
# Epoch:  95/150
# Agent trained by 10000 time steps (1m03.14s).
#
# Epoch:  96/150
# Agent trained by 10000 time steps (1m07.08s).
# Agent evaluated for 12 episodes of length 100000. Average return -5028.33. (0m35.04s)
#
# Epoch:  97/150
# Agent trained by 10000 time steps (1m03.20s).
#
# Epoch:  98/150
# Agent trained by 10000 time steps (1m03.54s).
# Agent evaluated for 12 episodes of length 100000. Average return -5030.59. (1m02.71s)
#
# Epoch:  99/150
# Agent trained by 10000 time steps (1m04.23s).
#
# Epoch: 100/150
# Agent trained by 10000 time steps (1m03.86s).
# Agent evaluated for 12 episodes of length 100000. Average return -5024.26. (1m17.93s)
#
# Epoch: 101/150
# Agent trained by 10000 time steps (1m06.92s).
#
# Epoch: 102/150
# Agent trained by 10000 time steps (1m13.49s).
# Agent evaluated for 12 episodes of length 100000. Average return -5022.90. (3m02.60s)
#
# Epoch: 103/150
# Agent trained by 10000 time steps (1m00.96s).
#
# Epoch: 104/150
# Agent trained by 10000 time steps (1m03.77s).
# Agent evaluated for 12 episodes of length 100000. Average return -5010.05. (4m53.28s)
#
# Epoch: 105/150
# Agent trained by 10000 time steps (1m03.48s).
#
# Epoch: 106/150
# Agent trained by 10000 time steps (1m03.65s).
# Agent evaluated for 12 episodes of length 100000. Average return -5016.26. (3m30.21s)
#
# Epoch: 107/150
# Agent trained by 10000 time steps (1m04.25s).
#
# Epoch: 108/150
# Agent trained by 10000 time steps (1m02.68s).
# Agent evaluated for 12 episodes of length 100000. Average return -5018.53. (2m35.48s)
#
# Epoch: 109/150
# Agent trained by 10000 time steps (1m04.06s).
#
# Epoch: 110/150
# Agent trained by 10000 time steps (1m01.12s).
# Agent evaluated for 12 episodes of length 100000. Average return -5019.28. (3m03.17s)
#
# Epoch: 111/150
# Agent trained by 10000 time steps (1m02.15s).
#
# Epoch: 112/150
# Agent trained by 10000 time steps (1m01.54s).
# Agent evaluated for 12 episodes of length 100000. Average return -5019.70. (3m13.44s)
#
# Epoch: 113/150
# Agent trained by 10000 time steps (1m01.07s).
#
# Epoch: 114/150
# Agent trained by 10000 time steps (1m02.07s).
# Agent evaluated for 12 episodes of length 100000. Average return -5019.91. (3m25.86s)
#
# Epoch: 115/150
# Agent trained by 10000 time steps (1m03.59s).
#
# Epoch: 116/150
# Agent trained by 10000 time steps (1m03.14s).
# Agent evaluated for 12 episodes of length 100000. Average return -5020.98. (3m24.68s)
#
# Epoch: 117/150
# Agent trained by 10000 time steps (1m00.41s).
#
# Epoch: 118/150
# Agent trained by 10000 time steps (1m00.66s).
# Agent evaluated for 12 episodes of length 100000. Average return -5021.38. (1m15.51s)
#
# Epoch: 119/150
# Agent trained by 10000 time steps (1m04.40s).
#
# Epoch: 120/150
# Agent trained by 10000 time steps (1m02.86s).
# Agent evaluated for 12 episodes of length 100000. Average return -5019.49. (2m14.39s)
#
# Epoch: 121/150
# Agent trained by 10000 time steps (1m03.00s).
#
# Epoch: 122/150
# Agent trained by 10000 time steps (1m02.19s).
# Agent evaluated for 12 episodes of length 100000. Average return -5019.48. (2m12.23s)
#
# Epoch: 123/150
# Agent trained by 10000 time steps (1m02.30s).
#
# Epoch: 124/150
# Agent trained by 10000 time steps (1m04.74s).
# Agent evaluated for 12 episodes of length 100000. Average return -5024.62. (1m25.74s)
#
# Epoch: 125/150
# Agent trained by 10000 time steps (1m01.50s).
#
# Epoch: 126/150
# Agent trained by 10000 time steps (1m01.54s).
# Agent evaluated for 12 episodes of length 100000. Average return -5018.62. (1m35.45s)
#
# Epoch: 127/150
# Agent trained by 10000 time steps (1m02.41s).
#
# Epoch: 128/150
# Agent trained by 10000 time steps (1m02.69s).
# Agent evaluated for 12 episodes of length 100000. Average return -5023.41. (1m48.36s)
#
# Epoch: 129/150
# Agent trained by 10000 time steps (1m02.03s).
#
# Epoch: 130/150
# Agent trained by 10000 time steps (1m02.39s).
# Agent evaluated for 12 episodes of length 100000. Average return -5026.05. (5m28.50s)
#
# Epoch: 131/150
# Agent trained by 10000 time steps (1m02.60s).
#
# Epoch: 132/150
# Agent trained by 10000 time steps (1m01.00s).
# Agent evaluated for 12 episodes of length 100000. Average return -5019.06. (2m50.69s)
#
# Epoch: 133/150
# Agent trained by 10000 time steps (1m00.60s).
#
# Epoch: 134/150
# Agent trained by 10000 time steps (1m00.99s).
# Agent evaluated for 12 episodes of length 100000. Average return -5021.29. (2m13.92s)
#
# Epoch: 135/150
# Agent trained by 10000 time steps (1m00.94s).
#
# Epoch: 136/150
# Agent trained by 10000 time steps (0m58.25s).
# Agent evaluated for 12 episodes of length 100000. Average return -5021.30. (1m46.12s)
#
# Epoch: 137/150
# Agent trained by 10000 time steps (0m56.60s).
#
# Epoch: 138/150
# Agent trained by 10000 time steps (0m57.88s).
# Agent evaluated for 12 episodes of length 100000. Average return -5020.38. (2m17.02s)
#
# Epoch: 139/150
# Agent trained by 10000 time steps (1m00.14s).
#
# Epoch: 140/150
# Agent trained by 10000 time steps (0m59.57s).
# Agent evaluated for 12 episodes of length 100000. Average return -5021.49. (3m01.59s)
#
# Epoch: 141/150
# Agent trained by 10000 time steps (1m01.21s).
#
# Epoch: 142/150
# Agent trained by 10000 time steps (0m58.43s).
# Agent evaluated for 12 episodes of length 100000. Average return -5018.59. (3m13.82s)
#
# Epoch: 143/150
# Agent trained by 10000 time steps (0m58.61s).
#
# Epoch: 144/150
# Agent trained by 10000 time steps (0m59.28s).
# Agent evaluated for 12 episodes of length 100000. Average return -5022.86. (1m36.41s)
#
# Epoch: 145/150
# Agent trained by 10000 time steps (1m00.30s).
#
# Epoch: 146/150
# Agent trained by 10000 time steps (1m00.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -5023.66. (1m21.24s)
#
# Epoch: 147/150
# Agent trained by 10000 time steps (1m00.19s).
#
# Epoch: 148/150
# Agent trained by 10000 time steps (1m00.03s).
# Agent evaluated for 12 episodes of length 100000. Average return -5020.46. (2m12.29s)
#
# Epoch: 149/150
# Agent trained by 10000 time steps (0m57.73s).
#
# Epoch: 150/150
# Agent trained by 10000 time steps (0m56.99s).
# Agent evaluated for 12 episodes of length 100000. Average return -5023.50. (2m10.98s)
# Fetching the most trained agent so far (epoch 150).
# Agent (seed 0) was trained for 150 epochs.

# %% [markdown]
# ## Run the agent in an environment
# We create another environment which has the same observation space and action space as the assumed one, albeit with a different set of environment parameters.

# %%
from auditoryforage.AF_env import AuditoryForaging

# Change below line if you want to try the trained model on a different set of environemnt.
# env_param = [-3.0, 8.0, 13, 8, -8, -4]

env = AuditoryForaging(spec={'agent':{'lick_cost':env_param[0],'food_reward':env_param[1],'attention_cost_coeff':env_param[2], 'attention_cost_temp': env_param[3], 'penalty_cost': env_param[4], 'iti_cost': env_param[5]}})
episode = agent.run_one_episode(env=env, num_steps=10000, q_states = [[i] for i in range(env.no_nodes)])
fig = plot_AF_episode(episode, env)

env.spec
# Out:
# {'agent': {'lick_cost': -3.0,
#   'food_reward': 200.0,
#   'attention_cost_coeff': 38,
#   'attention_cost_temp': 15,
#   'penalty_cost': -5000,
#   'iti_cost': 0,
#   'no_attention_modes': 6},
#  'experiment': {'prob_01': 0.004,
#   'no_signal_nodes': 150,
#   'no_penalty_nodes': 1,
#   'no_ITI_nodes': 150}}

# %%
duration_before_licking = 10
plt.stem(episode['q_probs'].T[0,-duration_before_licking:-1],'b')
plt.stem(np.sum(episode['q_probs'].T[1:151,-duration_before_licking:-1],0),'r')
plt.title('Beliefs before licking')
plt.xlabel('time')
plt.ylabel('Probability')
plt.legend(['noise state','signal state'])
plt.show()

# plt.stem(episode['observations'].T[0,-duration_before_licking:-1],'b')
# plt.stem(episode['actions'].T[-duration_before_licking:-1],'r')
# plt.xlabel('time')
# plt.legend(['observation','actions'])
# plt.show()

# plt.imshow(episode['q_probs'].T[152:300,:])
# plt.xlabel('time')
# plt.ylabel('Probability of ITI states')
# plt.show()

# %% [markdown]
# We can save the episode data in an external `pickle` file.

# %%
import os, pickle

episode_path = f'store/episode_{env.get_param()}.pickle'

if os.path.exists(episode_path):
    print(f"File {episode_path} already exists, will not be overwritten.")
else:
    with open(episode_path, 'wb') as f:
        pickle.dump({
            'external_env_param': env.get_param(),
            'internal_env_param': agent.model.env.get_param(),
            **episode,
        }, f)
    print(f"Episode data saved at '{episode_path}'.")
# Out:
# Episode data saved at 'store/episode_(-3.0, 200.0, 38, 15, -5000, 0).pickle'.

# %% [markdown]
# # Train multiple agents for different environments

# %% [markdown]
# ## Sweep over parameter grid
#
# We define a grid of environment parameters, and train multiple agents for each of the combination using different random seeds.
#
# The following can also be done by running `demo-sweep.py` in command line:
# ```bash
# python demo-sweep.py env_param_grid=param_grids/param_grid_0.yaml num_epochs=20 count=5
# ```

# %%
env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [-50],
    [0]
]

num_epochs = 20 # number of RL epochs

#Lokesh removed the agent_seeds, and count arguments (that can be specified).
manager.train_agents(env_param_grid=env_param_grid, num_epochs=num_epochs)

# %%
report = manager.overview_agents(env_param_grid=env_param_grid)

# %% [markdown]
# # Compute likelihood of an episode

# %% [markdown]
# ## Likelihood of a specific agent
#
# Given a sequence actions and observations, we compute the likelihood of episode data conditioned on a trained agent $p(a_{1:t}, o_{1:t}|\theta_\mathrm{agent})$.

# %%
logp = agent.episode_likelihood(episode['actions'], episode['observations'])
print('log likelihood {:.3f}'.format(logp))

# %% [markdown]
# ## Likelihood of a series of agents
#
# After multiple agents have been trained on a grid of environment parameters, compute the likelihood of episode data conditioned on each agent.

# %%
from irc.utils import logmeanexp

# Uncomment below line, and comment the one after that, if you want to speciy some other episode data
# 'episode_(-3.0, 12.0, 15, 10, -8, -4).pickle'
episode_path = f'episode_{env.get_param()}.pickle'

env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [-50],
    [0]
]

logps = manager.compute_logps(episode_path=episode_path, env_param_grid=env_param_grid, min_epoch=5, min_optimality=.9)

# logps = logmeanexp(logps, axis=(-2, -1))
# print(f"Log likelihood of all environments saved in an array of shape {logps.shape}")

p = np.exp(logmeanexp(logps, axis=(-2, -1)))
p /= np.nansum(p)

print(f"Probabilities of all environments saved in an array of shape {p.shape}")

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# for episode_path in ['episode_00.pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         agent_seeds=agent_seeds, min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))
#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[2], figsize=(8, 2.5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[..., i], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$r_\mathrm{food}$'+'={:g}'.format(env_param_grid[2][i]))
#         ax.set_xticks(range(p.shape[1]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[1]])
#         ax.set_xlabel(r'$p_\mathrm{cue}$')
#         ax.set_yticks(range(p.shape[0]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[0]])
#             ax.set_ylabel(r'$p_\mathrm{appear}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
        
#         # h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         h = ax.imshow(np.log(p[i,...]))
        
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
#     plt.show()

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

episode_path_list = []
episode_path_list.append('episode_(-3.0, 16.0, 30, 14, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 25, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 25, 10, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 10, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 22, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 22, -8, -4).pickle')

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
    plt.show()

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    # h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    h = plt.imshow(np.log(p))
    
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
    plt.show()

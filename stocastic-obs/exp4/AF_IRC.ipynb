# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 15, 'lines.linewidth': 2,
    'xtick.labelsize': 13, 'ytick.labelsize': 13,
    'axes.spines.top': False, 'axes.spines.right': False,
    'savefig.dpi': 1200,
})

import yaml
import numpy as np

import os
import sys
sys.path.append(f'{os.getcwd()}/irc_gym')

from irc.manager import IRCManager

from auditoryforage.utils import plot_AF_episode

# %% [markdown]
# # Train one agent for a single environment

# %%
defaults = {
    'agent.env._target_': 'auditoryforage.AF_env.AuditoryForaging',
    'agent.model._target_': 'irc.model.FuncBeliefModel',
}
manager = IRCManager(defaults=defaults)

# %% [markdown]
# ## Train an agent
# We train a rational agent for the assume environment parameter [$lick\_cost, food\_reward, attention\_cost\_coeff, attention\_cost\_temp, penalty\_cost, iti\_cost$].

# %%
env_param = [-3.0, 200.0, 25, 10, -1000, 0]
num_epochs = 1000

agent = manager.train_agent(env_param, num_epochs=num_epochs)
agent, fig = manager.inspect_agent(env_param, figsize=(5, 2.5))
# Out:
# Checkpoint loaded.
#
# Epoch:    1/1000
# Agent trained by 10000 time steps (1m00.04s).
#
# Epoch:    2/1000
# Agent trained by 10000 time steps (0m56.30s).
# Agent evaluated for 12 episodes of length 100000. Average return -3058.72. (0m07.53s)
#
# Epoch:    3/1000
# Agent trained by 10000 time steps (0m55.82s).
#
# Epoch:    4/1000
# Agent trained by 10000 time steps (0m55.81s).
# Agent evaluated for 12 episodes of length 100000. Average return -3044.67. (0m07.27s)
#
# Epoch:    5/1000
# Agent trained by 10000 time steps (0m55.54s).
#
# Epoch:    6/1000
# Agent trained by 10000 time steps (0m55.84s).
# Agent evaluated for 12 episodes of length 100000. Average return -3038.77. (0m07.20s)
#
# Epoch:    7/1000
# Agent trained by 10000 time steps (0m55.71s).
#
# Epoch:    8/1000
# Agent trained by 10000 time steps (0m55.60s).
# Agent evaluated for 12 episodes of length 100000. Average return -3060.03. (0m07.41s)
#
# Epoch:    9/1000
# Agent trained by 10000 time steps (0m55.74s).
#
# Epoch:   10/1000
# Agent trained by 10000 time steps (0m55.79s).
# Agent evaluated for 12 episodes of length 100000. Average return -3003.24. (0m07.07s)
#
# Epoch:   11/1000
# Agent trained by 10000 time steps (0m55.89s).
#
# Epoch:   12/1000
# Agent trained by 10000 time steps (0m56.60s).
# Agent evaluated for 12 episodes of length 100000. Average return -3048.39. (0m07.32s)
#
# Epoch:   13/1000
# Agent trained by 10000 time steps (0m55.30s).
#
# Epoch:   14/1000
# Agent trained by 10000 time steps (0m55.69s).
# Agent evaluated for 12 episodes of length 100000. Average return -3085.80. (0m07.92s)
#
# Epoch:   15/1000
# Agent trained by 10000 time steps (0m56.12s).
#
# Epoch:   16/1000
# Agent trained by 10000 time steps (0m55.64s).
# Agent evaluated for 12 episodes of length 100000. Average return -3103.11. (0m07.74s)
#
# Epoch:   17/1000
# Agent trained by 10000 time steps (0m55.72s).
#
# Epoch:   18/1000
# Agent trained by 10000 time steps (0m55.96s).
# Agent evaluated for 12 episodes of length 100000. Average return -2984.29. (0m06.96s)
#
# Epoch:   19/1000
# Agent trained by 10000 time steps (0m55.78s).
#
# Epoch:   20/1000
# Agent trained by 10000 time steps (0m55.55s).
# Agent evaluated for 12 episodes of length 100000. Average return -3047.94. (0m07.61s)
#
# Epoch:   21/1000
# Agent trained by 10000 time steps (0m55.74s).
#
# Epoch:   22/1000
# Agent trained by 10000 time steps (0m56.19s).
# Agent evaluated for 12 episodes of length 100000. Average return -2927.98. (0m07.18s)
#
# Epoch:   23/1000
# Agent trained by 10000 time steps (0m55.89s).
#
# Epoch:   24/1000
# Agent trained by 10000 time steps (0m55.69s).
# Agent evaluated for 12 episodes of length 100000. Average return -3061.16. (0m08.93s)
#
# Epoch:   25/1000
# Agent trained by 10000 time steps (0m56.09s).
#
# Epoch:   26/1000
# Agent trained by 10000 time steps (0m55.53s).
# Agent evaluated for 12 episodes of length 100000. Average return -3014.23. (0m08.05s)
#
# Epoch:   27/1000
# Agent trained by 10000 time steps (0m55.62s).
#
# Epoch:   28/1000
# Agent trained by 10000 time steps (0m55.47s).
# Agent evaluated for 12 episodes of length 100000. Average return -2961.86. (0m07.57s)
#
# Epoch:   29/1000
# Agent trained by 10000 time steps (0m55.69s).
#
# Epoch:   30/1000
# Agent trained by 10000 time steps (0m55.50s).
# Agent evaluated for 12 episodes of length 100000. Average return -2970.42. (0m07.55s)
#
# Epoch:   31/1000
# Agent trained by 10000 time steps (0m55.52s).
#
# Epoch:   32/1000
# Agent trained by 10000 time steps (0m55.57s).
# Agent evaluated for 12 episodes of length 100000. Average return -2980.59. (0m07.69s)
#
# Epoch:   33/1000
# Agent trained by 10000 time steps (0m55.84s).
#
# Epoch:   34/1000
# Agent trained by 10000 time steps (0m56.15s).
# Agent evaluated for 12 episodes of length 100000. Average return -2969.29. (0m07.74s)
#
# Epoch:   35/1000
# Agent trained by 10000 time steps (0m55.97s).
#
# Epoch:   36/1000
# Agent trained by 10000 time steps (0m55.86s).
# Agent evaluated for 12 episodes of length 100000. Average return -2866.88. (0m06.87s)
#
# Epoch:   37/1000
# Agent trained by 10000 time steps (0m56.02s).
#
# Epoch:   38/1000
# Agent trained by 10000 time steps (0m55.81s).
# Agent evaluated for 12 episodes of length 100000. Average return -2934.91. (0m07.57s)
#
# Epoch:   39/1000
# Agent trained by 10000 time steps (0m55.90s).
#
# Epoch:   40/1000
# Agent trained by 10000 time steps (0m55.78s).
# Agent evaluated for 12 episodes of length 100000. Average return -2913.55. (0m07.31s)
#
# Epoch:   41/1000
# Agent trained by 10000 time steps (0m55.35s).
#
# Epoch:   42/1000
# Agent trained by 10000 time steps (0m55.42s).
# Agent evaluated for 12 episodes of length 100000. Average return -2893.11. (0m07.19s)
#
# Epoch:   43/1000
# Agent trained by 10000 time steps (0m56.04s).
#
# Epoch:   44/1000
# Agent trained by 10000 time steps (0m55.45s).
# Agent evaluated for 12 episodes of length 100000. Average return -2909.41. (0m07.30s)
#
# Epoch:   45/1000
# Agent trained by 10000 time steps (0m55.48s).
#
# Epoch:   46/1000
# Agent trained by 10000 time steps (0m55.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -2846.93. (0m06.82s)
#
# Epoch:   47/1000
# Agent trained by 10000 time steps (0m55.75s).
#
# Epoch:   48/1000
# Agent trained by 10000 time steps (0m55.69s).
# Agent evaluated for 12 episodes of length 100000. Average return -2855.99. (0m06.94s)
#
# Epoch:   49/1000
# Agent trained by 10000 time steps (0m55.46s).
#
# Epoch:   50/1000
# Agent trained by 10000 time steps (0m55.77s).
# Agent evaluated for 12 episodes of length 100000. Average return -2857.41. (0m06.91s)
#
# Epoch:   51/1000
# Agent trained by 10000 time steps (0m55.41s).
#
# Epoch:   52/1000
# Agent trained by 10000 time steps (0m56.75s).
# Agent evaluated for 12 episodes of length 100000. Average return -2910.90. (0m07.57s)
#
# Epoch:   53/1000
# Agent trained by 10000 time steps (0m56.52s).
#
# Epoch:   54/1000
# Agent trained by 10000 time steps (0m56.53s).
# Agent evaluated for 12 episodes of length 100000. Average return -2895.28. (0m07.24s)
#
# Epoch:   55/1000
# Agent trained by 10000 time steps (0m55.91s).
#
# Epoch:   56/1000
# Agent trained by 10000 time steps (0m55.96s).
# Agent evaluated for 12 episodes of length 100000. Average return -2810.02. (0m06.63s)
#
# Epoch:   57/1000
# Agent trained by 10000 time steps (0m56.02s).
#
# Epoch:   58/1000
# Agent trained by 10000 time steps (0m55.89s).
# Agent evaluated for 12 episodes of length 100000. Average return -2880.60. (0m07.11s)
#
# Epoch:   59/1000
# Agent trained by 10000 time steps (0m55.97s).
#
# Epoch:   60/1000
# Agent trained by 10000 time steps (0m56.07s).
# Agent evaluated for 12 episodes of length 100000. Average return -2895.57. (0m07.22s)
#
# Epoch:   61/1000
# Agent trained by 10000 time steps (0m56.06s).
#
# Epoch:   62/1000
# Agent trained by 10000 time steps (0m56.13s).
# Agent evaluated for 12 episodes of length 100000. Average return -2938.80. (0m07.60s)
#
# Epoch:   63/1000
# Agent trained by 10000 time steps (0m55.81s).
#
# Epoch:   64/1000
# Agent trained by 10000 time steps (0m55.94s).
# Agent evaluated for 12 episodes of length 100000. Average return -2874.24. (0m07.15s)
#
# Epoch:   65/1000
# Agent trained by 10000 time steps (0m56.16s).
#
# Epoch:   66/1000
# Agent trained by 10000 time steps (0m55.77s).
# Agent evaluated for 12 episodes of length 100000. Average return -2887.27. (0m07.17s)
#
# Epoch:   67/1000
# Agent trained by 10000 time steps (0m55.76s).
#
# Epoch:   68/1000
# Agent trained by 10000 time steps (0m56.13s).
# Agent evaluated for 12 episodes of length 100000. Average return -2883.46. (0m07.31s)
#
# Epoch:   69/1000
# Agent trained by 10000 time steps (0m56.10s).
#
# Epoch:   70/1000
# Agent trained by 10000 time steps (0m55.99s).
# Agent evaluated for 12 episodes of length 100000. Average return -2897.64. (0m07.47s)
#
# Epoch:   71/1000
# Agent trained by 10000 time steps (0m57.04s).
#
# Epoch:   72/1000
# Agent trained by 10000 time steps (0m56.36s).
# Agent evaluated for 12 episodes of length 100000. Average return -2854.31. (0m07.10s)
#
# Epoch:   73/1000
# Agent trained by 10000 time steps (0m56.42s).
#
# Epoch:   74/1000
# Agent trained by 10000 time steps (0m56.04s).
# Agent evaluated for 12 episodes of length 100000. Average return -2865.92. (0m07.01s)
#
# Epoch:   75/1000
# Agent trained by 10000 time steps (0m56.41s).
#
# Epoch:   76/1000
# Agent trained by 10000 time steps (0m56.35s).
# Agent evaluated for 12 episodes of length 100000. Average return -2965.39. (0m07.33s)
#
# Epoch:   77/1000
# Agent trained by 10000 time steps (0m55.94s).
#
# Epoch:   78/1000
# Agent trained by 10000 time steps (0m56.45s).
# Agent evaluated for 12 episodes of length 100000. Average return -2935.75. (0m07.00s)
#
# Epoch:   79/1000
# Agent trained by 10000 time steps (0m56.24s).
#
# Epoch:   80/1000
# Agent trained by 10000 time steps (0m56.46s).
# Agent evaluated for 12 episodes of length 100000. Average return -2930.12. (0m06.92s)
#
# Epoch:   81/1000
# Agent trained by 10000 time steps (0m56.34s).
#
# Epoch:   82/1000
# Agent trained by 10000 time steps (0m56.65s).
# Agent evaluated for 12 episodes of length 100000. Average return -2923.54. (0m06.88s)
#
# Epoch:   83/1000
# Agent trained by 10000 time steps (0m56.29s).
#
# Epoch:   84/1000
# Agent trained by 10000 time steps (0m56.31s).
# Agent evaluated for 12 episodes of length 100000. Average return -3024.36. (0m07.73s)
#
# Epoch:   85/1000
# Agent trained by 10000 time steps (0m57.06s).
#
# Epoch:   86/1000
# Agent trained by 10000 time steps (0m57.04s).
# Agent evaluated for 12 episodes of length 100000. Average return -2982.29. (0m07.15s)
#
# Epoch:   87/1000
# Agent trained by 10000 time steps (0m57.04s).
#
# Epoch:   88/1000
# Agent trained by 10000 time steps (0m57.21s).
# Agent evaluated for 12 episodes of length 100000. Average return -2888.80. (0m06.72s)
#
# Epoch:   89/1000
# Agent trained by 10000 time steps (0m56.73s).
#
# Epoch:   90/1000
# Agent trained by 10000 time steps (0m56.97s).
# Agent evaluated for 12 episodes of length 100000. Average return -2966.12. (0m07.31s)
#
# Epoch:   91/1000
# Agent trained by 10000 time steps (0m57.08s).
#
# Epoch:   92/1000
# Agent trained by 10000 time steps (0m56.89s).
# Agent evaluated for 12 episodes of length 100000. Average return -2980.22. (0m07.21s)
#
# Epoch:   93/1000
# Agent trained by 10000 time steps (0m56.53s).
#
# Epoch:   94/1000
# Agent trained by 10000 time steps (0m57.13s).
# Agent evaluated for 12 episodes of length 100000. Average return -2918.05. (0m07.25s)
#
# Epoch:   95/1000
# Agent trained by 10000 time steps (0m56.59s).
#
# Epoch:   96/1000
# Agent trained by 10000 time steps (0m56.43s).
# Agent evaluated for 12 episodes of length 100000. Average return -2930.66. (0m07.17s)
#
# Epoch:   97/1000
# Agent trained by 10000 time steps (0m56.41s).
#
# Epoch:   98/1000
# Agent trained by 10000 time steps (0m56.44s).
# Agent evaluated for 12 episodes of length 100000. Average return -2899.71. (0m06.96s)
#
# Epoch:   99/1000
# Agent trained by 10000 time steps (0m56.59s).
#
# Epoch:  100/1000
# Agent trained by 10000 time steps (0m56.74s).
# Agent evaluated for 12 episodes of length 100000. Average return -2964.55. (0m07.43s)
#
# Epoch:  101/1000
# Agent trained by 10000 time steps (0m56.81s).
#
# Epoch:  102/1000
# Agent trained by 10000 time steps (0m57.36s).
# Agent evaluated for 12 episodes of length 100000. Average return -2947.91. (0m07.24s)
#
# Epoch:  103/1000
# Agent trained by 10000 time steps (0m56.91s).
#
# Epoch:  104/1000
# Agent trained by 10000 time steps (0m56.03s).
# Agent evaluated for 12 episodes of length 100000. Average return -2945.97. (0m07.23s)
#
# Epoch:  105/1000
# Agent trained by 10000 time steps (0m56.42s).
#
# Epoch:  106/1000
# Agent trained by 10000 time steps (0m56.39s).
# Agent evaluated for 12 episodes of length 100000. Average return -2953.93. (0m07.51s)
#
# Epoch:  107/1000
# Agent trained by 10000 time steps (0m56.91s).
#
# Epoch:  108/1000
# Agent trained by 10000 time steps (0m56.25s).
# Agent evaluated for 12 episodes of length 100000. Average return -2971.80. (0m07.64s)
#
# Epoch:  109/1000
# Agent trained by 10000 time steps (0m57.19s).
#
# Epoch:  110/1000
# Agent trained by 10000 time steps (0m56.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -2981.87. (0m07.71s)
#
# Epoch:  111/1000
# Agent trained by 10000 time steps (0m56.65s).
#
# Epoch:  112/1000
# Agent trained by 10000 time steps (0m56.47s).
# Agent evaluated for 12 episodes of length 100000. Average return -2978.06. (0m07.78s)
#
# Epoch:  113/1000
# Agent trained by 10000 time steps (0m57.35s).
#
# Epoch:  114/1000
# Agent trained by 10000 time steps (0m57.73s).
# Agent evaluated for 12 episodes of length 100000. Average return -2940.73. (0m07.34s)
#
# Epoch:  115/1000
# Agent trained by 10000 time steps (0m56.67s).
#
# Epoch:  116/1000
# Agent trained by 10000 time steps (0m56.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -2908.24. (0m07.33s)
#
# Epoch:  117/1000
# Agent trained by 10000 time steps (0m56.57s).
#
# Epoch:  118/1000
# Agent trained by 10000 time steps (0m56.81s).
# Agent evaluated for 12 episodes of length 100000. Average return -2956.64. (0m07.40s)
#
# Epoch:  119/1000
# Agent trained by 10000 time steps (0m56.43s).
#
# Epoch:  120/1000
# Agent trained by 10000 time steps (0m56.64s).
# Agent evaluated for 12 episodes of length 100000. Average return -2955.75. (0m07.34s)
#
# Epoch:  121/1000
# Agent trained by 10000 time steps (0m56.97s).
#
# Epoch:  122/1000
# Agent trained by 10000 time steps (0m56.77s).
# Agent evaluated for 12 episodes of length 100000. Average return -2900.55. (0m07.01s)
#
# Epoch:  123/1000
# Agent trained by 10000 time steps (0m57.15s).
#
# Epoch:  124/1000
# Agent trained by 10000 time steps (0m57.32s).
# Agent evaluated for 12 episodes of length 100000. Average return -2928.78. (0m07.17s)
#
# Epoch:  125/1000
# Agent trained by 10000 time steps (0m56.97s).
#
# Epoch:  126/1000
# Agent trained by 10000 time steps (0m56.49s).
# Agent evaluated for 12 episodes of length 100000. Average return -2924.57. (0m07.23s)
#
# Epoch:  127/1000
# Agent trained by 10000 time steps (0m57.81s).
#
# Epoch:  128/1000
# Agent trained by 10000 time steps (0m56.44s).
# Agent evaluated for 12 episodes of length 100000. Average return -2950.17. (0m07.49s)
#
# Epoch:  129/1000
# Agent trained by 10000 time steps (0m56.70s).
#
# Epoch:  130/1000
# Agent trained by 10000 time steps (0m56.22s).
# Agent evaluated for 12 episodes of length 100000. Average return -2893.58. (0m06.90s)
#
# Epoch:  131/1000
# Agent trained by 10000 time steps (0m57.35s).
#
# Epoch:  132/1000
# Agent trained by 10000 time steps (0m57.22s).
# Agent evaluated for 12 episodes of length 100000. Average return -2865.64. (0m06.66s)
#
# Epoch:  133/1000
# Agent trained by 10000 time steps (0m56.47s).
#
# Epoch:  134/1000
# Agent trained by 10000 time steps (0m56.45s).
# Agent evaluated for 12 episodes of length 100000. Average return -2921.95. (0m07.02s)
#
# Epoch:  135/1000
# Agent trained by 10000 time steps (0m56.33s).
#
# Epoch:  136/1000
# Agent trained by 10000 time steps (0m56.71s).
# Agent evaluated for 12 episodes of length 100000. Average return -2910.72. (0m07.35s)
#
# Epoch:  137/1000
# Agent trained by 10000 time steps (0m56.81s).
#
# Epoch:  138/1000
# Agent trained by 10000 time steps (0m56.15s).
# Agent evaluated for 12 episodes of length 100000. Average return -2888.70. (0m06.84s)
#
# Epoch:  139/1000
# Agent trained by 10000 time steps (0m56.41s).
#
# Epoch:  140/1000
# Agent trained by 10000 time steps (0m56.03s).
# Agent evaluated for 12 episodes of length 100000. Average return -2920.27. (0m07.19s)
#
# Epoch:  141/1000
# Agent trained by 10000 time steps (0m56.95s).
#
# Epoch:  142/1000
# Agent trained by 10000 time steps (0m56.48s).
# Agent evaluated for 12 episodes of length 100000. Average return -2915.93. (0m07.12s)
#
# Epoch:  143/1000
# Agent trained by 10000 time steps (0m56.33s).
#
# Epoch:  144/1000
# Agent trained by 10000 time steps (0m56.46s).
# Agent evaluated for 12 episodes of length 100000. Average return -2955.63. (0m07.42s)
#
# Epoch:  145/1000
# Agent trained by 10000 time steps (0m56.41s).
#
# Epoch:  146/1000
# Agent trained by 10000 time steps (0m57.29s).
# Agent evaluated for 12 episodes of length 100000. Average return -2943.49. (0m07.26s)
#
# Epoch:  147/1000
# Agent trained by 10000 time steps (0m56.67s).
#
# Epoch:  148/1000
# Agent trained by 10000 time steps (0m57.15s).
# Agent evaluated for 12 episodes of length 100000. Average return -2923.94. (0m07.24s)
#
# Epoch:  149/1000
# Agent trained by 10000 time steps (0m56.37s).
#
# Epoch:  150/1000
# Agent trained by 10000 time steps (0m56.46s).
# Agent evaluated for 12 episodes of length 100000. Average return -2931.48. (0m07.29s)
#
# Epoch:  151/1000
# Agent trained by 10000 time steps (0m56.35s).
#
# Epoch:  152/1000
# Agent trained by 10000 time steps (0m56.61s).
# Agent evaluated for 12 episodes of length 100000. Average return -2911.97. (0m07.31s)
#
# Epoch:  153/1000
# Agent trained by 10000 time steps (0m56.82s).
#
# Epoch:  154/1000
# Agent trained by 10000 time steps (0m56.88s).
# Agent evaluated for 12 episodes of length 100000. Average return -2892.67. (0m07.28s)
#
# Epoch:  155/1000
# Agent trained by 10000 time steps (0m57.22s).
#
# Epoch:  156/1000
# Agent trained by 10000 time steps (0m57.90s).
# Agent evaluated for 12 episodes of length 100000. Average return -2951.41. (0m07.48s)
#
# Epoch:  157/1000
# Agent trained by 10000 time steps (0m57.42s).
#
# Epoch:  158/1000
# Agent trained by 10000 time steps (0m56.98s).
# Agent evaluated for 12 episodes of length 100000. Average return -2922.94. (0m07.21s)
#
# Epoch:  159/1000
# Agent trained by 10000 time steps (0m57.31s).
#
# Epoch:  160/1000
# Agent trained by 10000 time steps (0m57.05s).
# Agent evaluated for 12 episodes of length 100000. Average return -2902.44. (0m07.02s)
#
# Epoch:  161/1000
# Agent trained by 10000 time steps (0m56.60s).
#
# Epoch:  162/1000
# Agent trained by 10000 time steps (0m56.50s).
# Agent evaluated for 12 episodes of length 100000. Average return -2931.25. (0m07.24s)
#
# Epoch:  163/1000
# Agent trained by 10000 time steps (0m56.76s).
#
# Epoch:  164/1000
# Agent trained by 10000 time steps (0m57.11s).
# Agent evaluated for 12 episodes of length 100000. Average return -2970.76. (0m07.98s)
#
# Epoch:  165/1000
# Agent trained by 10000 time steps (0m57.27s).
#
# Epoch:  166/1000
# Agent trained by 10000 time steps (0m56.94s).
# Agent evaluated for 12 episodes of length 100000. Average return -2927.16. (0m07.38s)
#
# Epoch:  167/1000
# Agent trained by 10000 time steps (0m57.10s).
#
# Epoch:  168/1000
# Agent trained by 10000 time steps (0m57.53s).
# Agent evaluated for 12 episodes of length 100000. Average return -2935.44. (0m07.47s)
#
# Epoch:  169/1000
# Agent trained by 10000 time steps (0m57.02s).
#
# Epoch:  170/1000
# Agent trained by 10000 time steps (0m57.61s).
# Agent evaluated for 12 episodes of length 100000. Average return -2954.52. (0m07.56s)
#
# Epoch:  171/1000
# Agent trained by 10000 time steps (0m56.89s).
#
# Epoch:  172/1000
# Agent trained by 10000 time steps (0m57.00s).
# Agent evaluated for 12 episodes of length 100000. Average return -2920.35. (0m07.35s)
#
# Epoch:  173/1000
# Agent trained by 10000 time steps (0m57.05s).
#
# Epoch:  174/1000
# Agent trained by 10000 time steps (0m56.79s).
# Agent evaluated for 12 episodes of length 100000. Average return -2872.20. (0m06.86s)
#
# Epoch:  175/1000
# Agent trained by 10000 time steps (0m56.85s).
#
# Epoch:  176/1000
# Agent trained by 10000 time steps (0m56.97s).
# Agent evaluated for 12 episodes of length 100000. Average return -2927.23. (0m07.35s)
#
# Epoch:  177/1000
# Agent trained by 10000 time steps (0m56.72s).
#
# Epoch:  178/1000
# Agent trained by 10000 time steps (0m57.54s).
# Agent evaluated for 12 episodes of length 100000. Average return -2942.20. (0m07.53s)
#
# Epoch:  179/1000
# Agent trained by 10000 time steps (0m57.23s).
#
# Epoch:  180/1000
# Agent trained by 10000 time steps (0m57.83s).
# Agent evaluated for 12 episodes of length 100000. Average return -2954.72. (0m07.51s)
#
# Epoch:  181/1000
# Agent trained by 10000 time steps (0m57.00s).
#
# Epoch:  182/1000
# Agent trained by 10000 time steps (0m57.00s).
# Agent evaluated for 12 episodes of length 100000. Average return -2923.83. (0m07.28s)
#
# Epoch:  183/1000
# Agent trained by 10000 time steps (0m57.15s).
#
# Epoch:  184/1000
# Agent trained by 10000 time steps (0m57.78s).
# Agent evaluated for 12 episodes of length 100000. Average return -2909.48. (0m06.93s)
#
# Epoch:  185/1000
# Agent trained by 10000 time steps (0m57.02s).
#
# Epoch:  186/1000
# Agent trained by 10000 time steps (0m57.09s).
# Agent evaluated for 12 episodes of length 100000. Average return -2913.38. (0m07.17s)
#
# Epoch:  187/1000
# Agent trained by 10000 time steps (0m57.33s).
#
# Epoch:  188/1000
# Agent trained by 10000 time steps (0m57.13s).
# Agent evaluated for 12 episodes of length 100000. Average return -2970.83. (0m07.42s)
#
# Epoch:  189/1000
# Agent trained by 10000 time steps (0m56.81s).
#
# Epoch:  190/1000
# Agent trained by 10000 time steps (0m57.17s).
# Agent evaluated for 12 episodes of length 100000. Average return -2878.79. (0m06.94s)
#
# Epoch:  191/1000
# Agent trained by 10000 time steps (0m56.87s).
#
# Epoch:  192/1000
# Agent trained by 10000 time steps (0m57.54s).
# Agent evaluated for 12 episodes of length 100000. Average return -2894.39. (0m07.19s)
#
# Epoch:  193/1000
# Agent trained by 10000 time steps (0m57.76s).
#
# Epoch:  194/1000
# Agent trained by 10000 time steps (0m56.79s).
# Agent evaluated for 12 episodes of length 100000. Average return -2912.30. (0m07.23s)
#
# Epoch:  195/1000
# Agent trained by 10000 time steps (0m57.05s).
#
# Epoch:  196/1000
# Agent trained by 10000 time steps (0m57.05s).
# Agent evaluated for 12 episodes of length 100000. Average return -2932.23. (0m07.28s)
#
# Epoch:  197/1000
# Agent trained by 10000 time steps (0m57.04s).
#
# Epoch:  198/1000
# Agent trained by 10000 time steps (0m57.11s).
# Agent evaluated for 12 episodes of length 100000. Average return -2958.48. (0m07.48s)
#
# Epoch:  199/1000
# Agent trained by 10000 time steps (0m57.26s).
#
# Epoch:  200/1000
# Agent trained by 10000 time steps (0m57.50s).
# Agent evaluated for 12 episodes of length 100000. Average return -2986.81. (0m07.65s)
#
# Epoch:  201/1000
# Agent trained by 10000 time steps (0m57.91s).
#
# Epoch:  202/1000
# Agent trained by 10000 time steps (0m57.34s).
# Agent evaluated for 12 episodes of length 100000. Average return -3038.14. (0m07.80s)
#
# Epoch:  203/1000
# Agent trained by 10000 time steps (0m57.87s).
#
# Epoch:  204/1000
# Agent trained by 10000 time steps (0m57.78s).
# Agent evaluated for 12 episodes of length 100000. Average return -2926.91. (0m07.16s)
#
# Epoch:  205/1000
# Agent trained by 10000 time steps (0m57.32s).
#
# Epoch:  206/1000
# Agent trained by 10000 time steps (0m57.12s).
# Agent evaluated for 12 episodes of length 100000. Average return -2920.45. (0m07.28s)
#
# Epoch:  207/1000
# Agent trained by 10000 time steps (0m57.40s).
#
# Epoch:  208/1000
# Agent trained by 10000 time steps (0m57.20s).
# Agent evaluated for 12 episodes of length 100000. Average return -2932.97. (0m07.34s)
#
# Epoch:  209/1000
# Agent trained by 10000 time steps (0m57.19s).
#
# Epoch:  210/1000
# Agent trained by 10000 time steps (0m57.28s).
# Agent evaluated for 12 episodes of length 100000. Average return -2908.97. (0m07.11s)
#
# Epoch:  211/1000
# Agent trained by 10000 time steps (0m56.75s).
#
# Epoch:  212/1000
# Agent trained by 10000 time steps (0m57.44s).
# Agent evaluated for 12 episodes of length 100000. Average return -2978.83. (0m07.55s)
#
# Epoch:  213/1000
# Agent trained by 10000 time steps (0m57.63s).
#
# Epoch:  214/1000
# Agent trained by 10000 time steps (0m57.95s).
# Agent evaluated for 12 episodes of length 100000. Average return -2879.68. (0m06.95s)
#
# Epoch:  215/1000
# Agent trained by 10000 time steps (0m56.94s).
#
# Epoch:  216/1000
# Agent trained by 10000 time steps (0m57.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -2945.10. (0m07.14s)
#
# Epoch:  217/1000
# Agent trained by 10000 time steps (0m56.89s).
#
# Epoch:  218/1000
# Agent trained by 10000 time steps (0m57.10s).
# Agent evaluated for 12 episodes of length 100000. Average return -2940.28. (0m07.27s)
#
# Epoch:  219/1000
# Agent trained by 10000 time steps (0m57.76s).
#
# Epoch:  220/1000
# Agent trained by 10000 time steps (0m57.44s).
# Agent evaluated for 12 episodes of length 100000. Average return -2920.73. (0m07.14s)
#
# Epoch:  221/1000
# Agent trained by 10000 time steps (0m57.41s).
#
# Epoch:  222/1000
# Agent trained by 10000 time steps (0m57.16s).
# Agent evaluated for 12 episodes of length 100000. Average return -2887.77. (0m06.89s)
#
# Epoch:  223/1000
# Agent trained by 10000 time steps (0m58.09s).
#
# Epoch:  224/1000
# Agent trained by 10000 time steps (0m57.61s).
# Agent evaluated for 12 episodes of length 100000. Average return -2948.14. (0m07.19s)
#
# Epoch:  225/1000
# Agent trained by 10000 time steps (0m57.00s).
#
# Epoch:  226/1000
# Agent trained by 10000 time steps (0m57.27s).
# Agent evaluated for 12 episodes of length 100000. Average return -2973.54. (0m07.53s)
#
# Epoch:  227/1000
# Agent trained by 10000 time steps (0m56.79s).
#
# Epoch:  228/1000
# Agent trained by 10000 time steps (0m57.33s).
# Agent evaluated for 12 episodes of length 100000. Average return -2958.98. (0m07.57s)
#
# Epoch:  229/1000
# Agent trained by 10000 time steps (0m57.03s).
#
# Epoch:  230/1000
# Agent trained by 10000 time steps (0m57.42s).
# Agent evaluated for 12 episodes of length 100000. Average return -2938.81. (0m07.40s)
#
# Epoch:  231/1000
# Agent trained by 10000 time steps (0m57.55s).
#
# Epoch:  232/1000
# Agent trained by 10000 time steps (0m56.90s).
# Agent evaluated for 12 episodes of length 100000. Average return -2950.69. (0m07.25s)
#
# Epoch:  233/1000
# Agent trained by 10000 time steps (0m57.59s).
#
# Epoch:  234/1000
# Agent trained by 10000 time steps (0m57.26s).
# Agent evaluated for 12 episodes of length 100000. Average return -2982.28. (0m07.58s)
#
# Epoch:  235/1000
# Agent trained by 10000 time steps (0m57.14s).
#
# Epoch:  236/1000
# Agent trained by 10000 time steps (0m56.93s).
# Agent evaluated for 12 episodes of length 100000. Average return -2921.48. (0m07.27s)
#
# Epoch:  237/1000
# Agent trained by 10000 time steps (0m57.38s).
#
# Epoch:  238/1000
# Agent trained by 10000 time steps (0m57.10s).
# Agent evaluated for 12 episodes of length 100000. Average return -2925.63. (0m06.97s)
#
# Epoch:  239/1000
# Agent trained by 10000 time steps (0m56.82s).
#
# Epoch:  240/1000
# Agent trained by 10000 time steps (0m57.95s).
# Agent evaluated for 12 episodes of length 100000. Average return -2939.43. (0m07.34s)
#
# Epoch:  241/1000
# Agent trained by 10000 time steps (0m57.97s).
#
# Epoch:  242/1000
# Agent trained by 10000 time steps (0m57.95s).
# Agent evaluated for 12 episodes of length 100000. Average return -2938.64. (0m07.38s)
#
# Epoch:  243/1000
# Agent trained by 10000 time steps (0m57.03s).
#
# Epoch:  244/1000
# Agent trained by 10000 time steps (0m57.17s).
# Agent evaluated for 12 episodes of length 100000. Average return -2907.94. (0m07.11s)
#
# Epoch:  245/1000
# Agent trained by 10000 time steps (0m57.30s).
#
# Epoch:  246/1000
# Agent trained by 10000 time steps (0m57.38s).
# Agent evaluated for 12 episodes of length 100000. Average return -2906.14. (0m07.27s)
#
# Epoch:  247/1000
# Agent trained by 10000 time steps (0m57.40s).
#
# Epoch:  248/1000
# Agent trained by 10000 time steps (0m57.23s).
# Agent evaluated for 12 episodes of length 100000. Average return -2949.46. (0m07.45s)
#
# Epoch:  249/1000
# Agent trained by 10000 time steps (0m57.64s).
#
# Epoch:  250/1000
# Agent trained by 10000 time steps (0m57.77s).
# Agent evaluated for 12 episodes of length 100000. Average return -2903.98. (0m07.37s)
#
# Epoch:  251/1000
# Agent trained by 10000 time steps (0m57.11s).
#
# Epoch:  252/1000
# Agent trained by 10000 time steps (0m56.84s).
# Agent evaluated for 12 episodes of length 100000. Average return -2929.32. (0m07.36s)
#
# Epoch:  253/1000
# Agent trained by 10000 time steps (0m57.10s).
#
# Epoch:  254/1000
# Agent trained by 10000 time steps (0m57.30s).
# Agent evaluated for 12 episodes of length 100000. Average return -2933.27. (0m07.43s)
#
# Epoch:  255/1000
# Agent trained by 10000 time steps (0m58.04s).
#
# Epoch:  256/1000
# Agent trained by 10000 time steps (0m57.04s).
# Agent evaluated for 12 episodes of length 100000. Average return -2955.49. (0m07.43s)
#
# Epoch:  257/1000
# Agent trained by 10000 time steps (0m56.82s).
#
# Epoch:  258/1000
# Agent trained by 10000 time steps (0m57.33s).
# Agent evaluated for 12 episodes of length 100000. Average return -2940.52. (0m07.46s)
#
# Epoch:  259/1000
# Agent trained by 10000 time steps (0m57.40s).
#
# Epoch:  260/1000
# Agent trained by 10000 time steps (0m57.44s).
# Agent evaluated for 12 episodes of length 100000. Average return -2872.59. (0m06.86s)
#
# Epoch:  261/1000
# Agent trained by 10000 time steps (0m57.25s).
#
# Epoch:  262/1000
# Agent trained by 10000 time steps (0m57.54s).
# Agent evaluated for 12 episodes of length 100000. Average return -2902.73. (0m07.09s)
#
# Epoch:  263/1000
# Agent trained by 10000 time steps (0m57.24s).
#
# Epoch:  264/1000
# Agent trained by 10000 time steps (0m57.24s).
# Agent evaluated for 12 episodes of length 100000. Average return -2922.75. (0m07.03s)
#
# Epoch:  265/1000
# Agent trained by 10000 time steps (0m57.10s).
#
# Epoch:  266/1000
# Agent trained by 10000 time steps (0m57.71s).
# Agent evaluated for 12 episodes of length 100000. Average return -2955.14. (0m07.57s)
#
# Epoch:  267/1000
# Agent trained by 10000 time steps (0m58.01s).
#
# Epoch:  268/1000
# Agent trained by 10000 time steps (0m57.78s).
# Agent evaluated for 12 episodes of length 100000. Average return -2863.18. (0m06.86s)
#
# Epoch:  269/1000
# Agent trained by 10000 time steps (0m57.56s).
#
# Epoch:  270/1000
# Agent trained by 10000 time steps (0m57.22s).
# Agent evaluated for 12 episodes of length 100000. Average return -2968.63. (0m07.59s)
#
# Epoch:  271/1000
# Agent trained by 10000 time steps (0m56.90s).
#
# Epoch:  272/1000
# Agent trained by 10000 time steps (0m57.46s).
# Agent evaluated for 12 episodes of length 100000. Average return -2932.71. (0m07.46s)
#
# Epoch:  273/1000
# Agent trained by 10000 time steps (0m58.05s).
#
# Epoch:  274/1000
# Agent trained by 10000 time steps (0m57.10s).
# Agent evaluated for 12 episodes of length 100000. Average return -2873.84. (0m06.88s)
#
# Epoch:  275/1000
# Agent trained by 10000 time steps (0m57.44s).
#
# Epoch:  276/1000
# Agent trained by 10000 time steps (0m57.40s).
# Agent evaluated for 12 episodes of length 100000. Average return -2863.17. (0m06.98s)
#
# Epoch:  277/1000
# Agent trained by 10000 time steps (0m57.32s).
#
# Epoch:  278/1000
# Agent trained by 10000 time steps (0m57.14s).
# Agent evaluated for 12 episodes of length 100000. Average return -2895.77. (0m07.10s)
#
# Epoch:  279/1000
# Agent trained by 10000 time steps (0m56.95s).
#
# Epoch:  280/1000
# Agent trained by 10000 time steps (0m56.94s).
# Agent evaluated for 12 episodes of length 100000. Average return -2918.62. (0m07.31s)
#
# Epoch:  281/1000
# Agent trained by 10000 time steps (0m57.22s).
#
# Epoch:  282/1000
# Agent trained by 10000 time steps (0m58.29s).
# Agent evaluated for 12 episodes of length 100000. Average return -2900.85. (0m06.98s)
#
# Epoch:  283/1000
# Agent trained by 10000 time steps (0m57.36s).
#
# Epoch:  284/1000
# Agent trained by 10000 time steps (0m57.91s).
# Agent evaluated for 12 episodes of length 100000. Average return -2915.02. (0m07.31s)
#
# Epoch:  285/1000
# Agent trained by 10000 time steps (0m57.38s).
#
# Epoch:  286/1000
# Agent trained by 10000 time steps (0m57.13s).
# Agent evaluated for 12 episodes of length 100000. Average return -2926.51. (0m07.31s)
#
# Epoch:  287/1000
# Agent trained by 10000 time steps (0m57.64s).
#
# Epoch:  288/1000
# Agent trained by 10000 time steps (0m57.29s).
# Agent evaluated for 12 episodes of length 100000. Average return -2873.14. (0m06.82s)
#
# Epoch:  289/1000
# Agent trained by 10000 time steps (0m57.13s).
#
# Epoch:  290/1000
# Agent trained by 10000 time steps (0m57.13s).
# Agent evaluated for 12 episodes of length 100000. Average return -2921.61. (0m07.31s)
#
# Epoch:  291/1000
# Agent trained by 10000 time steps (0m56.87s).
#
# Epoch:  292/1000
# Agent trained by 10000 time steps (0m57.10s).
# Agent evaluated for 12 episodes of length 100000. Average return -2905.41. (0m07.14s)
#
# Epoch:  293/1000
# Agent trained by 10000 time steps (0m57.75s).
#
# Epoch:  294/1000
# Agent trained by 10000 time steps (0m57.75s).
# Agent evaluated for 12 episodes of length 100000. Average return -2967.52. (0m07.51s)
#
# Epoch:  295/1000
# Agent trained by 10000 time steps (0m58.11s).
#
# Epoch:  296/1000
# Agent trained by 10000 time steps (0m57.21s).
# Agent evaluated for 12 episodes of length 100000. Average return -2928.86. (0m07.13s)
#
# Epoch:  297/1000
# Agent trained by 10000 time steps (0m56.97s).
#
# Epoch:  298/1000
# Agent trained by 10000 time steps (0m57.65s).
# Agent evaluated for 12 episodes of length 100000. Average return -2914.03. (0m07.04s)
#
# Epoch:  299/1000
# Agent trained by 10000 time steps (0m57.30s).
#
# Epoch:  300/1000
# Agent trained by 10000 time steps (0m57.82s).
# Agent evaluated for 12 episodes of length 100000. Average return -2942.81. (0m07.40s)
#
# Epoch:  301/1000
# Agent trained by 10000 time steps (0m57.27s).
#
# Epoch:  302/1000
# Agent trained by 10000 time steps (0m57.22s).
# Agent evaluated for 12 episodes of length 100000. Average return -2946.54. (0m07.46s)
#
# Epoch:  303/1000
# Agent trained by 10000 time steps (0m57.51s).
#
# Epoch:  304/1000
# Agent trained by 10000 time steps (0m57.71s).
# Agent evaluated for 12 episodes of length 100000. Average return -2954.93. (0m07.55s)
#
# Epoch:  305/1000
# Agent trained by 10000 time steps (0m57.86s).
#
# Epoch:  306/1000
# Agent trained by 10000 time steps (0m57.41s).
# Agent evaluated for 12 episodes of length 100000. Average return -2897.73. (0m07.08s)
#
# Epoch:  307/1000
# Agent trained by 10000 time steps (0m57.24s).
#
# Epoch:  308/1000
# Agent trained by 10000 time steps (0m57.20s).
# Agent evaluated for 12 episodes of length 100000. Average return -2879.77. (0m07.01s)
#
# Epoch:  309/1000
# Agent trained by 10000 time steps (0m57.75s).
#
# Epoch:  310/1000
# Agent trained by 10000 time steps (0m57.46s).
# Agent evaluated for 12 episodes of length 100000. Average return -2898.54. (0m07.07s)
#
# Epoch:  311/1000
# Agent trained by 10000 time steps (0m57.01s).
#
# Epoch:  312/1000
# Agent trained by 10000 time steps (0m56.96s).
# Agent evaluated for 12 episodes of length 100000. Average return -2911.74. (0m07.13s)
#
# Epoch:  313/1000
# Agent trained by 10000 time steps (0m57.20s).
#
# Epoch:  314/1000
# Agent trained by 10000 time steps (0m57.24s).
# Agent evaluated for 12 episodes of length 100000. Average return -2956.76. (0m07.59s)
#
# Epoch:  315/1000
# Agent trained by 10000 time steps (0m57.38s).
#
# Epoch:  316/1000
# Agent trained by 10000 time steps (0m58.11s).
# Agent evaluated for 12 episodes of length 100000. Average return -2865.78. (0m06.95s)
#
# Epoch:  317/1000
# Agent trained by 10000 time steps (0m57.01s).
#
# Epoch:  318/1000
# Agent trained by 10000 time steps (0m56.93s).
# Agent evaluated for 12 episodes of length 100000. Average return -2944.01. (0m07.43s)
#
# Epoch:  319/1000
# Agent trained by 10000 time steps (0m57.13s).
#
# Epoch:  320/1000
# Agent trained by 10000 time steps (0m56.92s).
# Agent evaluated for 12 episodes of length 100000. Average return -2826.98. (0m06.65s)
#
# Epoch:  321/1000
# Agent trained by 10000 time steps (0m56.88s).
#
# Epoch:  322/1000
# Agent trained by 10000 time steps (0m57.06s).
# Agent evaluated for 12 episodes of length 100000. Average return -2894.76. (0m06.95s)
#
# Epoch:  323/1000
# Agent trained by 10000 time steps (0m56.94s).
#
# Epoch:  324/1000
# Agent trained by 10000 time steps (0m57.02s).
# Agent evaluated for 12 episodes of length 100000. Average return -2942.79. (0m07.32s)
#
# Epoch:  325/1000
# Agent trained by 10000 time steps (0m57.19s).
#
# Epoch:  326/1000
# Agent trained by 10000 time steps (0m56.98s).
# Agent evaluated for 12 episodes of length 100000. Average return -2888.22. (0m07.24s)
#
# Epoch:  327/1000
# Agent trained by 10000 time steps (0m57.07s).
#
# Epoch:  328/1000
# Agent trained by 10000 time steps (0m57.06s).
# Agent evaluated for 12 episodes of length 100000. Average return -2962.73. (0m07.56s)
#
# Epoch:  329/1000
# Agent trained by 10000 time steps (0m57.19s).
#
# Epoch:  330/1000
# Agent trained by 10000 time steps (0m56.82s).
# Agent evaluated for 12 episodes of length 100000. Average return -2905.73. (0m07.24s)
#
# Epoch:  331/1000
# Agent trained by 10000 time steps (0m57.01s).
#
# Epoch:  332/1000
# Agent trained by 10000 time steps (0m57.28s).
# Agent evaluated for 12 episodes of length 100000. Average return -2945.81. (0m07.46s)
#
# Epoch:  333/1000
# Agent trained by 10000 time steps (0m56.60s).
#
# Epoch:  334/1000
# Agent trained by 10000 time steps (0m56.76s).
# Agent evaluated for 12 episodes of length 100000. Average return -2868.49. (0m06.94s)
#
# Epoch:  335/1000
# Agent trained by 10000 time steps (0m57.03s).
#
# Epoch:  336/1000
# Agent trained by 10000 time steps (0m57.48s).
# Agent evaluated for 12 episodes of length 100000. Average return -2936.53. (0m07.59s)
#
# Epoch:  337/1000
# Agent trained by 10000 time steps (0m57.55s).
#
# Epoch:  338/1000
# Agent trained by 10000 time steps (0m57.38s).
# Agent evaluated for 12 episodes of length 100000. Average return -2963.99. (0m07.60s)
#
# Epoch:  339/1000
# Agent trained by 10000 time steps (0m57.91s).
#
# Epoch:  340/1000
# Agent trained by 10000 time steps (0m57.99s).
# Agent evaluated for 12 episodes of length 100000. Average return -2925.44. (0m07.33s)
#
# Epoch:  341/1000
# Agent trained by 10000 time steps (0m57.16s).
#
# Epoch:  342/1000
# Agent trained by 10000 time steps (0m56.97s).
# Agent evaluated for 12 episodes of length 100000. Average return -2929.89. (0m07.30s)
#
# Epoch:  343/1000
# Agent trained by 10000 time steps (0m57.28s).
#
# Epoch:  344/1000
# Agent trained by 10000 time steps (0m58.28s).
# Agent evaluated for 12 episodes of length 100000. Average return -2959.84. (0m07.66s)
#
# Epoch:  345/1000
# Agent trained by 10000 time steps (0m57.52s).
#
# Epoch:  346/1000
# Agent trained by 10000 time steps (0m57.06s).
# Agent evaluated for 12 episodes of length 100000. Average return -2933.62. (0m07.37s)
#
# Epoch:  347/1000
# Agent trained by 10000 time steps (0m57.08s).
#
# Epoch:  348/1000
# Agent trained by 10000 time steps (0m57.20s).
# Agent evaluated for 12 episodes of length 100000. Average return -2864.15. (0m06.83s)
#
# Epoch:  349/1000
# Agent trained by 10000 time steps (0m57.16s).
#
# Epoch:  350/1000
# Agent trained by 10000 time steps (0m57.28s).
# Agent evaluated for 12 episodes of length 100000. Average return -2942.54. (0m07.38s)
#
# Epoch:  351/1000
# Agent trained by 10000 time steps (0m57.02s).
#
# Epoch:  352/1000
# Agent trained by 10000 time steps (0m56.90s).
# Agent evaluated for 12 episodes of length 100000. Average return -2991.74. (0m08.01s)
#
# Epoch:  353/1000
# Agent trained by 10000 time steps (0m57.26s).
#
# Epoch:  354/1000
# Agent trained by 10000 time steps (0m57.00s).
# Agent evaluated for 12 episodes of length 100000. Average return -2936.56. (0m07.27s)
#
# Epoch:  355/1000
# Agent trained by 10000 time steps (0m57.50s).
#
# Epoch:  356/1000
# Agent trained by 10000 time steps (0m57.83s).
# Agent evaluated for 12 episodes of length 100000. Average return -2949.07. (0m07.25s)
#
# Epoch:  357/1000
# Agent trained by 10000 time steps (0m56.97s).
#
# Epoch:  358/1000
# Agent trained by 10000 time steps (0m57.10s).
# Agent evaluated for 12 episodes of length 100000. Average return -2892.75. (0m06.95s)
#
# Epoch:  359/1000
# Agent trained by 10000 time steps (0m57.47s).
#
# Epoch:  360/1000
# Agent trained by 10000 time steps (0m57.90s).
# Agent evaluated for 12 episodes of length 100000. Average return -2875.80. (0m06.94s)
#
# Epoch:  361/1000
# Agent trained by 10000 time steps (0m57.24s).
#
# Epoch:  362/1000
# Agent trained by 10000 time steps (0m57.11s).
# Agent evaluated for 12 episodes of length 100000. Average return -2909.20. (0m07.22s)
#
# Epoch:  363/1000
# Agent trained by 10000 time steps (0m57.03s).
#
# Epoch:  364/1000
# Agent trained by 10000 time steps (0m57.44s).
# Agent evaluated for 12 episodes of length 100000. Average return -2964.38. (0m07.61s)
#
# Epoch:  365/1000
# Agent trained by 10000 time steps (0m57.20s).
#
# Epoch:  366/1000
# Agent trained by 10000 time steps (0m57.09s).
# Agent evaluated for 12 episodes of length 100000. Average return -2961.50. (0m07.55s)
#
# Epoch:  367/1000
# Agent trained by 10000 time steps (0m57.09s).
#
# Epoch:  368/1000
# Agent trained by 10000 time steps (0m57.54s).
# Agent evaluated for 12 episodes of length 100000. Average return -2882.24. (0m06.90s)
#
# Epoch:  369/1000
# Agent trained by 10000 time steps (0m57.30s).
#
# Epoch:  370/1000
# Agent trained by 10000 time steps (0m57.15s).
# Agent evaluated for 12 episodes of length 100000. Average return -2934.08. (0m07.41s)
#
# Epoch:  371/1000
# Agent trained by 10000 time steps (0m57.14s).
#
# Epoch:  372/1000
# Agent trained by 10000 time steps (0m57.46s).
# Agent evaluated for 12 episodes of length 100000. Average return -2919.90. (0m07.08s)
#
# Epoch:  373/1000
# Agent trained by 10000 time steps (0m56.85s).
#
# Epoch:  374/1000
# Agent trained by 10000 time steps (0m57.13s).
# Agent evaluated for 12 episodes of length 100000. Average return -2857.97. (0m06.83s)
#
# Epoch:  375/1000
# Agent trained by 10000 time steps (0m57.55s).
#
# Epoch:  376/1000
# Agent trained by 10000 time steps (0m57.78s).
# Agent evaluated for 12 episodes of length 100000. Average return -2964.91. (0m07.91s)
#
# Epoch:  377/1000
# Agent trained by 10000 time steps (0m58.12s).
#
# Epoch:  378/1000
# Agent trained by 10000 time steps (0m57.67s).
# Agent evaluated for 12 episodes of length 100000. Average return -2918.50. (0m07.25s)
#
# Epoch:  379/1000
# Agent trained by 10000 time steps (0m57.10s).
#
# Epoch:  380/1000
# Agent trained by 10000 time steps (0m57.02s).
# Agent evaluated for 12 episodes of length 100000. Average return -2998.64. (0m07.62s)
#
# Epoch:  381/1000
# Agent trained by 10000 time steps (0m57.02s).
#
# Epoch:  382/1000
# Agent trained by 10000 time steps (0m56.84s).
# Agent evaluated for 12 episodes of length 100000. Average return -2936.98. (0m07.46s)
#
# Epoch:  383/1000
# Agent trained by 10000 time steps (0m57.08s).
#
# Epoch:  384/1000
# Agent trained by 10000 time steps (0m57.33s).
# Agent evaluated for 12 episodes of length 100000. Average return -2884.93. (0m06.86s)
#
# Epoch:  385/1000
# Agent trained by 10000 time steps (0m57.06s).
#
# Epoch:  386/1000
# Agent trained by 10000 time steps (0m57.00s).
# Agent evaluated for 12 episodes of length 100000. Average return -2894.77. (0m06.99s)
#
# Epoch:  387/1000
# Agent trained by 10000 time steps (0m57.78s).
#
# Epoch:  388/1000
# Agent trained by 10000 time steps (0m58.70s).
# Agent evaluated for 12 episodes of length 100000. Average return -2949.65. (0m07.46s)
#
# Epoch:  389/1000
# Agent trained by 10000 time steps (0m57.72s).
#
# Epoch:  390/1000
# Agent trained by 10000 time steps (0m56.96s).
# Agent evaluated for 12 episodes of length 100000. Average return -2906.21. (0m07.09s)
#
# Epoch:  391/1000
# Agent trained by 10000 time steps (0m57.21s).
#
# Epoch:  392/1000
# Agent trained by 10000 time steps (0m57.21s).
# Agent evaluated for 12 episodes of length 100000. Average return -2987.31. (0m07.57s)
#
# Epoch:  393/1000
# Agent trained by 10000 time steps (0m57.07s).
#
# Epoch:  394/1000
# Agent trained by 10000 time steps (0m56.95s).
# Agent evaluated for 12 episodes of length 100000. Average return -2889.91. (0m07.01s)
#
# Epoch:  395/1000
# Agent trained by 10000 time steps (0m57.30s).
#
# Epoch:  396/1000
# Agent trained by 10000 time steps (0m57.12s).
# Agent evaluated for 12 episodes of length 100000. Average return -2886.11. (0m06.94s)
#
# Epoch:  397/1000
# Agent trained by 10000 time steps (0m56.88s).
#
# Epoch:  398/1000
# Agent trained by 10000 time steps (0m57.66s).
# Agent evaluated for 12 episodes of length 100000. Average return -2937.46. (0m07.40s)
#
# Epoch:  399/1000
# Agent trained by 10000 time steps (0m57.05s).
#
# Epoch:  400/1000
# Agent trained by 10000 time steps (0m57.45s).
# Agent evaluated for 12 episodes of length 100000. Average return -2935.13. (0m07.28s)
#
# Epoch:  401/1000
# Agent trained by 10000 time steps (0m57.62s).
#
# Epoch:  402/1000
# Agent trained by 10000 time steps (0m57.24s).
# Agent evaluated for 12 episodes of length 100000. Average return -2883.25. (0m06.93s)
#
# Epoch:  403/1000
# Agent trained by 10000 time steps (0m57.46s).
#
# Epoch:  404/1000
# Agent trained by 10000 time steps (0m57.77s).
# Agent evaluated for 12 episodes of length 100000. Average return -2892.36. (0m07.06s)
#
# Epoch:  405/1000
# Agent trained by 10000 time steps (0m57.32s).
#
# Epoch:  406/1000
# Agent trained by 10000 time steps (0m57.11s).
# Agent evaluated for 12 episodes of length 100000. Average return -2922.84. (0m07.31s)
#
# Epoch:  407/1000
# Agent trained by 10000 time steps (0m57.24s).
#
# Epoch:  408/1000
# Agent trained by 10000 time steps (0m57.12s).
# Agent evaluated for 12 episodes of length 100000. Average return -2960.31. (0m07.32s)
#
# Epoch:  409/1000
# Agent trained by 10000 time steps (0m57.04s).
#
# Epoch:  410/1000
# Agent trained by 10000 time steps (0m57.44s).
# Agent evaluated for 12 episodes of length 100000. Average return -2949.16. (0m07.44s)
#
# Epoch:  411/1000
# Agent trained by 10000 time steps (0m57.58s).
#
# Epoch:  412/1000
# Agent trained by 10000 time steps (0m57.26s).
# Agent evaluated for 12 episodes of length 100000. Average return -2890.28. (0m07.05s)
#
# Epoch:  413/1000
# Agent trained by 10000 time steps (0m56.88s).
#
# Epoch:  414/1000
# Agent trained by 10000 time steps (0m56.93s).
# Agent evaluated for 12 episodes of length 100000. Average return -2925.57. (0m07.17s)
#
# Epoch:  415/1000
# Agent trained by 10000 time steps (0m57.01s).
#
# Epoch:  416/1000
# Agent trained by 10000 time steps (0m57.12s).
# Agent evaluated for 12 episodes of length 100000. Average return -2966.45. (0m07.51s)
#
# Epoch:  417/1000
# Agent trained by 10000 time steps (0m57.18s).
#
# Epoch:  418/1000
# Agent trained by 10000 time steps (0m57.37s).
# Agent evaluated for 12 episodes of length 100000. Average return -2888.13. (0m07.06s)
#
# Epoch:  419/1000
# Agent trained by 10000 time steps (0m57.32s).
#
# Epoch:  420/1000
# Agent trained by 10000 time steps (0m56.93s).
# Agent evaluated for 12 episodes of length 100000. Average return -2926.85. (0m07.27s)
#
# Epoch:  421/1000
# Agent trained by 10000 time steps (0m57.31s).
#
# Epoch:  422/1000
# Agent trained by 10000 time steps (0m58.05s).
# Agent evaluated for 12 episodes of length 100000. Average return -2898.63. (0m07.12s)
#
# Epoch:  423/1000
# Agent trained by 10000 time steps (0m57.59s).
#
# Epoch:  424/1000
# Agent trained by 10000 time steps (0m57.03s).
# Agent evaluated for 12 episodes of length 100000. Average return -2862.17. (0m06.83s)
#
# Epoch:  425/1000
# Agent trained by 10000 time steps (0m56.84s).
#
# Epoch:  426/1000
# Agent trained by 10000 time steps (0m57.01s).
# Agent evaluated for 12 episodes of length 100000. Average return -2876.65. (0m07.03s)
#
# Epoch:  427/1000
# Agent trained by 10000 time steps (0m57.11s).
#
# Epoch:  428/1000
# Agent trained by 10000 time steps (0m57.16s).
# Agent evaluated for 12 episodes of length 100000. Average return -2908.02. (0m07.39s)
#
# Epoch:  429/1000
# Agent trained by 10000 time steps (0m58.53s).
#
# Epoch:  430/1000
# Agent trained by 10000 time steps (0m57.68s).
# Agent evaluated for 12 episodes of length 100000. Average return -2910.82. (0m07.12s)
#
# Epoch:  431/1000
# Agent trained by 10000 time steps (0m57.03s).
#
# Epoch:  432/1000
# Agent trained by 10000 time steps (0m57.87s).
# Agent evaluated for 12 episodes of length 100000. Average return -2967.38. (0m07.57s)
#
# Epoch:  433/1000
# Agent trained by 10000 time steps (0m57.89s).
#
# Epoch:  434/1000
# Agent trained by 10000 time steps (0m57.64s).
# Agent evaluated for 12 episodes of length 100000. Average return -2912.14. (0m06.93s)
#
# Epoch:  435/1000
# Agent trained by 10000 time steps (0m57.10s).
#
# Epoch:  436/1000
# Agent trained by 10000 time steps (0m57.62s).
# Agent evaluated for 12 episodes of length 100000. Average return -2919.69. (0m07.31s)
#
# Epoch:  437/1000
# Agent trained by 10000 time steps (0m57.23s).
#
# Epoch:  438/1000
# Agent trained by 10000 time steps (0m57.78s).
# Agent evaluated for 12 episodes of length 100000. Average return -2925.84. (0m07.37s)
#
# Epoch:  439/1000
# Agent trained by 10000 time steps (0m57.15s).
#
# Epoch:  440/1000
# Agent trained by 10000 time steps (0m58.04s).
# Agent evaluated for 12 episodes of length 100000. Average return -2948.77. (0m07.38s)
#
# Epoch:  441/1000
# Agent trained by 10000 time steps (0m57.06s).
#
# Epoch:  442/1000
# Agent trained by 10000 time steps (0m58.11s).
# Agent evaluated for 12 episodes of length 100000. Average return -2980.19. (0m07.79s)
#
# Epoch:  443/1000
# Agent trained by 10000 time steps (0m58.02s).
#
# Epoch:  444/1000
# Agent trained by 10000 time steps (0m58.01s).
# Agent evaluated for 12 episodes of length 100000. Average return -2914.20. (0m07.13s)
#
# Epoch:  445/1000
# Agent trained by 10000 time steps (0m57.82s).
#
# Epoch:  446/1000
# Agent trained by 10000 time steps (0m57.98s).
# Agent evaluated for 12 episodes of length 100000. Average return -2970.85. (0m07.41s)
#
# Epoch:  447/1000
# Agent trained by 10000 time steps (0m57.80s).
#
# Epoch:  448/1000
# Agent trained by 10000 time steps (0m56.96s).
# Agent evaluated for 12 episodes of length 100000. Average return -2979.09. (0m07.50s)
#
# Epoch:  449/1000
# ...
#
# Epoch:  719/1000
# Agent trained by 10000 time steps (0m57.07s).
#
# Epoch:  720/1000
# Agent trained by 10000 time steps (0m57.64s).
# Agent evaluated for 12 episodes of length 100000. Average return -2910.77. (0m07.25s)
#
# Epoch:  721/1000
# Agent trained by 10000 time steps (0m58.02s).
#
# Epoch:  722/1000
# Agent trained by 10000 time steps (0m57.68s).
# Agent evaluated for 12 episodes of length 100000. Average return -2930.67. (0m07.50s)
#
# Epoch:  723/1000
# Agent trained by 10000 time steps (0m57.25s).
#
# Epoch:  724/1000
# Agent trained by 10000 time steps (0m57.66s).
# Agent evaluated for 12 episodes of length 100000. Average return -2904.59. (0m07.46s)
#
# Epoch:  725/1000
# Agent trained by 10000 time steps (0m57.95s).
#
# Epoch:  726/1000
# Agent trained by 10000 time steps (0m57.50s).
# Agent evaluated for 12 episodes of length 100000. Average return -2950.60. (0m07.65s)
#
# Epoch:  727/1000
# Agent trained by 10000 time steps (0m57.45s).
#
# Epoch:  728/1000
# Agent trained by 10000 time steps (0m57.55s).
# Agent evaluated for 12 episodes of length 100000. Average return -2913.64. (0m07.30s)
#
# Epoch:  729/1000
# Agent trained by 10000 time steps (0m57.75s).
#
# Epoch:  730/1000
# Agent trained by 10000 time steps (0m57.92s).
# Agent evaluated for 12 episodes of length 100000. Average return -2917.73. (0m07.41s)
#
# Epoch:  731/1000
# Agent trained by 10000 time steps (0m57.31s).
#
# Epoch:  732/1000
# Agent trained by 10000 time steps (0m57.85s).
# Agent evaluated for 12 episodes of length 100000. Average return -2911.10. (0m07.35s)
#
# Epoch:  733/1000
# Agent trained by 10000 time steps (0m57.10s).
#
# Epoch:  734/1000
# Agent trained by 10000 time steps (0m57.59s).
# Agent evaluated for 12 episodes of length 100000. Average return -2930.18. (0m07.39s)
#
# Epoch:  735/1000
# Agent trained by 10000 time steps (0m57.20s).
#
# Epoch:  736/1000
# Agent trained by 10000 time steps (0m57.87s).
# Agent evaluated for 12 episodes of length 100000. Average return -2879.77. (0m07.03s)
#
# Epoch:  737/1000
# Agent trained by 10000 time steps (0m57.31s).
#
# Epoch:  738/1000
# Agent trained by 10000 time steps (0m58.44s).
# Agent evaluated for 12 episodes of length 100000. Average return -2924.69. (0m07.48s)
#
# Epoch:  739/1000
# Agent trained by 10000 time steps (0m58.06s).
#
# Epoch:  740/1000
# Agent trained by 10000 time steps (0m58.42s).
# Agent evaluated for 12 episodes of length 100000. Average return -2878.68. (0m07.07s)
#
# Epoch:  741/1000
# Agent trained by 10000 time steps (0m57.94s).
#
# Epoch:  742/1000
# Agent trained by 10000 time steps (0m57.75s).
# Agent evaluated for 12 episodes of length 100000. Average return -2941.10. (0m07.46s)
#
# Epoch:  743/1000
# Agent trained by 10000 time steps (0m57.15s).
#
# Epoch:  744/1000
# Agent trained by 10000 time steps (0m57.49s).
# Agent evaluated for 12 episodes of length 100000. Average return -2915.38. (0m07.37s)
#
# Epoch:  745/1000
# Agent trained by 10000 time steps (0m58.28s).
#
# Epoch:  746/1000
# Agent trained by 10000 time steps (0m57.98s).
# Agent evaluated for 12 episodes of length 100000. Average return -2891.29. (0m07.13s)
#
# Epoch:  747/1000
# Agent trained by 10000 time steps (0m57.47s).
#
# Epoch:  748/1000
# Agent trained by 10000 time steps (0m57.03s).
# Agent evaluated for 12 episodes of length 100000. Average return -2929.53. (0m07.57s)
#
# Epoch:  749/1000
# Agent trained by 10000 time steps (0m57.54s).
#
# Epoch:  750/1000
# Agent trained by 10000 time steps (0m57.76s).
# Agent evaluated for 12 episodes of length 100000. Average return -2896.32. (0m07.16s)
#
# Epoch:  751/1000
# Agent trained by 10000 time steps (0m57.53s).
#
# Epoch:  752/1000
# Agent trained by 10000 time steps (0m57.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -2889.83. (0m07.18s)
#
# Epoch:  753/1000
# Agent trained by 10000 time steps (0m57.39s).
#
# Epoch:  754/1000
# Agent trained by 10000 time steps (0m58.36s).
# Agent evaluated for 12 episodes of length 100000. Average return -2905.02. (0m07.27s)
#
# Epoch:  755/1000
# Agent trained by 10000 time steps (0m57.66s).
#
# Epoch:  756/1000
# Agent trained by 10000 time steps (1m06.40s).
# Agent evaluated for 12 episodes of length 100000. Average return -2914.19. (0m09.51s)
#
# Epoch:  757/1000
# Agent trained by 10000 time steps (1m16.38s).
#
# Epoch:  758/1000
# Agent trained by 10000 time steps (1m16.85s).
# Agent evaluated for 12 episodes of length 100000. Average return -2842.15. (0m09.06s)
#
# Epoch:  759/1000
# Agent trained by 10000 time steps (1m15.04s).
#
# Epoch:  760/1000
# Agent trained by 10000 time steps (1m11.24s).
# Agent evaluated for 12 episodes of length 100000. Average return -2916.23. (0m09.56s)
#
# Epoch:  761/1000
# Agent trained by 10000 time steps (1m09.80s).
#
# Epoch:  762/1000
# Agent trained by 10000 time steps (1m02.92s).
# Agent evaluated for 12 episodes of length 100000. Average return -2866.37. (0m07.61s)
#
# Epoch:  763/1000
# Agent trained by 10000 time steps (1m02.09s).
#
# Epoch:  764/1000
# Agent trained by 10000 time steps (1m04.57s).
# Agent evaluated for 12 episodes of length 100000. Average return -2849.57. (0m07.34s)
#
# Epoch:  765/1000
# Agent trained by 10000 time steps (1m00.46s).
#
# Epoch:  766/1000
# Agent trained by 10000 time steps (1m00.66s).
# Agent evaluated for 12 episodes of length 100000. Average return -2919.05. (0m07.94s)
#
# Epoch:  767/1000
# Agent trained by 10000 time steps (1m06.96s).
#
# Epoch:  768/1000
# Agent trained by 10000 time steps (1m08.95s).
# Agent evaluated for 12 episodes of length 100000. Average return -2926.34. (0m08.70s)
#
# Epoch:  769/1000
# Agent trained by 10000 time steps (1m07.18s).
#
# Epoch:  770/1000
# Agent trained by 10000 time steps (1m01.73s).
# Agent evaluated for 12 episodes of length 100000. Average return -2862.98. (0m07.28s)
#
# Epoch:  771/1000
# Agent trained by 10000 time steps (0m59.49s).
#
# Epoch:  772/1000
# Agent trained by 10000 time steps (0m59.83s).
# Agent evaluated for 12 episodes of length 100000. Average return -2839.66. (0m07.05s)
#
# Epoch:  773/1000
# Agent trained by 10000 time steps (0m59.82s).
#
# Epoch:  774/1000
# Agent trained by 10000 time steps (1m00.48s).
# Agent evaluated for 12 episodes of length 100000. Average return -2896.52. (0m07.56s)
#
# Epoch:  775/1000
# Agent trained by 10000 time steps (1m00.04s).
#
# Epoch:  776/1000
# Agent trained by 10000 time steps (1m00.32s).
# Agent evaluated for 12 episodes of length 100000. Average return -2920.14. (0m07.66s)
#
# Epoch:  777/1000
# Agent trained by 10000 time steps (1m00.22s).
#
# Epoch:  778/1000
# Agent trained by 10000 time steps (0m59.71s).
# Agent evaluated for 12 episodes of length 100000. Average return -2874.16. (0m07.21s)
#
# Epoch:  779/1000
# Agent trained by 10000 time steps (0m59.84s).
#
# Epoch:  780/1000
# Agent trained by 10000 time steps (0m59.05s).
# Agent evaluated for 12 episodes of length 100000. Average return -2892.71. (0m07.77s)
#
# Epoch:  781/1000
# Agent trained by 10000 time steps (1m14.55s).
#
# Epoch:  782/1000
# Agent trained by 10000 time steps (1m12.89s).
# Agent evaluated for 12 episodes of length 100000. Average return -2958.20. (0m09.70s)
#
# Epoch:  783/1000
# Agent trained by 10000 time steps (1m13.42s).
#
# Epoch:  784/1000
# Agent trained by 10000 time steps (1m14.90s).
# Agent evaluated for 12 episodes of length 100000. Average return -2897.06. (0m09.31s)
#
# Epoch:  785/1000
# Agent trained by 10000 time steps (1m14.82s).
#
# Epoch:  786/1000
# Agent trained by 10000 time steps (1m14.51s).
# Agent evaluated for 12 episodes of length 100000. Average return -2938.70. (0m09.88s)
#
# Epoch:  787/1000
# Agent trained by 10000 time steps (1m15.06s).
#
# Epoch:  788/1000
# Agent trained by 10000 time steps (1m14.18s).
# Agent evaluated for 12 episodes of length 100000. Average return -2942.27. (0m09.67s)
#
# Epoch:  789/1000
# Agent trained by 10000 time steps (1m14.54s).
#
# Epoch:  790/1000
# Agent trained by 10000 time steps (1m14.77s).
# Agent evaluated for 12 episodes of length 100000. Average return -2910.83. (0m09.62s)
#
# Epoch:  791/1000
# Agent trained by 10000 time steps (1m14.26s).
#
# Epoch:  792/1000
# Agent trained by 10000 time steps (1m15.07s).
# Agent evaluated for 12 episodes of length 100000. Average return -2971.66. (0m09.92s)
#
# Epoch:  793/1000
# Agent trained by 10000 time steps (1m14.37s).
#
# Epoch:  794/1000
# Agent trained by 10000 time steps (1m14.43s).
# Agent evaluated for 12 episodes of length 100000. Average return -2965.65. (0m09.72s)
#
# Epoch:  795/1000
# Agent trained by 10000 time steps (1m15.10s).
#
# Epoch:  796/1000
# Agent trained by 10000 time steps (1m15.54s).
# Agent evaluated for 12 episodes of length 100000. Average return -2974.08. (0m09.47s)
#
# Epoch:  797/1000
# Agent trained by 10000 time steps (1m13.83s).
#
# Epoch:  798/1000
# Agent trained by 10000 time steps (1m14.79s).
# Agent evaluated for 12 episodes of length 100000. Average return -2880.05. (0m09.19s)
#
# Epoch:  799/1000
# Agent trained by 10000 time steps (1m14.80s).
#
# Epoch:  800/1000
# Agent trained by 10000 time steps (1m14.29s).
# Agent evaluated for 12 episodes of length 100000. Average return -2878.51. (0m09.32s)
#
# Epoch:  801/1000
# Agent trained by 10000 time steps (1m15.23s).
#
# Epoch:  802/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/AF_IRC.ipynb Cell 5 in 4
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/AF_IRC.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> env_param = [-3.0, 200.0, 25, 10, -1000, 0]
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/AF_IRC.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> num_epochs = 1000
# ----> <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/AF_IRC.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> agent = manager.train_agent(env_param, num_epochs=num_epochs)
#       <a href='vscode-notebook-cell:/home/lokesh/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/AF_IRC.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> agent, fig = manager.inspect_agent(env_param, figsize=(5, 2.5))
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/irc_gym/irc/manager.py:416, in IRCManager.train_agent(self, env_param, seed, num_epochs, **kwargs)
#     399 r"""Traines one agent.
#     400
#     401 Args
#    (...)
#     413
#     414 """
#     415 config = self.agent_manager.get_config({'env_param': env_param, 'seed': seed})
# --> 416 self.agent_manager.process(config, num_epochs=num_epochs, **kwargs)
#     417 return self.agent_manager.agent
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/irc_gym/jarvis/manager.py:232, in Manager.process(self, config, num_epochs, resume)
#     229     print(f"\nEpoch: {progress_str(self.epoch+1, num_epochs)}")
#     231 tic = time.time()
# --> 232 self.train()
#     233 toc = time.time()
#     234 if self._t_train is None:
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/irc_gym/irc/manager.py:159, in AgentManager.train(self)
#     151 r"""Runs RL algorithm for one epoch.
#     152
#     153 This method is only called in agent training mode. Each training epoch
#    (...)
#     156
#     157 """
#     158 tic = time.time()
# --> 159 self.agent.algo.learn(
#     160     **self.config.learn, log_interval=None, reset_num_timesteps=False,
#     161 )
#     162 toc = time.time()
#     163 if self.verbose>0:
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:307, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 def learn(
#     298     self: SelfPPO,
#     299     total_timesteps: int,
#    (...)
#     304     progress_bar: bool = False,
#     305 ) -> SelfPPO:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:248, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     244 callback.on_training_start(locals(), globals())
#     246 while self.num_timesteps < total_timesteps:
# --> 248     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     250     if continue_training is False:
#     251         break
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:175, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     172 if isinstance(self.action_space, spaces.Box):
#     173     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 175 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     177 self.num_timesteps += env.num_envs
#     179 # Give access to local variables
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:163, in VecEnv.step(self, actions)
#     156 """
#     157 Step the environments with the given action
#     158
#     159 :param actions: the action
#     160 :return: observation, reward, done, information
#     161 """
#     162 self.step_async(actions)
# --> 163 return self.step_wait()
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:54, in DummyVecEnv.step_wait(self)
#      52 def step_wait(self) -> VecEnvStepReturn:
#      53     for env_idx in range(self.num_envs):
# ---> 54         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      55             self.actions[env_idx]
#      56         )
#      57         if self.buf_dones[env_idx]:
#      58             # save final observation where user can get it, then reset
#      59             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, done, info = self.env.step(action)
#      95 self.rewards.append(reward)
#      96 if done:
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/irc_gym/irc/model.py:200, in BaseBeliefModel.step(self, action, env)
#     198         pass
#     199 # update belief
# --> 200 self.update_belief(action, observation)
#     201 belief = self.get_belief()
#     202 # update internal environment to ensure valid query states
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/irc_gym/irc/model.py:482, in FuncBeliefModel.update_belief(self, action, observation)
#     481 def update_belief(self, action, observation) -> None:
# --> 482     self.belief = self.env.update_belief(self.belief, action, observation)
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/auditoryforage/AF_env.py:311, in AuditoryForaging.update_belief(self, previous_belief, action, observation)
#     305 """
#     306 Updating belief, given previous belief, new observation, and past action.
#     307 """
#     309 lick_choice, attention_choice = self.dict_action_possible[action]
# --> 311 transition_matrix = self.find_transition_matrix()
#     312 observation_matrix = self.find_observation_matrix()
#     313 new_belief = np.zeros(self.no_nodes)
#
# File ~/OneDrive/projects/AF-IRC/auditory-foraging-IRC/stocastic-obs/exp4/auditoryforage/AF_env.py:354, in AuditoryForaging.find_transition_matrix(self)
#     352 for i in range(1,self.no_signal_nodes+1):
#     353     for j in range(self.no_signal_nodes + self.no_penalty_nodes + 1, self.no_signal_nodes + self.no_penalty_nodes + 1 + int(self.no_ITI_nodes/3)):
# --> 354         transition_matrix[(i, j, 1)] = 1/(self.no_ITI_nodes/3)
#     356 for i in range(self.no_signal_nodes+1,self.no_nodes-1):
#     357     transition_matrix[(i,i+1,1)] = 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Run the agent in an environment
# We create another environment which has the same observation space and action space as the assumed one, albeit with a different set of environment parameters.

# %%
from auditoryforage.AF_env import AuditoryForaging

# Change below line if you want to try the trained model on a different set of environemnt.
# env_param = [-3.0, 8.0, 13, 8, -8, -4]

env = AuditoryForaging(spec={'agent':{'lick_cost':env_param[0],'food_reward':env_param[1],'attention_cost_coeff':env_param[2], 'attention_cost_temp': env_param[3], 'penalty_cost': env_param[4], 'iti_cost': env_param[5]}})
episode = agent.run_one_episode(env=env, num_steps=1000, q_states = [[i] for i in range(env.no_nodes)])
fig = plot_AF_episode(episode, env)

env.spec
# Out:
# {'agent': {'lick_cost': -3.0,
#   'food_reward': 200.0,
#   'attention_cost_coeff': 25,
#   'attention_cost_temp': 10,
#   'penalty_cost': -50,
#   'iti_cost': 0,
#   'no_attention_modes': 6},
#  'experiment': {'prob_01': 0.004,
#   'no_signal_nodes': 150,
#   'no_penalty_nodes': 1,
#   'no_ITI_nodes': 150}}

# %%
# plt.imshow(episode['q_probs'].T[:300,300:550])
print(episode['rewards'])

plt.imshow(episode['q_probs'].T[152:300,:])
plt.show()
plt.stem(episode['states'])
plt.show()
# Out:
# [-26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -27.35435709 -26.28177741 -26.28177741 -26.28177741 -26.28177741
#  -26.28177741 -80.08217669]

# %% [markdown]
# We can save the episode data in an external `pickle` file.

# %%
import os, pickle

episode_path = f'store/episode_{env.get_param()}.pickle'

if os.path.exists(episode_path):
    print(f"File {episode_path} already exists, will not be overwritten.")
else:
    with open(episode_path, 'wb') as f:
        pickle.dump({
            'external_env_param': env.get_param(),
            'internal_env_param': agent.model.env.get_param(),
            **episode,
        }, f)
    print(f"Episode data saved at '{episode_path}'.")

# %% [markdown]
# # Train multiple agents for different environments

# %% [markdown]
# ## Sweep over parameter grid
#
# We define a grid of environment parameters, and train multiple agents for each of the combination using different random seeds.
#
# The following can also be done by running `demo-sweep.py` in command line:
# ```bash
# python demo-sweep.py env_param_grid=param_grids/param_grid_0.yaml num_epochs=20 count=5
# ```

# %%
env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [-50],
    [0]
]

num_epochs = 20 # number of RL epochs

#Lokesh removed the agent_seeds, and count arguments (that can be specified).
manager.train_agents(env_param_grid=env_param_grid, num_epochs=num_epochs)

# %%
report = manager.overview_agents(env_param_grid=env_param_grid)

# %% [markdown]
# # Compute likelihood of an episode

# %% [markdown]
# ## Likelihood of a specific agent
#
# Given a sequence actions and observations, we compute the likelihood of episode data conditioned on a trained agent $p(a_{1:t}, o_{1:t}|\theta_\mathrm{agent})$.

# %%
logp = agent.episode_likelihood(episode['actions'], episode['observations'])
print('log likelihood {:.3f}'.format(logp))

# %% [markdown]
# ## Likelihood of a series of agents
#
# After multiple agents have been trained on a grid of environment parameters, compute the likelihood of episode data conditioned on each agent.

# %%
from irc.utils import logmeanexp

# Uncomment below line, and comment the one after that, if you want to speciy some other episode data
# 'episode_(-3.0, 12.0, 15, 10, -8, -4).pickle'
episode_path = f'episode_{env.get_param()}.pickle'

env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [-50],
    [0]
]

logps = manager.compute_logps(episode_path=episode_path, env_param_grid=env_param_grid, min_epoch=5, min_optimality=.9)

# logps = logmeanexp(logps, axis=(-2, -1))
# print(f"Log likelihood of all environments saved in an array of shape {logps.shape}")

p = np.exp(logmeanexp(logps, axis=(-2, -1)))
p /= np.nansum(p)

print(f"Probabilities of all environments saved in an array of shape {p.shape}")

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# for episode_path in ['episode_00.pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         agent_seeds=agent_seeds, min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))
#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[2], figsize=(8, 2.5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[..., i], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$r_\mathrm{food}$'+'={:g}'.format(env_param_grid[2][i]))
#         ax.set_xticks(range(p.shape[1]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[1]])
#         ax.set_xlabel(r'$p_\mathrm{cue}$')
#         ax.set_yticks(range(p.shape[0]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[0]])
#             ax.set_ylabel(r'$p_\mathrm{appear}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
        
#         # h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         h = ax.imshow(np.log(p[i,...]))
        
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
#     plt.show()

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

episode_path_list = []
episode_path_list.append('episode_(-3.0, 16.0, 30, 14, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 25, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 25, 10, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 10, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 22, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 22, -8, -4).pickle')

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
    plt.show()

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    # h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    h = plt.imshow(np.log(p))
    
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
    plt.show()

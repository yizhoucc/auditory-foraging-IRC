# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 15, 'lines.linewidth': 2,
    'xtick.labelsize': 13, 'ytick.labelsize': 13,
    'axes.spines.top': False, 'axes.spines.right': False,
    'savefig.dpi': 1200,
})

import yaml
import numpy as np

import os
import sys
sys.path.append(f'{os.getcwd()}/irc_gym')

from irc.manager import IRCManager

from auditoryforage.utils import plot_AF_episode

# %% [markdown]
# # Train one agent for a single environment

# %%
defaults = {
    'agent.env._target_': 'auditoryforage.AF_env.AuditoryForaging',
    'agent.model._target_': 'irc.model.FuncBeliefModel',
}
manager = IRCManager(defaults=defaults)

# %% [markdown]
# ## Train an agent
# We train a rational agent for the assume environment parameter [$lick\_cost, food\_reward, attention\_cost\_coeff, attention\_cost\_temp, penalty\_cost, iti\_cost$].

# %%
env_param = [-3.0, 200.0, 25, 10, 0, 0]
num_epochs = 20

agent = manager.train_agent(env_param, num_epochs=num_epochs)
agent, fig = manager.inspect_agent(env_param, figsize=(5, 2.5))
# Out:
# No checkpoint loaded.
# Initializing an agent with internal environment parameter:
# (-3.0, 200.0, 25, 10, -8, -4)
# Agent evaluated for 12 episodes of length 20. Average return -518.63. (0m05.58s)
#
# Epoch:  1/80
# Agent trained by 40000 time steps (15m52.89s).
#
# Epoch:  2/80
# Agent trained by 40000 time steps (15m52.91s).
# Agent evaluated for 12 episodes of length 20. Average return -505.27. (0m05.33s)
#
# Epoch:  3/80
# Agent trained by 40000 time steps (15m53.48s).
#
# Epoch:  4/80
# Agent trained by 40000 time steps (15m36.17s).
# Agent evaluated for 12 episodes of length 20. Average return -478.67. (0m05.17s)
#
# Epoch:  5/80
# Agent trained by 40000 time steps (15m05.65s).
#
# Epoch:  6/80
# Agent trained by 40000 time steps (15m07.70s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.14s)
#
# Epoch:  7/80
# Agent trained by 40000 time steps (15m08.63s).
#
# Epoch:  8/80
# Agent trained by 40000 time steps (15m08.78s).
# Agent evaluated for 12 episodes of length 20. Average return -478.63. (0m05.10s)
#
# Epoch:  9/80
# Agent trained by 40000 time steps (15m06.23s).
#
# Epoch: 10/80
# Agent trained by 40000 time steps (15m09.20s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.08s)
#
# Epoch: 11/80
# Agent trained by 40000 time steps (15m09.80s).
#
# Epoch: 12/80
# Agent trained by 40000 time steps (15m12.84s).
# Agent evaluated for 12 episodes of length 20. Average return -478.62. (0m05.08s)
#
# Epoch: 13/80
# Agent trained by 40000 time steps (15m14.31s).
#
# Epoch: 14/80
# Agent trained by 40000 time steps (15m10.87s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.01s)
#
# Epoch: 15/80
# Agent trained by 40000 time steps (14m54.44s).
#
# Epoch: 16/80
# Agent trained by 40000 time steps (14m55.60s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.03s)
#
# Epoch: 17/80
# Agent trained by 40000 time steps (14m58.96s).
#
# Epoch: 18/80
# Agent trained by 40000 time steps (15m01.02s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.01s)
#
# Epoch: 19/80
# Agent trained by 40000 time steps (14m58.85s).
#
# Epoch: 20/80
# Agent trained by 40000 time steps (14m55.91s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.08s)
#
# Epoch: 21/80
# Agent trained by 40000 time steps (15m01.92s).
#
# Epoch: 22/80
# Agent trained by 40000 time steps (15m03.03s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.05s)
#
# Epoch: 23/80
# Agent trained by 40000 time steps (15m04.17s).
#
# Epoch: 24/80
# Agent trained by 40000 time steps (15m03.08s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.02s)
#
# Epoch: 25/80
# Agent trained by 40000 time steps (15m02.81s).
#
# Epoch: 26/80
# Agent trained by 40000 time steps (15m05.00s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.02s)
#
# Epoch: 27/80
# Agent trained by 40000 time steps (15m00.28s).
#
# Epoch: 28/80
# Agent trained by 40000 time steps (15m04.11s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.04s)
#
# Epoch: 29/80
# Agent trained by 40000 time steps (15m02.73s).
#
# Epoch: 30/80
# Agent trained by 40000 time steps (15m05.15s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.07s)
#
# Epoch: 31/80
# Agent trained by 40000 time steps (15m04.69s).
#
# Epoch: 32/80
# Agent trained by 40000 time steps (15m05.86s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.07s)
#
# Epoch: 33/80
# Agent trained by 40000 time steps (15m03.54s).
#
# Epoch: 34/80
# Agent trained by 40000 time steps (15m02.04s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.03s)
#
# Epoch: 35/80
# Agent trained by 40000 time steps (15m02.13s).
#
# Epoch: 36/80
# Agent trained by 40000 time steps (15m09.25s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.11s)
#
# Epoch: 37/80
# Agent trained by 40000 time steps (15m01.66s).
#
# Epoch: 38/80
# Agent trained by 40000 time steps (15m02.17s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.14s)
#
# Epoch: 39/80
# Agent trained by 40000 time steps (15m04.31s).
#
# Epoch: 40/80
# Agent trained by 40000 time steps (15m05.44s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.06s)
#
# Epoch: 41/80
# Agent trained by 40000 time steps (15m01.22s).
#
# Epoch: 42/80
# Agent trained by 40000 time steps (15m04.27s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.02s)
#
# Epoch: 43/80
# Agent trained by 40000 time steps (15m04.68s).
#
# Epoch: 44/80
# Agent trained by 40000 time steps (15m01.61s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.06s)
#
# Epoch: 45/80
# Agent trained by 40000 time steps (15m03.57s).
#
# Epoch: 46/80
# Agent trained by 40000 time steps (15m09.45s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.04s)
#
# Epoch: 47/80
# Agent trained by 40000 time steps (15m03.99s).
#
# Epoch: 48/80
# Agent trained by 40000 time steps (15m02.61s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.08s)
#
# Epoch: 49/80
# Agent trained by 40000 time steps (15m02.30s).
#
# Epoch: 50/80
# Agent trained by 40000 time steps (15m01.27s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.09s)
#
# Epoch: 51/80
# Agent trained by 40000 time steps (15m04.32s).
#
# Epoch: 52/80
# Agent trained by 40000 time steps (15m01.25s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.05s)
#
# Epoch: 53/80
# Agent trained by 40000 time steps (15m02.00s).
#
# Epoch: 54/80
# Agent trained by 40000 time steps (15m05.56s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.08s)
#
# Epoch: 55/80
# Agent trained by 40000 time steps (15m05.23s).
#
# Epoch: 56/80
# Agent trained by 40000 time steps (15m03.15s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.03s)
#
# Epoch: 57/80
# Agent trained by 40000 time steps (15m08.58s).
#
# Epoch: 58/80
# Agent trained by 40000 time steps (15m05.31s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.07s)
#
# Epoch: 59/80
# Agent trained by 40000 time steps (15m02.57s).
#
# Epoch: 60/80
# Agent trained by 40000 time steps (15m03.74s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m04.99s)
#
# Epoch: 61/80
# Agent trained by 40000 time steps (15m05.78s).
#
# Epoch: 62/80
# Agent trained by 40000 time steps (15m08.65s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.00s)
#
# Epoch: 63/80
# Agent trained by 40000 time steps (15m02.34s).
#
# Epoch: 64/80
# Agent trained by 40000 time steps (15m07.99s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.10s)
#
# Epoch: 65/80
# Agent trained by 40000 time steps (15m01.38s).
#
# Epoch: 66/80
# Agent trained by 40000 time steps (15m06.19s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.03s)
#
# Epoch: 67/80
# Agent trained by 40000 time steps (14m56.85s).
#
# Epoch: 68/80
# Agent trained by 40000 time steps (15m03.02s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.06s)
#
# Epoch: 69/80
# Agent trained by 40000 time steps (15m05.09s).
#
# Epoch: 70/80
# Agent trained by 40000 time steps (15m06.61s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m06.33s)
#
# Epoch: 71/80
# Agent trained by 40000 time steps (16m20.03s).
#
# Epoch: 72/80
# Agent trained by 40000 time steps (16m13.61s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.22s)
#
# Epoch: 73/80
# Agent trained by 40000 time steps (16m02.51s).
#
# Epoch: 74/80
# Agent trained by 40000 time steps (16m25.97s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.57s)
#
# Epoch: 75/80
# Agent trained by 40000 time steps (16m53.12s).
#
# Epoch: 76/80
# Agent trained by 40000 time steps (16m01.26s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.40s)
#
# Epoch: 77/80
# Agent trained by 40000 time steps (15m52.89s).
#
# Epoch: 78/80
# Agent trained by 40000 time steps (15m53.72s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.29s)
#
# Epoch: 79/80
# Agent trained by 40000 time steps (15m43.03s).
#
# Epoch: 80/80
# Agent trained by 40000 time steps (15m50.46s).
# Agent evaluated for 12 episodes of length 20. Average return -478.57. (0m05.24s)
# Fetching the most trained agent so far (epoch 80).
# Agent (seed 0) was trained for 80 epochs, RL optimality 100.00%.

# %% [markdown]
# ## Run the agent in an environment
# We create another environment which has the same observation space and action space as the assumed one, albeit with a different set of environment parameters.

# %%
from auditoryforage.AF_env import AuditoryForaging

# Change below line if you want to try the trained model on a different set of environemnt.
# env_param = [-3.0, 8.0, 13, 8, -8, -4]

env = AuditoryForaging(spec={'experiment': {'prob_01': 0.5},'agent':{'lick_cost':env_param[0],'food_reward':env_param[1],'attention_cost_coeff':env_param[2], 'attention_cost_temp': env_param[3], 'penalty_cost': env_param[4], 'iti_cost': env_param[5]}})
episode = agent.run_one_episode(env=env, num_steps=1000, q_states = [[i] for i in range(env.no_nodes)])
fig = plot_AF_episode(episode, env)

env.spec
# Out:
# {'experiment': {'prob_01': 0.5,
#   'no_signal_nodes': 250,
#   'no_penalty_nodes': 500,
#   'no_ITI_nodes': 300},
#  'agent': {'lick_cost': -3.0,
#   'food_reward': 200.0,
#   'attention_cost_coeff': 25,
#   'attention_cost_temp': 10,
#   'penalty_cost': -8,
#   'iti_cost': -4,
#   'no_attention_modes': 6}}

# %%
# plt.imshow(episode['q_probs'].T[:300,300:550])
plt.imshow(episode['q_probs'].T[:50,300:350])
plt.show()

# %%
plt.stem(episode['states'][250:560])
plt.show()

# %% [markdown]
# We can save the episode data in an external `pickle` file.

# %%
import os, pickle

episode_path = f'store/episode_{env.get_param()}.pickle'

if os.path.exists(episode_path):
    print(f"File {episode_path} already exists, will not be overwritten.")
else:
    with open(episode_path, 'wb') as f:
        pickle.dump({
            'external_env_param': env.get_param(),
            'internal_env_param': agent.model.env.get_param(),
            **episode,
        }, f)
    print(f"Episode data saved at '{episode_path}'.")
# Out:
# Episode data saved at 'store/episode_(-3.0, 200.0, 25, 10, -8, -4).pickle'.

# %% [markdown]
# # Train multiple agents for different environments

# %% [markdown]
# ## Sweep over parameter grid
#
# We define a grid of environment parameters, and train multiple agents for each of the combination using different random seeds.
#
# The following can also be done by running `demo-sweep.py` in command line:
# ```bash
# python demo-sweep.py env_param_grid=param_grids/param_grid_0.yaml num_epochs=20 count=5
# ```

# %%
env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [0],
    [0]
]

num_epochs = 20 # number of RL epochs

#Lokesh removed the agent_seeds, and count arguments (that can be specified).
manager.train_agents(env_param_grid=env_param_grid, num_epochs=num_epochs)
# Out:
# Use default agent seeds [0, 1, 2] for each environment parameter.
# ------------
# Processing B8D8F997 (1)...
# No checkpoint loaded.
# Initializing an agent with internal environment parameter:
# (-3.0, 16.0, 35, 10, -8, -4)
# Agent evaluated for 12 episodes of length 20. Average return -714.94. (0m05.05s)
#
# Epoch:  1/80
# Agent trained by 40000 time steps (16m35.14s).
#
# Epoch:  2/80
# Agent trained by 40000 time steps (14m57.19s).
# Agent evaluated for 12 episodes of length 20. Average return -705.52. (0m05.10s)
#
# Epoch:  3/80
# Agent trained by 40000 time steps (14m59.92s).
#
# Epoch:  4/80
# Agent trained by 40000 time steps (14m53.62s).
# Agent evaluated for 12 episodes of length 20. Average return -685.72. (0m05.49s)
#
# Epoch:  5/80
# Agent trained by 40000 time steps (14m58.41s).
#
# Epoch:  6/80
# Agent trained by 40000 time steps (15m01.39s).
# Agent evaluated for 12 episodes of length 20. Average return -670.37. (0m05.04s)
#
# Epoch:  7/80
# Agent trained by 40000 time steps (15m02.52s).
#
# Epoch:  8/80
# Agent trained by 40000 time steps (14m59.43s).
# Agent evaluated for 12 episodes of length 20. Average return -670.08. (0m04.99s)
#
# Epoch:  9/80
# Agent trained by 40000 time steps (15m02.76s).
#
# Epoch: 10/80
# Agent trained by 40000 time steps (15m14.97s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.17s)
#
# Epoch: 11/80
# Agent trained by 40000 time steps (15m00.88s).
#
# Epoch: 12/80
# Agent trained by 40000 time steps (15m09.55s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.11s)
#
# Epoch: 13/80
# Agent trained by 40000 time steps (15m11.07s).
#
# Epoch: 14/80
# Agent trained by 40000 time steps (15m10.83s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.09s)
#
# Epoch: 15/80
# Agent trained by 40000 time steps (15m10.94s).
#
# Epoch: 16/80
# Agent trained by 40000 time steps (15m14.29s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.43s)
#
# Epoch: 17/80
# Agent trained by 40000 time steps (15m13.80s).
#
# Epoch: 18/80
# Agent trained by 40000 time steps (15m06.46s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.11s)
#
# Epoch: 19/80
# Agent trained by 40000 time steps (15m21.63s).
#
# Epoch: 20/80
# Agent trained by 40000 time steps (15m20.50s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.10s)
#
# Epoch: 21/80
# Agent trained by 40000 time steps (15m16.51s).
#
# Epoch: 22/80
# Agent trained by 40000 time steps (15m21.56s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.06s)
#
# Epoch: 23/80
# Agent trained by 40000 time steps (15m18.97s).
#
# Epoch: 24/80
# Agent trained by 40000 time steps (15m08.59s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.02s)
#
# Epoch: 25/80
# Agent trained by 40000 time steps (15m12.28s).
#
# Epoch: 26/80
# Agent trained by 40000 time steps (15m14.92s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.15s)
#
# Epoch: 27/80
# Agent trained by 40000 time steps (15m15.84s).
#
# Epoch: 28/80
# Agent trained by 40000 time steps (15m09.07s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.07s)
#
# Epoch: 29/80
# Agent trained by 40000 time steps (15m12.08s).
#
# Epoch: 30/80
# Agent trained by 40000 time steps (15m04.64s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.05s)
#
# Epoch: 31/80
# Agent trained by 40000 time steps (15m11.45s).
#
# Epoch: 32/80
# Agent trained by 40000 time steps (15m11.91s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.03s)
#
# Epoch: 33/80
# Agent trained by 40000 time steps (15m13.89s).
#
# Epoch: 34/80
# Agent trained by 40000 time steps (15m19.62s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.16s)
#
# Epoch: 35/80
# Agent trained by 40000 time steps (15m22.03s).
#
# Epoch: 36/80
# Agent trained by 40000 time steps (15m18.30s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.22s)
#
# Epoch: 37/80
# Agent trained by 40000 time steps (15m15.20s).
#
# Epoch: 38/80
# Agent trained by 40000 time steps (15m16.50s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.13s)
#
# Epoch: 39/80
# Agent trained by 40000 time steps (15m16.58s).
#
# Epoch: 40/80
# Agent trained by 40000 time steps (15m16.76s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.12s)
#
# Epoch: 41/80
# Agent trained by 40000 time steps (15m20.03s).
#
# Epoch: 42/80
# Agent trained by 40000 time steps (15m15.59s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.06s)
#
# Epoch: 43/80
# Agent trained by 40000 time steps (15m24.64s).
#
# Epoch: 44/80
# Agent trained by 40000 time steps (15m19.86s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.09s)
#
# Epoch: 45/80
# Agent trained by 40000 time steps (15m20.23s).
#
# Epoch: 46/80
# Agent trained by 40000 time steps (15m14.00s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.18s)
#
# Epoch: 47/80
# Agent trained by 40000 time steps (15m14.12s).
#
# Epoch: 48/80
# Agent trained by 40000 time steps (15m19.74s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.12s)
#
# Epoch: 49/80
# Agent trained by 40000 time steps (15m11.62s).
#
# Epoch: 50/80
# Agent trained by 40000 time steps (15m13.05s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.03s)
#
# Epoch: 51/80
# Agent trained by 40000 time steps (15m12.22s).
#
# Epoch: 52/80
# Agent trained by 40000 time steps (15m10.78s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.34s)
#
# Epoch: 53/80
# Agent trained by 40000 time steps (15m17.71s).
#
# Epoch: 54/80
# Agent trained by 40000 time steps (15m14.47s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.15s)
#
# Epoch: 55/80
# Agent trained by 40000 time steps (15m13.64s).
#
# Epoch: 56/80
# Agent trained by 40000 time steps (15m16.10s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.13s)
#
# Epoch: 57/80
# Agent trained by 40000 time steps (15m20.82s).
#
# Epoch: 58/80
# Agent trained by 40000 time steps (15m14.04s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.24s)
#
# Epoch: 59/80
# Agent trained by 40000 time steps (15m20.45s).
#
# Epoch: 60/80
# Agent trained by 40000 time steps (15m16.26s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.09s)
#
# Epoch: 61/80
# Agent trained by 40000 time steps (15m09.19s).
#
# Epoch: 62/80
# Agent trained by 40000 time steps (15m07.56s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.12s)
#
# Epoch: 63/80
# Agent trained by 40000 time steps (15m10.03s).
#
# Epoch: 64/80
# Agent trained by 40000 time steps (15m12.38s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.18s)
#
# Epoch: 65/80
# Agent trained by 40000 time steps (15m10.92s).
#
# Epoch: 66/80
# Agent trained by 40000 time steps (15m15.38s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.05s)
#
# Epoch: 67/80
# Agent trained by 40000 time steps (15m09.89s).
#
# Epoch: 68/80
# Agent trained by 40000 time steps (15m19.65s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.13s)
#
# Epoch: 69/80
# Agent trained by 40000 time steps (15m21.69s).
#
# Epoch: 70/80
# Agent trained by 40000 time steps (15m20.27s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.24s)
#
# Epoch: 71/80
# Agent trained by 40000 time steps (15m22.41s).
#
# Epoch: 72/80
# Agent trained by 40000 time steps (15m17.36s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.08s)
#
# Epoch: 73/80
# Agent trained by 40000 time steps (15m06.07s).
#
# Epoch: 74/80
# Agent trained by 40000 time steps (15m17.69s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.27s)
#
# Epoch: 75/80
# Agent trained by 40000 time steps (15m13.80s).
#
# Epoch: 76/80
# Agent trained by 40000 time steps (15m04.35s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.15s)
#
# Epoch: 77/80
# Agent trained by 40000 time steps (15m12.49s).
#
# Epoch: 78/80
# Agent trained by 40000 time steps (15m10.88s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.06s)
#
# Epoch: 79/80
# Agent trained by 40000 time steps (15m12.09s).
#
# Epoch: 80/80
# Agent trained by 40000 time steps (15m15.40s).
# Agent evaluated for 12 episodes of length 20. Average return -670.00. (0m05.02s)
# ------------
# Processing 60D93875 (2)...
# No checkpoint loaded.
# Initializing an agent with internal environment parameter:
# (-3.0, 16.0, 35, 14, -8, -4)
# Agent evaluated for 12 episodes of length 20. Average return -697.58. (0m05.10s)
#
# Epoch:  1/80
# Agent trained by 40000 time steps (14m56.87s).
#
# Epoch:  2/80
# Agent trained by 40000 time steps (15m07.55s).
# Agent evaluated for 12 episodes of length 20. Average return -688.58. (0m05.09s)
#
# Epoch:  3/80
# Agent trained by 40000 time steps (15m03.86s).
#
# Epoch:  4/80
# Agent trained by 40000 time steps (15m00.27s).
# Agent evaluated for 12 episodes of length 20. Average return -675.81. (0m05.02s)
#
# Epoch:  5/80
# Agent trained by 40000 time steps (14m59.90s).
#
# Epoch:  6/80
# Agent trained by 40000 time steps (15m06.66s).
# Agent evaluated for 12 episodes of length 20. Average return -660.85. (0m05.13s)
#
# Epoch:  7/80
# Agent trained by 40000 time steps (14m59.32s).
#
# Epoch:  8/80
# Agent trained by 40000 time steps (14m58.96s).
# Agent evaluated for 12 episodes of length 20. Average return -660.52. (0m05.06s)
#
# Epoch:  9/80
# Agent trained by 40000 time steps (15m09.29s).
#
# Epoch: 10/80
# Agent trained by 40000 time steps (15m04.64s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.05s)
#
# Epoch: 11/80
# Agent trained by 40000 time steps (15m00.39s).
#
# Epoch: 12/80
# Agent trained by 40000 time steps (15m08.82s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.19s)
#
# Epoch: 13/80
# Agent trained by 40000 time steps (15m16.09s).
#
# Epoch: 14/80
# Agent trained by 40000 time steps (15m10.33s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.21s)
#
# Epoch: 15/80
# Agent trained by 40000 time steps (15m07.50s).
#
# Epoch: 16/80
# Agent trained by 40000 time steps (15m06.13s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.12s)
#
# Epoch: 17/80
# Agent trained by 40000 time steps (15m07.43s).
#
# Epoch: 18/80
# Agent trained by 40000 time steps (15m15.70s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.03s)
#
# Epoch: 19/80
# Agent trained by 40000 time steps (15m10.86s).
#
# Epoch: 20/80
# Agent trained by 40000 time steps (15m16.46s).
# Agent evaluated for 12 episodes of length 20. Average return -660.54. (0m05.07s)
#
# Epoch: 21/80
# Agent trained by 40000 time steps (15m13.42s).
#
# Epoch: 22/80
# Agent trained by 40000 time steps (15m12.78s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.38s)
#
# Epoch: 23/80
# Agent trained by 40000 time steps (15m12.16s).
#
# Epoch: 24/80
# Agent trained by 40000 time steps (15m15.37s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.10s)
#
# Epoch: 25/80
# Agent trained by 40000 time steps (15m24.14s).
#
# Epoch: 26/80
# Agent trained by 40000 time steps (15m10.74s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.10s)
#
# Epoch: 27/80
# Agent trained by 40000 time steps (15m10.92s).
#
# Epoch: 28/80
# Agent trained by 40000 time steps (15m19.08s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.06s)
#
# Epoch: 29/80
# Agent trained by 40000 time steps (15m15.44s).
#
# Epoch: 30/80
# Agent trained by 40000 time steps (15m17.54s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.07s)
#
# Epoch: 31/80
# Agent trained by 40000 time steps (15m18.72s).
#
# Epoch: 32/80
# Agent trained by 40000 time steps (15m12.59s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.02s)
#
# Epoch: 33/80
# Agent trained by 40000 time steps (15m27.78s).
#
# Epoch: 34/80
# Agent trained by 40000 time steps (15m25.83s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.21s)
#
# Epoch: 35/80
# Agent trained by 40000 time steps (15m09.62s).
#
# Epoch: 36/80
# Agent trained by 40000 time steps (15m11.47s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.09s)
#
# Epoch: 37/80
# Agent trained by 40000 time steps (15m22.24s).
#
# Epoch: 38/80
# Agent trained by 40000 time steps (15m12.30s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.03s)
#
# Epoch: 39/80
# Agent trained by 40000 time steps (15m12.29s).
#
# Epoch: 40/80
# Agent trained by 40000 time steps (15m10.34s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.14s)
#
# Epoch: 41/80
# Agent trained by 40000 time steps (15m08.85s).
#
# Epoch: 42/80
# Agent trained by 40000 time steps (15m10.09s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.07s)
#
# Epoch: 43/80
# Agent trained by 40000 time steps (15m09.27s).
#
# Epoch: 44/80
# Agent trained by 40000 time steps (15m13.08s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.10s)
#
# Epoch: 45/80
# Agent trained by 40000 time steps (15m10.73s).
#
# Epoch: 46/80
# Agent trained by 40000 time steps (15m12.49s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.08s)
#
# Epoch: 47/80
# Agent trained by 40000 time steps (15m18.18s).
#
# Epoch: 48/80
# Agent trained by 40000 time steps (15m14.46s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.13s)
#
# Epoch: 49/80
# Agent trained by 40000 time steps (15m22.19s).
#
# Epoch: 50/80
# Agent trained by 40000 time steps (15m19.10s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.24s)
#
# Epoch: 51/80
# Agent trained by 40000 time steps (15m16.85s).
#
# Epoch: 52/80
# Agent trained by 40000 time steps (15m19.72s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.14s)
#
# Epoch: 53/80
# Agent trained by 40000 time steps (15m18.90s).
#
# Epoch: 54/80
# Agent trained by 40000 time steps (15m23.40s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.15s)
#
# Epoch: 55/80
# Agent trained by 40000 time steps (15m28.49s).
#
# Epoch: 56/80
# Agent trained by 40000 time steps (15m17.35s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.04s)
#
# Epoch: 57/80
# Agent trained by 40000 time steps (15m05.71s).
#
# Epoch: 58/80
# Agent trained by 40000 time steps (15m13.02s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.09s)
#
# Epoch: 59/80
# Agent trained by 40000 time steps (15m15.41s).
#
# Epoch: 60/80
# Agent trained by 40000 time steps (15m18.45s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.02s)
#
# Epoch: 61/80
# Agent trained by 40000 time steps (15m12.28s).
#
# Epoch: 62/80
# Agent trained by 40000 time steps (15m17.73s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.04s)
#
# Epoch: 63/80
# Agent trained by 40000 time steps (15m12.26s).
#
# Epoch: 64/80
# Agent trained by 40000 time steps (15m20.85s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.05s)
#
# Epoch: 65/80
# Agent trained by 40000 time steps (15m10.47s).
#
# Epoch: 66/80
# Agent trained by 40000 time steps (15m14.95s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.05s)
#
# Epoch: 67/80
# Agent trained by 40000 time steps (15m16.88s).
#
# Epoch: 68/80
# Agent trained by 40000 time steps (15m03.74s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.04s)
#
# Epoch: 69/80
# Agent trained by 40000 time steps (15m09.63s).
#
# Epoch: 70/80
# Agent trained by 40000 time steps (15m05.96s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.03s)
#
# Epoch: 71/80
# Agent trained by 40000 time steps (15m08.99s).
#
# Epoch: 72/80
# Agent trained by 40000 time steps (15m12.90s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.24s)
#
# Epoch: 73/80
# Agent trained by 40000 time steps (15m16.70s).
#
# Epoch: 74/80
# Agent trained by 40000 time steps (15m15.56s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.05s)
#
# Epoch: 75/80
# Agent trained by 40000 time steps (15m19.26s).
#
# Epoch: 76/80
# Agent trained by 40000 time steps (15m14.34s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.07s)
#
# Epoch: 77/80
# Agent trained by 40000 time steps (15m09.92s).
#
# Epoch: 78/80
# Agent trained by 40000 time steps (15m11.03s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.25s)
#
# Epoch: 79/80
# Agent trained by 40000 time steps (15m17.63s).
#
# Epoch: 80/80
# Agent trained by 40000 time steps (15m05.85s).
# Agent evaluated for 12 episodes of length 20. Average return -660.50. (0m05.14s)
# ------------
# Processing 8FEF3749 (3)...
# No checkpoint loaded.
# Initializing an agent with internal environment parameter:
# (-3.0, 16.0, 20, 10, -8, -4)
# Agent evaluated for 12 episodes of length 20. Average return -417.87. (0m05.11s)
#
# Epoch:  1/80
# Agent trained by 40000 time steps (15m03.27s).
#
# Epoch:  2/80
# Agent trained by 40000 time steps (14m55.74s).
# Agent evaluated for 12 episodes of length 20. Average return -394.38. (0m05.05s)
#
# Epoch:  3/80
# Agent trained by 40000 time steps (14m58.70s).
#
# Epoch:  4/80
# Agent trained by 40000 time steps (15m02.54s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.07s)
#
# Epoch:  5/80
# Agent trained by 40000 time steps (15m00.62s).
#
# Epoch:  6/80
# Agent trained by 40000 time steps (15m08.11s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.21s)
#
# Epoch:  7/80
# Agent trained by 40000 time steps (14m58.83s).
#
# Epoch:  8/80
# Agent trained by 40000 time steps (15m01.08s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.10s)
#
# Epoch:  9/80
# Agent trained by 40000 time steps (15m05.98s).
#
# Epoch: 10/80
# Agent trained by 40000 time steps (14m59.20s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.14s)
#
# Epoch: 11/80
# Agent trained by 40000 time steps (15m10.17s).
#
# Epoch: 12/80
# Agent trained by 40000 time steps (15m16.90s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.05s)
#
# Epoch: 13/80
# Agent trained by 40000 time steps (15m11.80s).
#
# Epoch: 14/80
# Agent trained by 40000 time steps (15m23.28s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.17s)
#
# Epoch: 15/80
# Agent trained by 40000 time steps (15m06.24s).
#
# Epoch: 16/80
# Agent trained by 40000 time steps (15m11.56s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.06s)
#
# Epoch: 17/80
# Agent trained by 40000 time steps (15m09.48s).
#
# Epoch: 18/80
# Agent trained by 40000 time steps (15m11.59s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.00s)
#
# Epoch: 19/80
# Agent trained by 40000 time steps (15m07.35s).
#
# Epoch: 20/80
# Agent trained by 40000 time steps (15m14.85s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.12s)
#
# Epoch: 21/80
# Agent trained by 40000 time steps (15m18.24s).
#
# Epoch: 22/80
# Agent trained by 40000 time steps (15m17.49s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.04s)
#
# Epoch: 23/80
# Agent trained by 40000 time steps (15m12.60s).
#
# Epoch: 24/80
# Agent trained by 40000 time steps (15m16.51s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.05s)
#
# Epoch: 25/80
# Agent trained by 40000 time steps (15m09.48s).
#
# Epoch: 26/80
# Agent trained by 40000 time steps (15m10.43s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.03s)
#
# Epoch: 27/80
# Agent trained by 40000 time steps (15m20.95s).
#
# Epoch: 28/80
# Agent trained by 40000 time steps (15m17.14s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.81s)
#
# Epoch: 29/80
# Agent trained by 40000 time steps (15m12.56s).
#
# Epoch: 30/80
# Agent trained by 40000 time steps (15m16.42s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.10s)
#
# Epoch: 31/80
# Agent trained by 40000 time steps (15m16.93s).
#
# Epoch: 32/80
# Agent trained by 40000 time steps (15m09.26s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.25s)
#
# Epoch: 33/80
# Agent trained by 40000 time steps (15m18.29s).
#
# Epoch: 34/80
# Agent trained by 40000 time steps (15m06.15s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.05s)
#
# Epoch: 35/80
# Agent trained by 40000 time steps (15m08.93s).
#
# Epoch: 36/80
# Agent trained by 40000 time steps (15m16.47s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.09s)
#
# Epoch: 37/80
# Agent trained by 40000 time steps (15m14.15s).
#
# Epoch: 38/80
# Agent trained by 40000 time steps (15m10.75s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.07s)
#
# Epoch: 39/80
# Agent trained by 40000 time steps (15m12.45s).
#
# Epoch: 40/80
# Agent trained by 40000 time steps (15m10.59s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.06s)
#
# Epoch: 41/80
# Agent trained by 40000 time steps (15m14.86s).
#
# Epoch: 42/80
# Agent trained by 40000 time steps (15m09.84s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.01s)
#
# Epoch: 43/80
# Agent trained by 40000 time steps (15m18.51s).
#
# Epoch: 44/80
# Agent trained by 40000 time steps (15m08.84s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.02s)
#
# Epoch: 45/80
# Agent trained by 40000 time steps (15m14.94s).
#
# Epoch: 46/80
# Agent trained by 40000 time steps (15m22.53s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.19s)
#
# Epoch: 47/80
# Agent trained by 40000 time steps (15m18.48s).
#
# Epoch: 48/80
# Agent trained by 40000 time steps (15m16.05s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.36s)
#
# Epoch: 49/80
# Agent trained by 40000 time steps (15m15.19s).
#
# Epoch: 50/80
# Agent trained by 40000 time steps (15m08.84s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.07s)
#
# Epoch: 51/80
# Agent trained by 40000 time steps (15m11.24s).
#
# Epoch: 52/80
# Agent trained by 40000 time steps (15m19.75s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.08s)
#
# Epoch: 53/80
# Agent trained by 40000 time steps (15m14.42s).
#
# Epoch: 54/80
# Agent trained by 40000 time steps (15m13.20s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.06s)
#
# Epoch: 55/80
# Agent trained by 40000 time steps (15m13.23s).
#
# Epoch: 56/80
# Agent trained by 40000 time steps (15m15.17s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.17s)
#
# Epoch: 57/80
# Agent trained by 40000 time steps (15m10.44s).
#
# Epoch: 58/80
# Agent trained by 40000 time steps (15m09.35s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.04s)
#
# Epoch: 59/80
# Agent trained by 40000 time steps (15m14.81s).
#
# Epoch: 60/80
# Agent trained by 40000 time steps (15m13.49s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.04s)
#
# Epoch: 61/80
# Agent trained by 40000 time steps (15m09.99s).
#
# Epoch: 62/80
# Agent trained by 40000 time steps (15m13.82s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.02s)
#
# Epoch: 63/80
# Agent trained by 40000 time steps (15m09.53s).
#
# Epoch: 64/80
# Agent trained by 40000 time steps (15m07.45s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.01s)
#
# Epoch: 65/80
# Agent trained by 40000 time steps (15m08.38s).
#
# Epoch: 66/80
# Agent trained by 40000 time steps (15m13.55s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.08s)
#
# Epoch: 67/80
# Agent trained by 40000 time steps (15m11.36s).
#
# Epoch: 68/80
# Agent trained by 40000 time steps (15m12.54s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.03s)
#
# Epoch: 69/80
# Agent trained by 40000 time steps (15m15.20s).
#
# Epoch: 70/80
# Agent trained by 40000 time steps (15m10.22s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.02s)
#
# Epoch: 71/80
# Agent trained by 40000 time steps (15m08.89s).
#
# Epoch: 72/80
# Agent trained by 40000 time steps (15m17.32s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.03s)
#
# Epoch: 73/80
# Agent trained by 40000 time steps (15m07.96s).
#
# Epoch: 74/80
# Agent trained by 40000 time steps (15m18.88s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.04s)
#
# Epoch: 75/80
# Agent trained by 40000 time steps (15m13.07s).
#
# Epoch: 76/80
# Agent trained by 40000 time steps (15m21.79s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.27s)
#
# Epoch: 77/80
# Agent trained by 40000 time steps (15m10.02s).
#
# Epoch: 78/80
# Agent trained by 40000 time steps (15m15.87s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.06s)
#
# Epoch: 79/80
# Agent trained by 40000 time steps (15m10.44s).
#
# Epoch: 80/80
# Agent trained by 40000 time steps (15m18.99s).
# Agent evaluated for 12 episodes of length 20. Average return -382.86. (0m05.49s)
# ------------
# Processing 19563197 (4)...
# No checkpoint loaded.
# Initializing an agent with internal environment parameter:
# (-3.0, 16.0, 30, 10, -8, -4)
# Agent evaluated for 12 episodes of length 20. Average return -616.85. (0m05.26s)
#
# Epoch:  1/80
# Agent trained by 40000 time steps (15m07.29s).
#
# Epoch:  2/80
# Agent trained by 40000 time steps (15m07.45s).
# Agent evaluated for 12 episodes of length 20. Average return -606.15. (0m05.22s)
#
# Epoch:  3/80
# Agent trained by 40000 time steps (15m00.75s).
#
# Epoch:  4/80
# Agent trained by 40000 time steps (15m05.35s).
# Agent evaluated for 12 episodes of length 20. Average return -575.49. (0m05.12s)
#
# Epoch:  5/80
# Agent trained by 40000 time steps (15m16.09s).
#
# Epoch:  6/80
# Agent trained by 40000 time steps (15m01.00s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.60s)
#
# Epoch:  7/80
# Agent trained by 40000 time steps (15m05.30s).
#
# Epoch:  8/80
# Agent trained by 40000 time steps (15m01.45s).
# Agent evaluated for 12 episodes of length 20. Average return -574.38. (0m05.06s)
#
# Epoch:  9/80
# Agent trained by 40000 time steps (15m06.67s).
#
# Epoch: 10/80
# Agent trained by 40000 time steps (15m09.53s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.03s)
#
# Epoch: 11/80
# Agent trained by 40000 time steps (15m01.81s).
#
# Epoch: 12/80
# Agent trained by 40000 time steps (15m04.30s).
# Agent evaluated for 12 episodes of length 20. Average return -574.39. (0m05.06s)
#
# Epoch: 13/80
# Agent trained by 40000 time steps (15m07.19s).
#
# Epoch: 14/80
# Agent trained by 40000 time steps (15m08.21s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.14s)
#
# Epoch: 15/80
# Agent trained by 40000 time steps (15m02.84s).
#
# Epoch: 16/80
# Agent trained by 40000 time steps (15m15.83s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.26s)
#
# Epoch: 17/80
# Agent trained by 40000 time steps (15m13.42s).
#
# Epoch: 18/80
# Agent trained by 40000 time steps (15m19.71s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.02s)
#
# Epoch: 19/80
# Agent trained by 40000 time steps (15m03.63s).
#
# Epoch: 20/80
# Agent trained by 40000 time steps (15m08.11s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.13s)
#
# Epoch: 21/80
# Agent trained by 40000 time steps (15m12.37s).
#
# Epoch: 22/80
# Agent trained by 40000 time steps (15m13.56s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.27s)
#
# Epoch: 23/80
# Agent trained by 40000 time steps (15m13.46s).
#
# Epoch: 24/80
# Agent trained by 40000 time steps (15m08.91s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.11s)
#
# Epoch: 25/80
# Agent trained by 40000 time steps (15m14.48s).
#
# Epoch: 26/80
# Agent trained by 40000 time steps (15m16.46s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.49s)
#
# Epoch: 27/80
# Agent trained by 40000 time steps (15m11.06s).
#
# Epoch: 28/80
# Agent trained by 40000 time steps (15m09.62s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.04s)
#
# Epoch: 29/80
# Agent trained by 40000 time steps (15m18.11s).
#
# Epoch: 30/80
# Agent trained by 40000 time steps (15m11.00s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.02s)
#
# Epoch: 31/80
# Agent trained by 40000 time steps (15m11.62s).
#
# Epoch: 32/80
# Agent trained by 40000 time steps (15m10.63s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.05s)
#
# Epoch: 33/80
# Agent trained by 40000 time steps (15m16.14s).
#
# Epoch: 34/80
# Agent trained by 40000 time steps (15m20.62s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.10s)
#
# Epoch: 35/80
# Agent trained by 40000 time steps (15m17.64s).
#
# Epoch: 36/80
# Agent trained by 40000 time steps (15m11.93s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.05s)
#
# Epoch: 37/80
# Agent trained by 40000 time steps (15m11.20s).
#
# Epoch: 38/80
# Agent trained by 40000 time steps (15m18.75s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.26s)
#
# Epoch: 39/80
# Agent trained by 40000 time steps (15m17.72s).
#
# Epoch: 40/80
# Agent trained by 40000 time steps (15m12.00s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.07s)
#
# Epoch: 41/80
# Agent trained by 40000 time steps (15m09.85s).
#
# Epoch: 42/80
# Agent trained by 40000 time steps (15m19.38s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.15s)
#
# Epoch: 43/80
# Agent trained by 40000 time steps (15m06.47s).
#
# Epoch: 44/80
# Agent trained by 40000 time steps (15m08.92s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.09s)
#
# Epoch: 45/80
# Agent trained by 40000 time steps (15m12.10s).
#
# Epoch: 46/80
# Agent trained by 40000 time steps (15m21.72s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.23s)
#
# Epoch: 47/80
# Agent trained by 40000 time steps (15m16.66s).
#
# Epoch: 48/80
# Agent trained by 40000 time steps (15m15.77s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.44s)
#
# Epoch: 49/80
# Agent trained by 40000 time steps (15m09.09s).
#
# Epoch: 50/80
# Agent trained by 40000 time steps (15m08.76s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.10s)
#
# Epoch: 51/80
# Agent trained by 40000 time steps (15m20.35s).
#
# Epoch: 52/80
# Agent trained by 40000 time steps (15m13.20s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.74s)
#
# Epoch: 53/80
# Agent trained by 40000 time steps (15m23.44s).
#
# Epoch: 54/80
# Agent trained by 40000 time steps (15m18.31s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.04s)
#
# Epoch: 55/80
# Agent trained by 40000 time steps (15m08.92s).
#
# Epoch: 56/80
# Agent trained by 40000 time steps (15m11.75s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.09s)
#
# Epoch: 57/80
# Agent trained by 40000 time steps (15m09.75s).
#
# Epoch: 58/80
# Agent trained by 40000 time steps (15m07.84s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.02s)
#
# Epoch: 59/80
# Agent trained by 40000 time steps (15m13.37s).
#
# Epoch: 60/80
# Agent trained by 40000 time steps (15m08.61s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.07s)
#
# Epoch: 61/80
# Agent trained by 40000 time steps (15m06.85s).
#
# Epoch: 62/80
# Agent trained by 40000 time steps (15m12.29s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.03s)
#
# Epoch: 63/80
# Agent trained by 40000 time steps (15m11.31s).
#
# Epoch: 64/80
# Agent trained by 40000 time steps (15m16.50s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.08s)
#
# Epoch: 65/80
# Agent trained by 40000 time steps (15m09.15s).
#
# Epoch: 66/80
# Agent trained by 40000 time steps (15m17.08s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.67s)
#
# Epoch: 67/80
# Agent trained by 40000 time steps (15m16.91s).
#
# Epoch: 68/80
# Agent trained by 40000 time steps (15m17.24s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.05s)
#
# Epoch: 69/80
# Agent trained by 40000 time steps (15m11.40s).
#
# Epoch: 70/80
# Agent trained by 40000 time steps (15m09.52s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.07s)
#
# Epoch: 71/80
# Agent trained by 40000 time steps (15m07.25s).
#
# Epoch: 72/80
# Agent trained by 40000 time steps (15m08.89s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.04s)
#
# Epoch: 73/80
# Agent trained by 40000 time steps (15m28.25s).
#
# Epoch: 74/80
# Agent trained by 40000 time steps (15m19.34s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.08s)
#
# Epoch: 75/80
# Agent trained by 40000 time steps (15m17.10s).
#
# Epoch: 76/80
# Agent trained by 40000 time steps (15m15.35s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.07s)
#
# Epoch: 77/80
# Agent trained by 40000 time steps (15m16.63s).
#
# Epoch: 78/80
# Agent trained by 40000 time steps (15m17.79s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.07s)
#
# Epoch: 79/80
# Agent trained by 40000 time steps (15m22.30s).
#
# Epoch: 80/80
# Agent trained by 40000 time steps (15m11.18s).
# Agent evaluated for 12 episodes of length 20. Average return -574.29. (0m05.07s)
# ------------
# Processing CF1C3361 (5)...
# No checkpoint loaded.
# Initializing an agent with internal environment parameter:
# (-3.0, 16.0, 40, 10, -8, -4)
# Agent evaluated for 12 episodes of length 20. Average return -809.87. (0m05.09s)
#
# Epoch:  1/80
# Agent trained by 40000 time steps (14m59.81s).
#
# Epoch:  2/80
# Agent trained by 40000 time steps (15m07.17s).
# Agent evaluated for 12 episodes of length 20. Average return -802.42. (0m05.06s)
#
# Epoch:  3/80
# Agent trained by 40000 time steps (15m01.36s).
#
# Epoch:  4/80
# Agent trained by 40000 time steps (15m09.78s).
# Agent evaluated for 12 episodes of length 20. Average return -794.50. (0m05.27s)
#
# Epoch:  5/80
# Agent trained by 40000 time steps (15m12.05s).
#
# Epoch:  6/80
# Agent trained by 40000 time steps (14m55.61s).
# Agent evaluated for 12 episodes of length 20. Average return -766.69. (0m04.98s)
#
# Epoch:  7/80
# Agent trained by 40000 time steps (15m05.15s).
#
# Epoch:  8/80
# Agent trained by 40000 time steps (14m59.85s).
# Agent evaluated for 12 episodes of length 20. Average return -765.75. (0m05.17s)
#
# Epoch:  9/80
# Agent trained by 40000 time steps (15m10.41s).
#
# Epoch: 10/80
# Agent trained by 40000 time steps (15m10.68s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.18s)
#
# Epoch: 11/80
# Agent trained by 40000 time steps (15m05.36s).
#
# Epoch: 12/80
# Agent trained by 40000 time steps (15m08.10s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.12s)
#
# Epoch: 13/80
# Agent trained by 40000 time steps (15m11.72s).
#
# Epoch: 14/80
# Agent trained by 40000 time steps (15m13.61s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.09s)
#
# Epoch: 15/80
# Agent trained by 40000 time steps (15m14.01s).
#
# Epoch: 16/80
# Agent trained by 40000 time steps (15m04.80s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.10s)
#
# Epoch: 17/80
# Agent trained by 40000 time steps (15m15.98s).
#
# Epoch: 18/80
# Agent trained by 40000 time steps (15m15.79s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.10s)
#
# Epoch: 19/80
# Agent trained by 40000 time steps (15m04.12s).
#
# Epoch: 20/80
# Agent trained by 40000 time steps (15m14.03s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.15s)
#
# Epoch: 21/80
# Agent trained by 40000 time steps (15m19.10s).
#
# Epoch: 22/80
# Agent trained by 40000 time steps (15m09.08s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.05s)
#
# Epoch: 23/80
# Agent trained by 40000 time steps (15m08.27s).
#
# Epoch: 24/80
# Agent trained by 40000 time steps (15m14.39s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.07s)
#
# Epoch: 25/80
# Agent trained by 40000 time steps (15m08.42s).
#
# Epoch: 26/80
# Agent trained by 40000 time steps (15m13.29s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.03s)
#
# Epoch: 27/80
# Agent trained by 40000 time steps (15m11.58s).
#
# Epoch: 28/80
# Agent trained by 40000 time steps (15m06.80s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.00s)
#
# Epoch: 29/80
# Agent trained by 40000 time steps (15m05.42s).
#
# Epoch: 30/80
# Agent trained by 40000 time steps (15m10.27s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.08s)
#
# Epoch: 31/80
# Agent trained by 40000 time steps (15m00.29s).
#
# Epoch: 32/80
# Agent trained by 40000 time steps (15m12.80s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.09s)
#
# Epoch: 33/80
# Agent trained by 40000 time steps (15m12.11s).
#
# Epoch: 34/80
# Agent trained by 40000 time steps (15m11.40s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.03s)
#
# Epoch: 35/80
# Agent trained by 40000 time steps (15m18.21s).
#
# Epoch: 36/80
# Agent trained by 40000 time steps (15m12.87s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.09s)
#
# Epoch: 37/80
# Agent trained by 40000 time steps (15m11.67s).
#
# Epoch: 38/80
# Agent trained by 40000 time steps (15m09.32s).
# Agent evaluated for 12 episodes of length 20. Average return -765.72. (0m05.06s)
#
# Epoch: 39/80
# Agent trained by 40000 time steps (15m07.02s).
#
# Epoch: 40/80
# Agent trained by 40000 time steps (15m13.28s).
# Agent evaluated for 12 episodes of length 20. Average return -779.45. (0m05.10s)
#
# Epoch: 41/80
# Agent trained by 40000 time steps (16m36.85s).
#
# Epoch: 42/80
# Agent trained by 40000 time steps (16m39.61s).
# Agent evaluated for 12 episodes of length 20. Average return -784.96. (0m05.67s)
#
# Epoch: 43/80
# Agent trained by 40000 time steps (16m39.41s).
#
# Epoch: 44/80
# Agent trained by 40000 time steps (16m34.91s).
# Agent evaluated for 12 episodes of length 20. Average return -785.38. (0m05.59s)
#
# Epoch: 45/80
# Agent trained by 40000 time steps (16m43.32s).
#
# Epoch: 46/80
# Agent trained by 40000 time steps (16m47.60s).
# Agent evaluated for 12 episodes of length 20. Average return -780.42. (0m05.60s)
#
# Epoch: 47/80
# Agent trained by 40000 time steps (16m43.31s).
#
# Epoch: 48/80
# Agent trained by 40000 time steps (16m40.60s).
# Agent evaluated for 12 episodes of length 20. Average return -784.83. (0m05.66s)
#
# Epoch: 49/80
# Agent trained by 40000 time steps (16m45.29s).
#
# Epoch: 50/80
# Agent trained by 40000 time steps (16m47.39s).
# Agent evaluated for 12 episodes of length 20. Average return -792.60. (0m05.65s)
#
# Epoch: 51/80
# Agent trained by 40000 time steps (16m39.27s).
#
# Epoch: 52/80
# Agent trained by 40000 time steps (16m40.63s).
# Agent evaluated for 12 episodes of length 20. Average return -803.56. (0m05.64s)
#
# Epoch: 53/80
# Agent trained by 40000 time steps (16m35.65s).
#
# Epoch: 54/80
# Agent trained by 40000 time steps (16m37.08s).
# Agent evaluated for 12 episodes of length 20. Average return -804.26. (0m05.62s)
#
# Epoch: 55/80
# Agent trained by 40000 time steps (16m36.95s).
#
# Epoch: 56/80
# Agent trained by 40000 time steps (16m34.02s).
# Agent evaluated for 12 episodes of length 20. Average return -803.62. (0m05.63s)
#
# Epoch: 57/80
# Agent trained by 40000 time steps (16m44.06s).
#
# Epoch: 58/80
# Agent trained by 40000 time steps (16m43.19s).
# Agent evaluated for 12 episodes of length 20. Average return -796.95. (0m05.62s)
#
# Epoch: 59/80
# Agent trained by 40000 time steps (16m41.66s).
#
# Epoch: 60/80
# Agent trained by 40000 time steps (16m42.56s).
# Agent evaluated for 12 episodes of length 20. Average return -799.65. (0m05.61s)
#
# Epoch: 61/80
# Agent trained by 40000 time steps (16m43.76s).
#
# Epoch: 62/80
# Agent trained by 40000 time steps (16m40.30s).
# Agent evaluated for 12 episodes of length 20. Average return -798.88. (0m05.60s)
#
# Epoch: 63/80
# Agent trained by 40000 time steps (16m40.49s).
#
# Epoch: 64/80
# Agent trained by 40000 time steps (16m42.24s).
# Agent evaluated for 12 episodes of length 20. Average return -806.59. (0m05.56s)
#
# Epoch: 65/80
# Agent trained by 40000 time steps (16m41.24s).
#
# Epoch: 66/80
# Agent trained by 40000 time steps (16m38.33s).
# Agent evaluated for 12 episodes of length 20. Average return -798.12. (0m05.77s)
#
# Epoch: 67/80
# Agent trained by 40000 time steps (16m37.34s).
#
# Epoch: 68/80
# Agent trained by 40000 time steps (16m36.45s).
# Agent evaluated for 12 episodes of length 20. Average return -806.31. (0m05.64s)
#
# Epoch: 69/80
# Agent trained by 40000 time steps (16m40.21s).
#
# Epoch: 70/80
# Agent trained by 40000 time steps (16m33.00s).
# Agent evaluated for 12 episodes of length 20. Average return -805.54. (0m05.56s)
#
# Epoch: 71/80
# Agent trained by 40000 time steps (16m34.44s).
#
# Epoch: 72/80
# Agent trained by 40000 time steps (16m30.86s).
# Agent evaluated for 12 episodes of length 20. Average return -800.55. (0m05.59s)
#
# Epoch: 73/80
# Agent trained by 40000 time steps (16m39.69s).
#
# Epoch: 74/80
# Agent trained by 40000 time steps (16m43.89s).
# Agent evaluated for 12 episodes of length 20. Average return -800.69. (0m05.60s)
#
# Epoch: 75/80
# Agent trained by 40000 time steps (16m37.84s).
#
# Epoch: 76/80
# Agent trained by 40000 time steps (16m35.39s).
# Agent evaluated for 12 episodes of length 20. Average return -800.55. (0m05.59s)
#
# Epoch: 77/80
# Agent trained by 40000 time steps (16m36.87s).
#
# Epoch: 78/80
# Agent trained by 40000 time steps (16m36.61s).
# Agent evaluated for 12 episodes of length 20. Average return -802.36. (0m05.58s)
#
# Epoch: 79/80
# Agent trained by 40000 time steps (16m34.00s).
#
# Epoch: 80/80
# Agent trained by 40000 time steps (16m39.12s).
# Agent evaluated for 12 episodes of length 20. Average return -804.60. (0m05.72s)
# ------------
# Processing A24700D9 (6)...
# No checkpoint loaded.
# Initializing an agent with internal environment parameter:
# (-3.0, 16.0, 40, 6, -8, -4)
# Agent evaluated for 12 episodes of length 20. Average return -849.42. (0m05.82s)
#
# Epoch:  1/80
# Agent trained by 40000 time steps (16m30.10s).
#
# Epoch:  2/80
# Agent trained by 40000 time steps (16m36.32s).
# Agent evaluated for 12 episodes of length 20. Average return -841.96. (0m05.63s)
#
# Epoch:  3/80
# Agent trained by 40000 time steps (16m37.43s).
#
# Epoch:  4/80
# Agent trained by 40000 time steps (16m31.60s).
# Agent evaluated for 12 episodes of length 20. Average return -827.15. (0m05.62s)
#
# Epoch:  5/80
# Agent trained by 40000 time steps (16m34.45s).
#
# Epoch:  6/80
# Agent trained by 40000 time steps (16m41.63s).
# Agent evaluated for 12 episodes of length 20. Average return -792.56. (0m05.62s)
#
# Epoch:  7/80
# Agent trained by 40000 time steps (16m27.45s).
#
# Epoch:  8/80
# Agent trained by 40000 time steps (16m35.46s).
# Agent evaluated for 12 episodes of length 20. Average return -791.73. (0m05.63s)
#
# Epoch:  9/80
# Agent trained by 40000 time steps (16m32.14s).
#
# Epoch: 10/80
# Agent trained by 40000 time steps (16m35.95s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.58s)
#
# Epoch: 11/80
# Agent trained by 40000 time steps (16m34.93s).
#
# Epoch: 12/80
# Agent trained by 40000 time steps (16m43.96s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.60s)
#
# Epoch: 13/80
# Agent trained by 40000 time steps (16m36.61s).
#
# Epoch: 14/80
# Agent trained by 40000 time steps (16m44.00s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.62s)
#
# Epoch: 15/80
# Agent trained by 40000 time steps (16m32.96s).
#
# Epoch: 16/80
# Agent trained by 40000 time steps (16m42.93s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.64s)
#
# Epoch: 17/80
# Agent trained by 40000 time steps (16m37.30s).
#
# Epoch: 18/80
# Agent trained by 40000 time steps (16m41.59s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m06.24s)
#
# Epoch: 19/80
# Agent trained by 40000 time steps (16m36.39s).
#
# Epoch: 20/80
# Agent trained by 40000 time steps (16m38.37s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.69s)
#
# Epoch: 21/80
# Agent trained by 40000 time steps (16m38.17s).
#
# Epoch: 22/80
# Agent trained by 40000 time steps (16m39.29s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.61s)
#
# Epoch: 23/80
# Agent trained by 40000 time steps (16m40.30s).
#
# Epoch: 24/80
# Agent trained by 40000 time steps (16m41.41s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.70s)
#
# Epoch: 25/80
# Agent trained by 40000 time steps (16m46.54s).
#
# Epoch: 26/80
# Agent trained by 40000 time steps (16m37.73s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.61s)
#
# Epoch: 27/80
# Agent trained by 40000 time steps (16m48.20s).
#
# Epoch: 28/80
# Agent trained by 40000 time steps (16m44.88s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.62s)
#
# Epoch: 29/80
# Agent trained by 40000 time steps (16m45.24s).
#
# Epoch: 30/80
# Agent trained by 40000 time steps (16m45.69s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.58s)
#
# Epoch: 31/80
# Agent trained by 40000 time steps (16m38.87s).
#
# Epoch: 32/80
# Agent trained by 40000 time steps (16m40.90s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.62s)
#
# Epoch: 33/80
# Agent trained by 40000 time steps (16m48.00s).
#
# Epoch: 34/80
# Agent trained by 40000 time steps (16m39.76s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.67s)
#
# Epoch: 35/80
# Agent trained by 40000 time steps (16m44.52s).
#
# Epoch: 36/80
# Agent trained by 40000 time steps (16m44.51s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.64s)
#
# Epoch: 37/80
# Agent trained by 40000 time steps (16m43.50s).
#
# Epoch: 38/80
# Agent trained by 40000 time steps (16m41.32s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.61s)
#
# Epoch: 39/80
# Agent trained by 40000 time steps (16m40.31s).
#
# Epoch: 40/80
# Agent trained by 40000 time steps (16m43.16s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.66s)
#
# Epoch: 41/80
# Agent trained by 40000 time steps (16m46.74s).
#
# Epoch: 42/80
# Agent trained by 40000 time steps (16m46.81s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.63s)
#
# Epoch: 43/80
# Agent trained by 40000 time steps (16m52.72s).
#
# Epoch: 44/80
# Agent trained by 40000 time steps (16m49.58s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.67s)
#
# Epoch: 45/80
# Agent trained by 40000 time steps (16m47.27s).
#
# Epoch: 46/80
# Agent trained by 40000 time steps (16m47.41s).
# Agent evaluated for 12 episodes of length 20. Average return -791.67. (0m05.61s)
#
# Epoch: 47/80
# Agent trained by 40000 time steps (17m13.59s).
#
# Epoch: 48/80
# 5 works processed.

# %%
report = manager.overview_agents(env_param_grid=env_param_grid)

# %% [markdown]
# # Compute likelihood of an episode

# %% [markdown]
# ## Likelihood of a specific agent
#
# Given a sequence actions and observations, we compute the likelihood of episode data conditioned on a trained agent $p(a_{1:t}, o_{1:t}|\theta_\mathrm{agent})$.

# %%
logp = agent.episode_likelihood(episode['actions'], episode['observations'])
print('log likelihood {:.3f}'.format(logp))

# %% [markdown]
# ## Likelihood of a series of agents
#
# After multiple agents have been trained on a grid of environment parameters, compute the likelihood of episode data conditioned on each agent.

# %%
from irc.utils import logmeanexp

# Uncomment below line, and comment the one after that, if you want to speciy some other episode data
# 'episode_(-3.0, 12.0, 15, 10, -8, -4).pickle'
episode_path = f'episode_{env.get_param()}.pickle'

env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [-8],
    [-4]
]

logps = manager.compute_logps(episode_path=episode_path, env_param_grid=env_param_grid, min_epoch=5, min_optimality=.9)

# logps = logmeanexp(logps, axis=(-2, -1))
# print(f"Log likelihood of all environments saved in an array of shape {logps.shape}")

p = np.exp(logmeanexp(logps, axis=(-2, -1)))
p /= np.nansum(p)

print(f"Probabilities of all environments saved in an array of shape {p.shape}")

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# for episode_path in ['episode_00.pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         agent_seeds=agent_seeds, min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))
#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[2], figsize=(8, 2.5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[..., i], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$r_\mathrm{food}$'+'={:g}'.format(env_param_grid[2][i]))
#         ax.set_xticks(range(p.shape[1]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[1]])
#         ax.set_xlabel(r'$p_\mathrm{cue}$')
#         ax.set_yticks(range(p.shape[0]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[0]])
#             ax.set_ylabel(r'$p_\mathrm{appear}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
        
#         # h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         h = ax.imshow(np.log(p[i,...]))
        
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
#     plt.show()

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

episode_path_list = []
episode_path_list.append('episode_(-3.0, 16.0, 30, 14, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 25, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 25, 10, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 10, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 22, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 22, -8, -4).pickle')

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
    plt.show()

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    # h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    h = plt.imshow(np.log(p))
    
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
    plt.show()

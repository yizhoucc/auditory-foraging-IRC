# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({
    'font.size': 15, 'lines.linewidth': 2,
    'xtick.labelsize': 13, 'ytick.labelsize': 13,
    'axes.spines.top': False, 'axes.spines.right': False,
    'savefig.dpi': 1200,
})

import yaml
import numpy as np

import os
import sys
sys.path.append(f'{os.getcwd()}/irc_gym')

from irc.manager import IRCManager

from auditoryforage.utils import plot_AF_episode

# %% [markdown]
# # Train one agent for a single environment

# %%
defaults = {
    'agent.env._target_': 'auditoryforage.AF_env.AuditoryForaging',
    'agent.model._target_': 'irc.model.FuncBeliefModel',
}
manager = IRCManager(defaults=defaults)

# %% [markdown]
# ## Train an agent
# We train a rational agent for the assume environment parameter [$lick\_cost, food\_reward, attention\_cost\_coeff, attention\_cost\_temp, penalty\_cost, iti\_cost$].

# %%
env_param = [-3.0, 16.0, 20, 22, -8, -4]
num_epochs = 80

agent = manager.train_agent(env_param, num_epochs=num_epochs)
agent, fig = manager.inspect_agent(env_param, figsize=(5, 2.5))
# Out:
# Checkpoint (epoch 80) loaded.
# Fetching the most trained agent so far (epoch 80).
# Agent (seed 2) was trained for 80 epochs, RL optimality 99.54%.

# %% [markdown]
# ## Run the agent in an environment
# We create another environment which has the same observation space and action space as the assumed one, albeit with a different set of environment parameters.

# %%
from auditoryforage.AF_env import AuditoryForaging

# Change below line if you want to try the trained model on a different set of environemnt.
# env_param = [-3.0, 8.0, 13, 8, -8, -4]

env = AuditoryForaging(spec={'experiment': {'prob_01': 0.5},'agent':{'lick_cost':env_param[0],'food_reward':env_param[1],'attention_cost_coeff':env_param[2], 'attention_cost_temp': env_param[3], 'penalty_cost': env_param[4], 'iti_cost': env_param[5]}})
episode = agent.run_one_episode(env=env, num_steps=60, q_states = [[i] for i in range(env.no_nodes)])
fig = plot_AF_episode(episode, env)

env.spec
# Out:
# {'experiment': {'prob_01': 0.5,
#   'no_signal_nodes': 4,
#   'no_penalty_nodes': 1,
#   'no_ITI_nodes': 1},
#  'agent': {'lick_cost': -3.0,
#   'food_reward': 16.0,
#   'attention_cost_coeff': 20,
#   'attention_cost_temp': 22,
#   'penalty_cost': -8,
#   'iti_cost': -4,
#   'no_attention_modes': 6}}

# %% [markdown]
# We can save the episode data in an external `pickle` file.

# %%
import os, pickle

episode_path = f'store/episode_{env.get_param()}.pickle'

if os.path.exists(episode_path):
    print(f"File {episode_path} already exists, will not be overwritten.")
else:
    with open(episode_path, 'wb') as f:
        pickle.dump({
            'external_env_param': env.get_param(),
            'internal_env_param': agent.model.env.get_param(),
            **episode,
        }, f)
    print(f"Episode data saved at '{episode_path}'.")
# Out:
# Episode data saved at 'store/episode_(-3.0, 16.0, 20, 22, -8, -4).pickle'.

# %% [markdown]
# # Train multiple agents for different environments

# %% [markdown]
# ## Sweep over parameter grid
#
# We define a grid of environment parameters, and train multiple agents for each of the combination using different random seeds.
#
# The following can also be done by running `demo-sweep.py` in command line:
# ```bash
# python demo-sweep.py env_param_grid=param_grids/param_grid_0.yaml num_epochs=20 count=5
# ```

# %%
env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [-8],
    [-4]
]

num_epochs = 80 # number of RL epochs

#Lokesh removed the agent_seeds, and count arguments (that can be specified).
manager.train_agents(env_param_grid=env_param_grid, num_epochs=num_epochs)
# Out:
# Use default agent seeds [0, 1, 2] for each environment parameter.
# 0 works processed.
# All works are processed or being processed.

# %%
report = manager.overview_agents(env_param_grid=env_param_grid)
# Out:
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Average number of trained epochs: 80.0
# Approximate training time 0m02.02s per epoch.
# Approximate evaluation time 0m00.10s.
# Average training optimality 96.3%

# %% [markdown]
# # Compute likelihood of an episode

# %% [markdown]
# ## Likelihood of a specific agent
#
# Given a sequence actions and observations, we compute the likelihood of episode data conditioned on a trained agent $p(a_{1:t}, o_{1:t}|\theta_\mathrm{agent})$.

# %%
logp = agent.episode_likelihood(episode['actions'], episode['observations'])
print('log likelihood {:.3f}'.format(logp))
# Out:
# log likelihood -31.421

# %% [markdown]
# ## Likelihood of a series of agents
#
# After multiple agents have been trained on a grid of environment parameters, compute the likelihood of episode data conditioned on each agent.

# %%
from irc.utils import logmeanexp

# Uncomment below line, and comment the one after that, if you want to speciy some other episode data
# 'episode_(-3.0, 12.0, 15, 10, -8, -4).pickle'
episode_path = f'episode_{env.get_param()}.pickle'

env_param_grid = [
    [-3.0], # lick_cost
    [16.0], # food_reward
    [20, 25, 30, 35, 40], # attention_cost_coeff
    [6, 10, 14, 18, 22], # attention_cost_temp
    [-8],
    [-4]
]

logps = manager.compute_logps(episode_path=episode_path, env_param_grid=env_param_grid, min_epoch=5, min_optimality=.9)

# logps = logmeanexp(logps, axis=(-2, -1))
# print(f"Log likelihood of all environments saved in an array of shape {logps.shape}")

p = np.exp(logmeanexp(logps, axis=(-2, -1)))
p /= np.nansum(p)

print(f"Probabilities of all environments saved in an array of shape {p.shape}")
# Out:
# Episode data saved at key 053B3E.
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 053B3E (60 time steps)...
# ------------
# Processing 37BE9699 (1)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -179.044 ( 0m00.02s)
# ------------
# Processing 9C37527F (11)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 10, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -282.842 ( 0m00.02s)
# ------------
# Processing C2838B45 (21)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 35, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -75.577 ( 0m00.02s)
# ------------
# Processing C57917DA (31)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 6, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -388.137 ( 0m00.02s)
# ------------
# Processing 51D3B90F (41)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 35, 6, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -340.831 ( 0m00.02s)
# ------------
# Processing F464E266 (51)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -38.322 ( 0m00.02s)
# ------------
# Processing 618F073F (61)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -41.760 ( 0m00.02s)
# ------------
# Processing 96BAA71D (71)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 10, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -265.560 ( 0m00.02s)
# ------------
# Processing 39712469 (81)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -36.934 ( 0m00.02s)
# ------------
# Processing FD4F21D0 (91)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -123.085 ( 0m00.02s)
# ------------
# Processing 33D0FCD9 (101)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -179.044 ( 0m00.02s)
# ------------
# Processing 9A5C24B8 (111)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -128.953 ( 0m00.02s)
# ------------
# Processing 85FA11F7 (121)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -182.446 ( 0m00.02s)
# ------------
# Processing BDA933AF (131)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 35, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -74.187 ( 0m00.02s)
# ------------
# Processing 32EA4CFA (141)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 6, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -356.892 ( 0m00.02s)
# ------------
# Processing 264AD84B (151)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -40.374 ( 0m00.02s)
# ------------
# Processing EE05B0AC (161)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 6, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -388.137 ( 0m00.02s)
# ------------
# Processing 09F2CCAD (171)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -127.785 ( 0m00.02s)
# ------------
# Processing 15608087 (181)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -40.183 ( 0m00.02s)
# ------------
# Processing CA920D22 (191)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -128.953 ( 0m00.02s)
# ------------
# Processing 7983E859 (201)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -39.597 ( 0m00.02s)
# ------------
# Processing 14AF238A (211)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 20, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -61.858 ( 0m00.02s)
# ------------
# Processing DF859EFF (221)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 35, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -260.320 ( 0m00.02s)
# ------------
# Processing DB97BBCA (231)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -168.503 ( 0m00.02s)
# ------------
# Processing 4C987892 (241)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 35, 10, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -291.894 ( 0m00.02s)
# ------------
# Processing 00C7AFB3 (251)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 35, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -99.750 ( 0m00.02s)
# ------------
# Processing C02EC4B5 (261)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -39.597 ( 0m00.02s)
# ------------
# Processing 22BBCF45 (271)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -127.785 ( 0m00.02s)
# ------------
# Processing FBE8D2D2 (281)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 6, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -400.629 ( 0m00.02s)
# ------------
# Processing 8BE864AC (291)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -177.177 ( 0m00.02s)
# ------------
# Processing F725AC2D (301)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -36.991 ( 0m00.02s)
# ------------
# Processing 97CE15D2 (311)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 20, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -45.427 ( 0m00.02s)
# ------------
# Processing FEEC3F26 (321)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 20, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -31.421 ( 0m00.02s)
# ------------
# Processing B74134F1 (331)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 20, 10, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -69.487 ( 0m00.02s)
# ------------
# Processing 7F158137 (341)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 6, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -400.629 ( 0m00.02s)
# ------------
# Processing 0FFF1548 (351)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -59.506 ( 0m00.02s)
# ------------
# Processing B2F7ED38 (361)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -40.183 ( 0m00.02s)
# ------------
# Processing F83FA285 (371)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 35, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -99.750 ( 0m00.02s)
# ------------
# Processing CF86F259 (381)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -123.085 ( 0m00.02s)
# ------------
# Processing 70E5C9D8 (391)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 10, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -316.137 ( 0m00.02s)
# ------------
# Processing 5C72C62C (401)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -127.785 ( 0m00.02s)
# ------------
# Processing 1CE93516 (411)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -41.760 ( 0m00.02s)
# ------------
# Processing C97A8F3B (421)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -82.492 ( 0m00.02s)
# ------------
# Processing C35E3758 (431)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 35, 10, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -266.233 ( 0m00.02s)
# ------------
# Processing 452A93C6 (441)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 20, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -41.483 ( 0m00.02s)
# ------------
# Processing 625799AE (451)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -162.294 ( 0m00.02s)
# ------------
# Processing 27D541C5 (461)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 10, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -196.333 ( 0m00.02s)
# ------------
# Processing 256AA75B (471)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 10, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -282.842 ( 0m00.02s)
# ------------
# Processing 6B03AAD1 (481)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 35, 10, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -323.371 ( 0m00.02s)
# ------------
# Processing 04DB3EFC (491)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -38.322 ( 0m00.02s)
# ------------
# Processing DCA8530E (501)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 25, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -38.536 ( 0m00.02s)
# ------------
# Processing 4DC34371 (511)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 20, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -48.843 ( 0m00.02s)
# ------------
# Processing D9E99CC3 (521)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 40, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -123.085 ( 0m00.02s)
# ------------
# Processing BBA7D3AE (531)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 20, 22, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -45.427 ( 0m00.02s)
# ------------
# Processing D4771C07 (541)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 20, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -41.483 ( 0m00.02s)
# ------------
# Processing 33C17398 (551)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -51.448 ( 0m00.02s)
# ------------
# Processing 485983B7 (561)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 30, 14, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -203.243 ( 0m00.02s)
# ------------
# Processing F9E93E7A (571)...
# No checkpoint loaded.
# Agent environment parameter:
# (-3.0, 16.0, 20, 18, -8, -4)
# Log likelihood of an agent (trained for 80 epochs): -34.738 ( 0m00.02s)
# 576 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# Probabilities of all environments saved in an array of shape (1, 1, 5, 5, 1, 1)

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# for episode_path in ['episode_00.pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         agent_seeds=agent_seeds, min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))
#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[2], figsize=(8, 2.5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[..., i], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$r_\mathrm{food}$'+'={:g}'.format(env_param_grid[2][i]))
#         ax.set_xticks(range(p.shape[1]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[1]])
#         ax.set_xlabel(r'$p_\mathrm{cue}$')
#         ax.set_yticks(range(p.shape[0]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[0]])
#             ax.set_ylabel(r'$p_\mathrm{appear}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[0].index(env_param[0])
#     j = env_param_grid[1].index(env_param[1])
#     k = env_param_grid[2].index(env_param[2])
#     axes[k].scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
#         h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
#     plt.show()

# %%
# from irc.utils import logmeanexp

# # for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
# # for episode_path in ['episode_(-3.0, 12.0, 15, 10, -8, -4).pickle','episode_(-3.0, 8.0, 19, 12, -8, -4).pickle', 'episode_(-3.0, 16.0, 13, 8, -8, -4).pickle']:
# for episode_path in ['episode_(-3.0, 16.0, 30, 14, -8, -4).pickle']:
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
#     print('Length of episode: {}'.format(saved['num_steps']))
    
#     #Lokesh removed the agent_seeds argument (that can be specified).
#     logps = manager.compute_logps(
#         episode_path=episode_path, env_param_grid=env_param_grid,
#         min_epoch=25, min_optimality=0.98, patience=0,
#     )

#     p = np.exp(logmeanexp(logps, axis=(-2, -1)))

#     #Lokesh added this in order to squeeze out unwanted dimensions
#     p = np.squeeze(p)

#     p /= np.nansum(p)

#     _, axes = plt.subplots(1, p.shape[0], figsize=(16, 5), gridspec_kw={'wspace': 0.02})
#     for i, ax in enumerate(axes):
        
#         # h = ax.imshow(p[i,...], vmin=0, vmax=np.nanmax(p))
#         h = ax.imshow(np.log(p[i,...]))
        
#         ax.set_title(r'$\mathrm{food reward}$'+'={:g}'.format(env_param_grid[1][i]))
#         ax.set_xticks(range(p.shape[2]))
#         ax.set_xticklabels(['{:g}'.format(v) for v in env_param_grid[3]])
#         ax.set_xlabel(r'$\mathrm{attention cost temp}$')
#         ax.set_yticks(range(p.shape[1]))
#         if i==0:
#             ax.set_yticklabels(['{:g}'.format(v) for v in env_param_grid[2]])
#             ax.set_ylabel(r'$\mathrm{attention cost coeff}$')
#         else:
#             ax.set_yticklabels([])
#     # agent environment parameter
#     with open(f'store/{episode_path}', 'rb') as f:
#         saved = pickle.load(f)
#     env_param = saved['internal_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=30, marker='o', color='tomato')
#     env_param = saved['external_env_param']
#     i = env_param_grid[1].index(env_param[1])
#     j = env_param_grid[2].index(env_param[2])
#     k = env_param_grid[3].index(env_param[3])
#     axes[i].scatter(k, j, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
#     plt.colorbar(h, ax=axes, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
#     plt.show()

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

episode_path_list = []
episode_path_list.append('episode_(-3.0, 16.0, 30, 14, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 25, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 10, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 35, 18, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 6, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 40, 22, -8, -4).pickle')
episode_path_list.append('episode_(-3.0, 16.0, 20, 22, -8, -4).pickle')

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$p(\theta|a_{1:t},o_{1:t})$', fraction=0.1)
    plt.show()
# Out:
# External environment parameter: (-3.0, 16.0, 30, 14, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode E6B7C4 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 25, 18, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 31EC23 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 35, 10, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 2045B9 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 35, 18, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 2C053B (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 20, 6, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 3EC1FE (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 40, 6, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 633126 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 40, 22, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 4EB2E6 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 20, 22, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 053B3E (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.

# %%
# Modified for Lokesh's 2D case
from irc.utils import logmeanexp

# for episode_path in ['episode_{:02d}.pickle'.format(i) for i in range(4, 12)]:
for episode_path in episode_path_list:
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    print('External environment parameter: {}'.format(tuple(saved['external_env_param'])))
    print('Length of episode: {}'.format(saved['num_steps']))
    
    #Lokesh removed the agent_seeds argument (that can be specified).
    logps = manager.compute_logps(
        episode_path=episode_path, env_param_grid=env_param_grid,
        min_epoch=25, min_optimality=0.9, patience=0,
    )

    p = np.exp(logmeanexp(logps, axis=(-2, -1)))

    #Lokesh added this in order to squeeze out unwanted dimensions
    p = np.squeeze(p)

    p /= np.nansum(p)


    # h = plt.imshow(p, vmin=0, vmax=np.nanmax(p))
    h = plt.imshow(np.log(p))
    
    plt.xticks(range(p.shape[1]), ['{:g}'.format(v) for v in env_param_grid[3]])
    plt.xlabel(r'$\mathrm{attention\ cost\ temp}$')
    plt.yticks(range(p.shape[0]), ['{:g}'.format(v) for v in env_param_grid[2]])
    plt.ylabel(r'$\mathrm{attention\ cost\ coeff}$')
    # agent environment parameter
    with open(f'store/{episode_path}', 'rb') as f:
        saved = pickle.load(f)
    env_param = saved['internal_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=30, marker='o', color='tomato')
    env_param = saved['external_env_param']
    i = env_param_grid[2].index(env_param[2])
    j = env_param_grid[3].index(env_param[3])
    plt.scatter(j, i, s=40, marker='s', edgecolor='orchid', facecolor='none', linewidth=2)
    plt.colorbar(h, label=r'$\log(p(\theta|a_{1:t},o_{1:t}))$', fraction=0.1)
    plt.show()
# Out:
# External environment parameter: (-3.0, 16.0, 30, 14, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode E6B7C4 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 25, 18, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 31EC23 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 35, 10, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 2045B9 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 35, 18, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 2C053B (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 20, 6, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 3EC1FE (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 40, 6, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 633126 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 40, 22, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 4EB2E6 (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.
# External environment parameter: (-3.0, 16.0, 20, 22, -8, -4)
# Length of episode: 60
# Use default agent seeds [0, 1, 2] for each environment parameter.
# Use default belief seeds [0, 1, 2, 3, 4, 5, 6, 7] for each run.
# 72 valid agents found.
# Computing likelihood of episode 053B3E (60 time steps)...
# 0 works processed.
# All works are processed or being processed.
# 96.00% of the likelihood entries have been computed.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append(f'{os.getcwd()}/irc_gym')
from ult import *
from irc_gym.irc.model import FuncBeliefModel
from stable_baselines3 import PPO
from auditoryforage.AF_env import AuditoryForagingReward2 as AFtask

# %%
modelname = 'vary_reward_gamma_ctrl_V1'

epoch_size = 33333
n_epoch = 55
n_seed = 1
seed = 0
np.random.seed(seed)

# vary conditions
vmin, vmax = 10, 10000
food_reward_list = np.linspace(vmin, vmax, 5)
plist = [np.array([.5, .7])]
node_list = [25]
# fixed params
attcost = -1.6
facost = -50
env_param = [0, None, attcost, .25, facost, 0, 0]

# for plotting
no_episodes = 2222  # for eval plot during training
plot_no_episodes = 555 # for raster plot
minlen, maxlen=0,np.inf
nbin=15
bins=np.linspace(0,1,nbin)

# %%
# color bars
num_discrete_var = len(food_reward_list)
discrete_colors = rewardcmap(np.linspace(0, 1, num_discrete_var))
discrete_cmap = ListedColormap(discrete_colors)
boundaries = np.arange(num_discrete_var + 1)
norm = BoundaryNorm(boundaries, num_discrete_var)
fig, ax = plt.subplots(figsize=(8, 1))
fig.subplots_adjust(bottom=0.5)
cbar = fig.colorbar(
    plt.cm.ScalarMappable(norm=norm, cmap=discrete_cmap),
    cax=ax,
    orientation='horizontal',
    ticks=np.arange(num_discrete_var) + 0.5
)
cbar.set_label('Food reward')
cbar.set_ticks(np.arange(num_discrete_var) + 0.5)
cbar.set_ticklabels([f'{int(a)}' for a in food_reward_list])
plt.show()

# %%
# helper and plot function
def process_one_subdf_df(subdf,no_signal_nodes=25, no_penalty_nodes=1):
    '''process the subdf data into result lists. the input is a df'''
    hit_count = 0
    miss_count = 0
    false_alarm_count = 0
    noise_time_before_lick = 0
    signal_time_before_lick = 0
    total_noise_time = 0
    total_signal_time = 0
    total_reward = 0

    attention_time_points_across_subdfs = []
    subdf_length_across_subdfs = []
    hit_reaction_time_across_subdfs = []
    fa_reaction_time_across_subdfs = []

    # process single ep data
    if subdf['actions'][-1][0] == 1:
        if subdf['states'][-1][0] >  no_signal_nodes +  no_penalty_nodes:
            hit_count += 1
            signal_time_before_lick_curr_subdf = count_no_elements(
                subdf['states'], 1,  no_signal_nodes)
            hit_reaction_time_across_subdfs.append(
                signal_time_before_lick_curr_subdf)
            signal_time_before_lick += signal_time_before_lick_curr_subdf
        else:
            false_alarm_count += 1
            noise_time_before_lick_curr_subdf = count_no_elements(
                subdf['states'], 0, 0)
            fa_reaction_time_across_subdfs.append(
                noise_time_before_lick_curr_subdf)
            noise_time_before_lick += noise_time_before_lick_curr_subdf
    else:
        miss_count += 1
    total_signal_time += count_no_elements(
        subdf['states'], 1,  no_signal_nodes)
    total_noise_time += count_no_elements(subdf['states'], 0, 0)
    total_reward += sum(subdf['rewards'])
    # attention_time_points_across_subdfs.append(np.where(subdf['actions'] % env.no_attention_modes > 0)[0])
    attention_time_points_across_subdfs.append(
        np.where(np.array([elt[1] for elt in subdf['actions']]) == 1)[0])
    subdf_length_across_subdfs.append(len(subdf['states']))
    # end process single ep data
    food_reward_idx = subdf['trial_food_reward_idx']
    return (food_reward_idx,
            hit_count,
            miss_count,
            false_alarm_count,
            noise_time_before_lick,
            signal_time_before_lick,
            total_noise_time,
            total_signal_time,
            total_reward,
            attention_time_points_across_subdfs,
            subdf_length_across_subdfs,
            hit_reaction_time_across_subdfs,
            fa_reaction_time_across_subdfs
            )
def hit_reaction_plot(df):
    ''' '''
    # process data
    hit_count_list = [[0] for _ in range(len(food_reward_list))]
    miss_count_list = [[0] for _ in range(len(food_reward_list))]
    false_alarm_list = [[0] for _ in range(len(food_reward_list))]

    noise_time_before_lick_list = [[0] for _ in range(len(food_reward_list))]
    signal_time_before_lick_list = [[0] for _ in range(len(food_reward_list))]
    total_noise_time_list = [[0] for _ in range(len(food_reward_list))]
    total_signal_time_list = [[0] for _ in range(len(food_reward_list))]
    # dist naming space: list of list of num. big list of each reward cond. small list of each trial's summary stats, which is a single number.
    total_reward_dist= [[] for _ in range(len(food_reward_list))]
    rt_hit_dist=[[] for _ in range(len(food_reward_list))]
    rt_fa_dist=[[] for _ in range(len(food_reward_list))]
    total_att_time_dist = [[] for _ in range(len(food_reward_list))]

    for i in range(len(df)):
        (food_reward_idx,
        hit_count,
        miss_count,
        false_alarm_count,

        noise_time_before_lick,
        signal_time_before_lick,
        total_noise_time,
        total_signal_time,

        total_reward,

        attention_time_points_across_episodes,
        episode_length_across_episodes,
        hit_reaction_time_across_episodes,
        fa_reaction_time_across_episodes
        ) = process_one_subdf_df(df.iloc[i])

        hit_count_list[food_reward_idx][0] += (hit_count)
        miss_count_list[food_reward_idx][0] += (miss_count)
        false_alarm_list[food_reward_idx][0] += (false_alarm_count)

        noise_time_before_lick_list[food_reward_idx][0] += (noise_time_before_lick)
        signal_time_before_lick_list[food_reward_idx][0] += (
            signal_time_before_lick)
        total_noise_time_list[food_reward_idx][0] += (total_noise_time)
        total_signal_time_list[food_reward_idx][0] += (total_signal_time)

        total_reward_dist[food_reward_idx].append(total_reward)
        rt_hit_dist[food_reward_idx].append(signal_time_before_lick)
        rt_fa_dist[food_reward_idx].append(noise_time_before_lick)
        total_att_time_dist[food_reward_idx].append(len(attention_time_points_across_episodes[0]))


    # 3 curve plot
    hit_count_list, miss_count_list, false_alarm_list = np.array(
        hit_count_list), np.array(miss_count_list), np.array(false_alarm_list)
    hit_prob = [hit_count_list[i]/(hit_count_list[i]+miss_count_list[i] +
                                    false_alarm_list[i]) for i in range(len(hit_count_list))]
    miss_prob = [miss_count_list[i]/(hit_count_list[i]+miss_count_list[i] +
                                        false_alarm_list[i]) for i in range(len(hit_count_list))]
    fa_prob = [false_alarm_list[i]/(hit_count_list[i]+miss_count_list[i] +
                                    false_alarm_list[i]) for i in range(len(hit_count_list))]

    xs=np.arange(len(food_reward_list))
    fig, ax=plt.subplots(1,1, figsize=(5,4))

    ax.plot(xs, hit_prob, '-*g', label='hit')
    ax.plot(xs, miss_prob, '-*b', label='miss')
    ax.plot(xs, fa_prob, '-*r', label='fa')
    quickleg(ax, bbox_to_anchor=(-0.5,0))
    ax.set_xlabel('food reward')
    ax.set_ylabel('probability')
    # ax.set_xticks(xs, [f'{a:.0f}' for a in food_reward_list]) # actual values
    ax.set_xticks([xs[i] for i in [0,-1]], ['low', 'high']) # low high
    ax.set_xticks(xs)
    ax.set_yticks([0,0.5,1], ['0', '.5','1'])
    ax.set_xticks(xs)
    centerax(ax)
    ax.set_title('hit, miss, false alarm')
    plt.show()

    # reaction time
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    data = []
    for food_reward_idx, v in enumerate(rt_hit_dist):
        v = np.array(v)
        v = v[v > 1]  # ignore the 0 reaction time in the plots
        if len(v) == 0:
            continue
        data.append((food_reward_idx, v))


    for i, (food_reward_idx, curve) in enumerate(data):
        sns.kdeplot(curve, label=f'reward:{food_reward_list[food_reward_idx]:.0f}', clip=(1, np.max(v)), bw_adjust=1,color=rewardcmap(np.linspace(0, 1, len(data)))[i])

        # plt.plot(curve, color=cmap(np.linspace(0, 1, len(data)))[i])
    # color_bar=plt.colorbar(plt.cm.ScalarMappable(cmap=rewardcmap),ax=ax)
    # ticks = [0, 0.5, 1]
    # tick_labels = ['Low food reward', '', 'High food reward']
    # color_bar.set_ticks(ticks)
    # color_bar.set_ticklabels(tick_labels)

    ax.set_ylabel('probability')
    ax.set_xlabel('reaction time')
    centerax(ax)
    ax.set_xticks([0, 10, 20],[0, 10, 20])
    ax.set_yticks([])
    ax.set_yticklabels([])
    # quickleg(ax, bbox_to_anchor=(-0.5, 0))
    ax.set_title('vary reward \n reaction time distribution')
    # quicksave('reaction time distribution v3 full', modelname)
    plt.show()

# %%
for iepoch in range(0, n_epoch):
    # training ----------------
    for node in node_list:
        for p1p2 in plist:
            thismodel = f'seed{seed}_{modelname}_n{node}_p{p1p2}_ep{iepoch}'
        
            task = AFtask(spec={'agent':
                            {'lick_cost': env_param[0],
                            'food_reward': env_param[1],
                            'attention_cost_coeff': env_param[2],
                            'attention_cost_temp': env_param[3],
                            'penalty_cost': env_param[4],
                            'iti_cost': env_param[5],
                            'time_in_game_reward': env_param[6]},
                            'experiment': {'no_signal_nodes': node}})
            task.food_reward_list = food_reward_list
            taskbelief = FuncBeliefModel(env=task, rng=1)
            task.obs_certainity_possible = p1p2

            # train
            if iepoch == 0:
                model = PPO('MlpPolicy', taskbelief, verbose=0, device='cpu',
                            clip_range=0.1, ent_coef=0.01)
            else:
                previous_model = f'seed{seed}_{modelname}_n{node}_p{p1p2}_ep{iepoch-1}'
                model = PPO.load(f'ycstore/{previous_model}', env=taskbelief)
            model.learn(total_timesteps=epoch_size,)
            model.save(f'ycstore/{thismodel}')
            print(f'epoch{iepoch}, node{node}: yctore/{thismodel} saved')
            model = PPO.load(f'ycstore/{thismodel}', env=taskbelief) # test load

    # eval collection --------------------
    results=[]
    for inode, node in enumerate(node_list):
        for ip, p1p2 in enumerate(plist):
            task = AFtask(spec={'agent': 
                                        {'lick_cost': env_param[0],
                                        'food_reward': env_param[1],
                                        'attention_cost_coeff': env_param[2],
                                        'attention_cost_temp': env_param[3],
                                        'penalty_cost': env_param[4],
                                        'iti_cost': env_param[5],
                                        'time_in_game_reward': env_param[6]},
                                        'experiment':{                              'no_signal_nodes':node}})
            task.food_reward_list = food_reward_list
            taskbelief = FuncBeliefModel(env=task, rng=1)
            task.obs_certainity_possible = p1p2
            thismodel = f'seed{seed}_{modelname}_n{node}_p{p1p2}_ep{iepoch}'
            model = PPO.load(f'ycstore/{thismodel}')

            def eval_wrapper(a):
                episode = run_one_episode(task=task, taskbelief=taskbelief, agent=model,
                                        num_steps=100000, deterministic=True)
                return episode

            with multiprocess.Pool(processes=8) as pool:
                all_episode_data = pool.map(eval_wrapper, range(no_episodes))
            
            for episode in all_episode_data:
                # process
                episode['inode'] = inode
                episode['ip'] = ip
                episode['at_times'] = np.where(
                    np.array([elt[1] for elt in episode['actions']]) == 1)[0].astype('int')
                episode['at_seq'] = [float(elt[1])
                                    for elt in episode['actions']]
                if episode['actions'][-1][0] == 1:
                    episode['licktime'] = int(len(episode['states']))
                else:
                    episode['lick_licktimetime'] = -1
                episode['trial_len'] = len(episode['actions'])

                results.append(episode)

    df = pd.DataFrame(results)
    print(f'total reward: {sum(np.concatenate(df.rewards.to_numpy()))}')
    hit_reaction_plot(df)


    # attn time percent of trial len
    all_reward_res = {}  # k: v = foodreward idx: this food reward res
    for r in range(len(food_reward_list)):
        attention_prob_list, lick_prob_list, noise_prob_list, lick_time_list, att_time_list, trial_len, attention_entropy_list, lick_entropy_list = [], [], [], [], [], [], [], []
        all_reward_res[r] = attention_prob_list, lick_prob_list, noise_prob_list, lick_time_list, att_time_list, trial_len, attention_entropy_list, lick_entropy_list


    for episode in all_episode_data:
        attention_prob_list, lick_prob_list, noise_prob_list, lick_time_list, att_time_list, trial_len, attention_entropy_list, lick_entropy_list = all_reward_res[
            episode['trial_food_reward_idx']]
        att_time_list.append(
            np.where(np.array([elt[1] for elt in episode['actions']]) == 1)[0])

        if episode['actions'][-1][0] == 1:
            lick_time_list.append(len(episode['states']))
        else:
            lick_time_list.append(None)
        trial_len.append(len(episode['actions']))

        attention_prob, lick_prob, noise_prob, time = get_att_lick_probs_new(
            episode, model)
        attention_prob_list.append(attention_prob)
        lick_prob_list.append(lick_prob)
        noise_prob_list.append(noise_prob)
        attention_entropy_list.append(compute_bernoulli_entropy(attention_prob))
        lick_entropy_list.append(compute_bernoulli_entropy(lick_prob))


    fig= plt.figure()
    for food_reward_idx in all_reward_res.keys():
        attention_prob_list, lick_prob_list, noise_prob_list, lick_time_list, att_time_list, trial_len, attention_entropy_list, lick_entropy_list = all_reward_res[
            food_reward_idx]
        plotdata=[len(a)/b for a,b in zip(att_time_list,trial_len)]
        sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
            np.linspace(0, 1, len(all_reward_res)))[food_reward_idx])

    # plt.xlabel('number of high attentions')
    plt.ylabel('prob')
    plt.title(f'attention times protion of trials, varying food reward')
    # # plt.ylim(0,1500)
    # centerax(plt.gca())
    plt.yticks([])
    # plt.gca().spines['left'].set_visible(False)
    plt.xlim(0, None)
    plt.xticks([0, 15], [0,15])
    plt.xlabel('# high attentions')
    # quicksave('total att time percent', 'plot sigmoid', fig=fig)
    plt.show()
# Out:
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch0, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep0 saved
# total reward: 0.0
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch1, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep1 saved
# total reward: 0.0
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch2, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep2 saved
# total reward: 0.0
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch3, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep3 saved
# total reward: 0.0
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch4, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep4 saved
# total reward: 240396.32308644016
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch5, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep5 saved
# total reward: 227970.47421836428
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch6, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep6 saved
# total reward: 207163.7881996457
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch7, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep7 saved
# total reward: 214695.37640433133
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch8, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep8 saved
# total reward: 235137.33298640407
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch9, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep9 saved
# total reward: 240779.36185416646
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch10, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep10 saved
# total reward: 236300.79682423585
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch11, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep11 saved
# total reward: 254822.95938973373
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch12, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep12 saved
# total reward: 240124.64962317338
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch13, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep13 saved
# total reward: 226591.08602679748
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch14, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep14 saved
# total reward: 263716.5721021493
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch15, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep15 saved
# total reward: 234525.6588490928
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch16, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep16 saved
# total reward: 233933.0410849254
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch17, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep17 saved
# total reward: 231194.14644968408
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch18, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep18 saved
# total reward: 201023.9247670331
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch19, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep19 saved
# total reward: 217654.74010808687
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch20, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep20 saved
# total reward: 247073.36281654035
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch21, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep21 saved
# total reward: 243244.71932741333
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch22, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep22 saved
# total reward: 246454.6485358259
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch23, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep23 saved
# total reward: 264293.19502146967
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch24, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep24 saved
# total reward: 209287.79069701358
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch25, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep25 saved
# total reward: 237271.21067506485
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch26, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep26 saved
# total reward: 275937.4108453153
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch27, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep27 saved
# total reward: 238991.39357276694
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch28, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep28 saved
# total reward: 246663.61669324318
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch29, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep29 saved
# total reward: 242329.31281951175
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch30, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep30 saved
# total reward: 283509.8021372813
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch31, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep31 saved
# total reward: 224139.71429497766
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch32, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep32 saved
# total reward: 243020.63654649042
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch33, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep33 saved
# total reward: 278168.13557179796
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch34, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep34 saved
# total reward: 236281.80140448327
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch35, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep35 saved
# total reward: 237158.2743986264
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch36, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep36 saved
# total reward: 237998.38730617356
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch37, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep37 saved
# total reward: 264898.1390281355
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch38, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep38 saved
# total reward: 247820.30062665493
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch39, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep39 saved
# total reward: 246363.48649801838
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch40, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep40 saved
# total reward: 204150.73261305457
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch41, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep41 saved
# total reward: 283427.14960448083
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch42, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep42 saved
# total reward: 233002.92356982248
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch43, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep43 saved
# total reward: 266096.4075736725
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_47315/1041598586.py:113: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# epoch44, node25: yctore/seed0_vary_reward_gamma_ctrl_V1_n25_p[0.5 0.7]_ep44 saved
# total reward: 254588.12890901475

# %% [markdown]
# # eval plot

# %%
for iepoch in range(2, n_epoch,3):
   
    # eval collection --------------------
    results=[]
    for inode, node in enumerate(node_list):
        for ip, p1p2 in enumerate(plist):
            task = AFtask(spec={'agent': 
                                        {'lick_cost': env_param[0],
                                        'food_reward': env_param[1],
                                        'attention_cost_coeff': env_param[2],
                                        'attention_cost_temp': env_param[3],
                                        'penalty_cost': env_param[4],
                                        'iti_cost': env_param[5],
                                        'time_in_game_reward': env_param[6]},
                                        'experiment':{                              'no_signal_nodes':node}})
            task.food_reward_list = food_reward_list
            taskbelief = FuncBeliefModel(env=task, rng=1)
            task.obs_certainity_possible = p1p2
            thismodel = f'seed{seed}_{modelname}_n{node}_p{p1p2}_ep{iepoch}'
            model = PPO.load(f'ycstore/{thismodel}')

            def eval_wrapper(a):
                episode = run_one_episode(task=task, taskbelief=taskbelief, agent=model,
                                        num_steps=100000, deterministic=True)
                return episode

            with multiprocess.Pool(processes=8) as pool:
                all_episode_data = pool.map(eval_wrapper, range(no_episodes))
            
            for episode in all_episode_data:
                # process
                episode['inode'] = inode
                episode['ip'] = ip
                episode['at_times'] = np.where(
                    np.array([elt[1] for elt in episode['actions']]) == 1)[0].astype('int')
                episode['at_seq'] = [float(elt[1])
                                    for elt in episode['actions']]
                if episode['actions'][-1][0] == 1:
                    episode['licktime'] = int(len(episode['states']))
                else:
                    episode['lick_licktimetime'] = -1
                episode['trial_len'] = len(episode['actions'])

                results.append(episode)

    df = pd.DataFrame(results)
    print(f'total reward: {sum(np.concatenate(df.rewards.to_numpy()))}')
    hit_reaction_plot(df)


    # attn time percent of trial len
    all_reward_res = {}  # k: v = foodreward idx: this food reward res
    for r in range(len(food_reward_list)):
        attention_prob_list, lick_prob_list, noise_prob_list, lick_time_list, att_time_list, trial_len, attention_entropy_list, lick_entropy_list = [], [], [], [], [], [], [], []
        all_reward_res[r] = attention_prob_list, lick_prob_list, noise_prob_list, lick_time_list, att_time_list, trial_len, attention_entropy_list, lick_entropy_list


    for episode in all_episode_data:
        attention_prob_list, lick_prob_list, noise_prob_list, lick_time_list, att_time_list, trial_len, attention_entropy_list, lick_entropy_list = all_reward_res[
            episode['trial_food_reward_idx']]
        att_time_list.append(
            np.where(np.array([elt[1] for elt in episode['actions']]) == 1)[0])

        if episode['actions'][-1][0] == 1:
            lick_time_list.append(len(episode['states']))
        else:
            lick_time_list.append(None)
        trial_len.append(len(episode['actions']))

        attention_prob, lick_prob, noise_prob, time = get_att_lick_probs_new(
            episode, model)
        attention_prob_list.append(attention_prob)
        lick_prob_list.append(lick_prob)
        noise_prob_list.append(noise_prob)
        attention_entropy_list.append(compute_bernoulli_entropy(attention_prob))
        lick_entropy_list.append(compute_bernoulli_entropy(lick_prob))


    fig= plt.figure()
    for food_reward_idx in all_reward_res.keys():
        attention_prob_list, lick_prob_list, noise_prob_list, lick_time_list, att_time_list, trial_len, attention_entropy_list, lick_entropy_list = all_reward_res[
            food_reward_idx]
        plotdata=[len(a) for a,b in zip(att_time_list,trial_len)]
        sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
            np.linspace(0, 1, len(all_reward_res)))[food_reward_idx])

    # plt.xlabel('number of high attentions')
    plt.ylabel('prob')
    plt.title(f'attention times protion of trials, varying food reward')
    # # plt.ylim(0,1500)
    # centerax(plt.gca())
    plt.yticks([])
    # plt.gca().spines['left'].set_visible(False)
    plt.xlim(0, None)
    plt.xticks([0, 15], [0,15])
    plt.xlabel('# high attentions')
    # quicksave('total att time percent', 'plot sigmoid', fig=fig)
    plt.show()
# Out:
# total reward: 0.0
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 0.0
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 213183.50682062682
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 214364.05040941932
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 212720.42153328838
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 220453.03519074392
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 223903.94810505936
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 218536.75017473943
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 223574.4093430012
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 240245.59475177297
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 220670.13562327446
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 241292.53469695768
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 241591.71748275543
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 232551.63417714264
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 228697.71721610034
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 236445.3863875722
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/570429958.py:84: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(plotdata, label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=1, common_norm=False, color=rewardcmap(
# total reward: 198257.6061777814
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 70
#      67     lick_time_list.append(None)
#      68 trial_len.append(len(episode['actions']))
# ---> 70 attention_prob, lick_prob, noise_prob, time = get_att_lick_probs_new(
#      71     episode, model)
#      72 attention_prob_list.append(attention_prob)
#      73 lick_prob_list.append(lick_prob)
#
# File ~/repo/auditory-foraging-IRC/ult.py:695, in get_att_lick_probs_new(episode, agent)
#     693 for ind in range(start_time, len(episode['beliefs'][:-1])):
#     694     belief = episode['beliefs'][:-1][ind]
# --> 695     lick_prob, att_prob = compute_action_probs(belief, agent)
#     696     lick_probs.append(lick_prob)
#     697     att_probs.append(att_prob)
#
# File ~/repo/auditory-foraging-IRC/ult.py:671, in compute_action_probs(belief, agent)
#     669 '''same function rewrite just for clarity'''
#     670 pi = agent.policy.get_distribution(torch.tensor(belief)[None].to('cpu'))
# --> 671 nolicknoatt = np.exp(pi.log_prob(torch.tensor(
#     672     [np.array([0, 0])], dtype=torch.long, device='cpu')).item())
#     673 nolickatt = np.exp(pi.log_prob(torch.tensor(
#     674     [np.array([0, 1])], dtype=torch.long, device='cpu')).item())
#     675 licknoatt = np.exp(pi.log_prob(torch.tensor(
#     676     [np.array([1, 0])], dtype=torch.long, device='cpu')).item())
#
# File /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/stable_baselines3/common/distributions.py:348, in MultiCategoricalDistribution.log_prob(self, actions)
#     345 def log_prob(self, actions: th.Tensor) -> th.Tensor:
#     346     # Extract each discrete action and compute log prob for their respective distributions
#     347     return th.stack(
# --> 348         [dist.log_prob(action) for dist, action in zip(self.distribution, th.unbind(actions, dim=1))], dim=1
#     349     ).sum(dim=1)
#
# File /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/torch/distributions/categorical.py:137, in Categorical.log_prob(self, value)
#     135 def log_prob(self, value):
#     136     if self._validate_args:
# --> 137         self._validate_sample(value)
#     138     value = value.long().unsqueeze(-1)
#     139     value, log_pmf = torch.broadcast_tensors(value, self.logits)
#
# File /opt/homebrew/anaconda3/envs/lab/lib/python3.12/site-packages/torch/distributions/distribution.py:311, in Distribution._validate_sample(self, value)
#     309 assert support is not None
#     310 valid = support.check(value)
# --> 311 if not valid.all():
#     312     raise ValueError(
#     313         "Expected value argument "
#     314         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#     317         f"but found invalid values:\n{value}"
#     318     )
#
# KeyboardInterrupt:

# %%
# new eval ploting --------------------
for food_reward_idx in range(len(food_reward_list)):
    rasterfig, ax = plt.subplots(1, 1, figsize=(
        3, len(plist)*2,), sharex=True, sharey=True)

    subdf=df[(df.trial_food_reward_idx==food_reward_idx)]

    # df=df[df['at_times'].apply(len) > 0]
    subdf=subdf[subdf.licktime!=-1]
    # df.licktime=df.licktime.astype('int')
    subdf=subdf[~subdf.licktime.isna()]

    if len(subdf)==0: continue
    trial_len = np.array(subdf.trial_len)
    valid_ind = np.where((minlen < trial_len) & (trial_len < maxlen))[0]
    grid = np.zeros((len(valid_ind), max(trial_len)+2))
    # print(food_reward_idx,ip, grid.shape)
    sortind = np.argsort([trial_len[i] for i in valid_ind])

    # att
    plot_data = np.array(subdf.at_times)[valid_ind]
    for i, arr in enumerate(plot_data):
        grid[i, arr] = -1
    # lick
    plot_data = np.array(subdf.licktime)[valid_ind]
    for i, arr in enumerate(plot_data):
        if arr:
            grid[i, int(arr)] = 1


    c = ax.imshow(grid, cmap=attnlickcmap, vmin=-1, vmax=1,
                        aspect='auto', interpolation='none')

    ax.set_xticks([0, 50, 100])
    ax.set_xlim(0, 100)
    ax.set_ylim(0, 300)
    ax.set_yticks([])
    ax.spines['left'].set_visible(False)
    ax.set_ylabel(f'{ip} p')
    rasterfig.suptitle(f'{food_reward_idx}, food')
    rasterfig.show()
# Out:
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/122045644.py:41: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   rasterfig.show()

# %%
fig= plt.figure()

for food_reward_idx in np.arange(len(food_reward_list)):
    
    subdf=df[(df.trial_food_reward_idx==food_reward_idx)]
    sns.kdeplot([len(a) for a in subdf.at_times],  label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=2, common_norm=False, color=rewardcmap(
        np.linspace(0, 1, len(food_reward_list)))[food_reward_idx])

    plt.xlabel('number of high attentions')
    plt.ylabel('prob')
    plt.title(f'total attention times, varying food reward')
    # plt.ylim(0,1500)
    # plt.legend()

    centerax(plt.gca())
    plt.yticks([])
    plt.xlim(0, 20)
    # plt.xticks([0, 15])
    # quicksave('total att time', 'plot sigmoid', fig=fig)
plt.show()
# Out:
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/3434413588.py:7: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot([len(a) for a in subdf.at_times],  label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=2, common_norm=False, color=rewardcmap(
# /var/folders/dt/bkhywtzd6ks2r0sh5qxb78w00000gn/T/ipykernel_94026/3434413588.py:7: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot([len(a) for a in subdf.at_times],  label=f'food reward={food_reward_list[food_reward_idx]:.0f}', bw_adjust=2, common_norm=False, color=rewardcmap(
